# %%
# %load_ext autoreload
# %autoreload 2
from notebook import *
# if get something about NUMEXPR_MAX_THREADS being set incorrectly, don't worry.  It's not a problem.
# Out:
# <style>h1 {font-size: 2vw;} h2 {font-size: 1.5vw;} p {font-size: 1.4vw;} div.prompt, code, output, prompt, kbd, pre, samp {font-family: 'SF Mono', 'Courier New', Courier, monospace, sans-serif !important;font-size: 1.4vw !important;}</style>

# %% [markdown]
# # Code Example: Linked list v.s. array

# %% [markdown]
# ## If we don't have cache misses, would linked list be a good option?

# %%
compare([do_render_code("linked_list/linked_list.c", show="depth_of_array"),do_render_code("linked_list/linked_list.c", show="depth_of_list")])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// linked_list/linked_list.c:23-35 (13 lines)</span>
# <span class="kt">int</span><span class="w"> </span><span class="nf">depth_of_array</span><span class="p">(</span><span class="k">struct</span><span class="w"> </span><span class="nc">node</span><span class="w"> </span><span class="o">*</span><span class="n">start</span><span class="p">,</span><span class="w"> </span><span class="kt">int</span><span class="w"> </span><span class="n">size</span><span class="p">)</span>
# <span class="p">{</span>
# <span class="w">    </span><span class="kt">int</span><span class="w"> </span><span class="n">number_of_nodes</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="mi">0</span><span class="p">,</span><span class="w"> </span><span class="n">i</span><span class="p">;</span>
# <span class="w">    </span><span class="kt">unsigned</span><span class="w"> </span><span class="kt">long</span><span class="w"> </span><span class="n">sum</span><span class="o">=</span><span class="mi">0</span><span class="p">;</span>
# <span class="w">    </span><span class="k">struct</span><span class="w"> </span><span class="nc">node</span><span class="w"> </span><span class="o">*</span><span class="n">node</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="n">start</span><span class="p">;</span>
# <span class="w">    </span><span class="k">if</span><span class="p">(</span><span class="n">node</span><span class="o">!=</span><span class="nb">NULL</span><span class="p">)</span><span class="w"> </span><span class="n">number_of_nodes</span><span class="o">=</span><span class="mi">1</span><span class="p">;</span>
# <span class="w">    </span><span class="k">for</span><span class="p">(</span><span class="n">i</span><span class="o">=</span><span class="mi">0</span><span class="p">;</span><span class="n">i</span><span class="o">&lt;</span><span class="n">size</span><span class="p">;</span><span class="n">i</span><span class="o">++</span><span class="p">)</span>
# <span class="w">    </span><span class="p">{</span>
# <span class="w">        </span><span class="k">if</span><span class="p">(</span><span class="n">node</span><span class="p">[</span><span class="n">i</span><span class="p">].</span><span class="n">next</span><span class="p">)</span>
# <span class="w">            </span><span class="n">number_of_nodes</span><span class="o">++</span><span class="p">;</span>
# <span class="w">    </span><span class="p">}</span>
# <sp

# %%
! make -C linked_list clean ; make -C linked_list
# Out:
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# rm -f linked_list linked_list.s
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# cc -c -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H perfstats.c
# cc -c -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.c
# cc -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.o perfstats.o  linked_list_main.c -o linked_list
# cc -S -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.c
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'

# %%
! make -C linked_list clean ; make -C linked_list
! echo "size,list,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "1024,array," >> stats.csv
! linked_list/linked_list 1024 0 100000
! echo -n "1024,list," >> stats.csv
! linked_list/linked_list 1024 1 100000
display_df_mono(render_csv("stats.csv", columns=["size","list","ET","L1_dcache_miss_rate"]))
# Out:
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# rm -f linked_list linked_list.s
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# cc -c -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H perfstats.c
# cc -c -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.c
# cc -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.o perfstats.o  linked_list_main.c -o linked_list
# cc -S -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.c
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# depth: 1024
# depth: 1024
# <style type="text/css">
# #T_66b80_row0_col0, #T_66b80_row0_col1, #T_66b80_row0_col2, #T_66b80_row0_col3, #T_66b80_row0_col4, #T_66b80_row1_col0, #T_66b80_row1_col1, #T_66b80_row1_col2, #T_66b80_row1_col3, #T_66b80_row1_col4 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_66b80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66b80_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_66b80_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_66b80_level0_col2" class="col_heading level0 col2" >list</th>
#       <th id="T_66b80_level0_col3" class="col_heading level0 col3" >ET</th>
#       <th id="T_66b80_level0_col4" class="col_heading level0 col4" >L1_dcache_miss_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66b80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66b80_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_66b80_row0_col1" class="data row0 col1" >1024</td>
#       <td id="T_66b80_row0_col2" class="data row0 col2" >array</td>
#       <td id="T_66b80_row0_col3" class="data row0 col3" >0.026304</td>
#       <td id="T_66b80_row0_col4" class="data row0 col4" >0.000021</td>
#     </tr>
#     <tr>
#       <th id="T_66b80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66b80_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_66b80_row1_col1" class="data row1 col1" >1024</td>
#       <td id="T_66b80_row1_col2" class="data row1 col2" >list</td>
#       <td id="T_66b80_row1_col3" class="data row1 col3" >0.106581</td>
#       <td id="T_66b80_row1_col4" class="data row1 col4" >0.000085</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Take a look of their assembly

# %%
compare([do_render_code("linked_list/linked_list.s", show=["depth_of_array:",".LFE"]),do_render_code("linked_list/linked_list.s", show=["depth_of_list",".LFE0:"])])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// linked_list/linked_list.s:26-49 (24 lines)</span>
# <span class="nl">depth_of_array</span><span class="p">:</span>
# <span class="p">.</span><span class="n">LFB1</span><span class="o">:</span>
# <span class="w">	</span><span class="p">.</span><span class="n">cfi_startproc</span>
# <span class="w">	</span><span class="n">endbr64</span>
# <span class="w">	</span><span class="n">testq</span><span class="w">	</span><span class="o">%</span><span class="n">rdi</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">rdi</span>
# <span class="w">	</span><span class="n">setne</span><span class="w">	</span><span class="o">%</span><span class="n">dl</span>
# <span class="w">	</span><span class="n">movzbl</span><span class="w">	</span><span class="o">%</span><span class="n">dl</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">edx</span>
# <span class="w">	</span><span class="n">testl</span><span class="w">	</span><span class="o">%</span><span class="n">esi</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">esi</span>
# <span class="w">	</span><span class="n">jle</span><span class="w">	</span><span class="p">.</span><span class="n">L6</span>
# <span class="w">	</span><span class="n">movq</span><span class="w">	</span><span class="o">%</span><span class="n">rdi</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">rax</span>
# <span class="w">	</span><span class="n">movslq</span><span class="w">	</span><span class="o">%</span><span class="n">esi</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">rsi</span>
# <span class="w">	</span><span class="n">salq</span><span class="w">	</span><span class="n">$4</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">rsi</span>
# <span class="w">	</span><span class="n">addq</span><span class="w">	</span><span class="o">%</span><span class="n">rsi</span><span class="p">,</span><span class="w"> </span><span class="o">%</span><span class="n">rdi</span>
# <span class="p">.</span><span class="n">L9</span><span class="o">:</span>
# <span class="w">	</span><span class="n">cmpq</span><span class="w">	</span><span class="n">$1</span><span class="p">,</span><span class="w"> </span><span class="mi">8</span><span class="p">(</span><span class="o">%</span><span class="n">rax</span><span class="p">)</span>
# <spa

# %%
display_df_mono(render_csv("stats.csv"))
# Out:
# <style type="text/css">
# #T_8a9c8_row0_col0, #T_8a9c8_row0_col1, #T_8a9c8_row0_col2, #T_8a9c8_row0_col3, #T_8a9c8_row0_col4, #T_8a9c8_row0_col5, #T_8a9c8_row0_col6, #T_8a9c8_row0_col7, #T_8a9c8_row0_col8, #T_8a9c8_row0_col9, #T_8a9c8_row0_col10, #T_8a9c8_row0_col11, #T_8a9c8_row0_col12, #T_8a9c8_row1_col0, #T_8a9c8_row1_col1, #T_8a9c8_row1_col2, #T_8a9c8_row1_col3, #T_8a9c8_row1_col4, #T_8a9c8_row1_col5, #T_8a9c8_row1_col6, #T_8a9c8_row1_col7, #T_8a9c8_row1_col8, #T_8a9c8_row1_col9, #T_8a9c8_row1_col10, #T_8a9c8_row1_col11, #T_8a9c8_row1_col12, #T_8a9c8_row2_col0, #T_8a9c8_row2_col1, #T_8a9c8_row2_col2, #T_8a9c8_row2_col3, #T_8a9c8_row2_col4, #T_8a9c8_row2_col5, #T_8a9c8_row2_col6, #T_8a9c8_row2_col7, #T_8a9c8_row2_col8, #T_8a9c8_row2_col9, #T_8a9c8_row2_col10, #T_8a9c8_row2_col11, #T_8a9c8_row2_col12, #T_8a9c8_row3_col0, #T_8a9c8_row3_col1, #T_8a9c8_row3_col2, #T_8a9c8_row3_col3, #T_8a9c8_row3_col4, #T_8a9c8_row3_col5, #T_8a9c8_row3_col6, #T_8a9c8_row3_col7, #T_8a9c8_row3_col8, #T_8a9c8_row3_col9, #T_8a9c8_row3_col10, #T_8a9c8_row3_col11, #T_8a9c8_row3_col12, #T_8a9c8_row4_col0, #T_8a9c8_row4_col1, #T_8a9c8_row4_col2, #T_8a9c8_row4_col3, #T_8a9c8_row4_col4, #T_8a9c8_row4_col5, #T_8a9c8_row4_col6, #T_8a9c8_row4_col7, #T_8a9c8_row4_col8, #T_8a9c8_row4_col9, #T_8a9c8_row4_col10, #T_8a9c8_row4_col11, #T_8a9c8_row4_col12, #T_8a9c8_row5_col0, #T_8a9c8_row5_col1, #T_8a9c8_row5_col2, #T_8a9c8_row5_col3, #T_8a9c8_row5_col4, #T_8a9c8_row5_col5, #T_8a9c8_row5_col6, #T_8a9c8_row5_col7, #T_8a9c8_row5_col8, #T_8a9c8_row5_col9, #T_8a9c8_row5_col10, #T_8a9c8_row5_col11, #T_8a9c8_row5_col12, #T_8a9c8_row6_col0, #T_8a9c8_row6_col1, #T_8a9c8_row6_col2, #T_8a9c8_row6_col3, #T_8a9c8_row6_col4, #T_8a9c8_row6_col5, #T_8a9c8_row6_col6, #T_8a9c8_row6_col7, #T_8a9c8_row6_col8, #T_8a9c8_row6_col9, #T_8a9c8_row6_col10, #T_8a9c8_row6_col11, #T_8a9c8_row6_col12, #T_8a9c8_row7_col0, #T_8a9c8_row7_col1, #T_8a9c8_row7_col2, #T_8a9c8_row7_col3, #T_8a9c8_row7_col4, #T_8a9c8_row7_col5, #T_8a9c8_row7_col6, #T_8a9c8_row7_col7, #T_8a9c8_row7_col8, #T_8a9c8_row7_col9, #T_8a9c8_row7_col10, #T_8a9c8_row7_col11, #T_8a9c8_row7_col12, #T_8a9c8_row8_col0, #T_8a9c8_row8_col1, #T_8a9c8_row8_col2, #T_8a9c8_row8_col3, #T_8a9c8_row8_col4, #T_8a9c8_row8_col5, #T_8a9c8_row8_col6, #T_8a9c8_row8_col7, #T_8a9c8_row8_col8, #T_8a9c8_row8_col9, #T_8a9c8_row8_col10, #T_8a9c8_row8_col11, #T_8a9c8_row8_col12, #T_8a9c8_row9_col0, #T_8a9c8_row9_col1, #T_8a9c8_row9_col2, #T_8a9c8_row9_col3, #T_8a9c8_row9_col4, #T_8a9c8_row9_col5, #T_8a9c8_row9_col6, #T_8a9c8_row9_col7, #T_8a9c8_row9_col8, #T_8a9c8_row9_col9, #T_8a9c8_row9_col10, #T_8a9c8_row9_col11, #T_8a9c8_row9_col12, #T_8a9c8_row10_col0, #T_8a9c8_row10_col1, #T_8a9c8_row10_col2, #T_8a9c8_row10_col3, #T_8a9c8_row10_col4, #T_8a9c8_row10_col5, #T_8a9c8_row10_col6, #T_8a9c8_row10_col7, #T_8a9c8_row10_col8, #T_8a9c8_row10_col9, #T_8a9c8_row10_col10, #T_8a9c8_row10_col11, #T_8a9c8_row10_col12, #T_8a9c8_row11_col0, #T_8a9c8_row11_col1, #T_8a9c8_row11_col2, #T_8a9c8_row11_col3, #T_8a9c8_row11_col4, #T_8a9c8_row11_col5, #T_8a9c8_row11_col6, #T_8a9c8_row11_col7, #T_8a9c8_row11_col8, #T_8a9c8_row11_col9, #T_8a9c8_row11_col10, #T_8a9c8_row11_col11, #T_8a9c8_row11_col12 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_8a9c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a9c8_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_8a9c8_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_8a9c8_level0_col2" class="col_heading level0 col2" >list</th>
#       <th id="T_8a9c8_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_8a9c8_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_8a9c8_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_8a9c8_level0_col6" class="col_heading level0 col6" >CT</th>
#       <th id="T_8a9c8_level0_col7" class="col_heading level0 col7" >ET</th>
#       <th id="T_8a9c8_level0_col8" class="col_heading level0 col8" >L1_dcache_miss_rate</th>
#       <th id="T_8a9c8_level0_col9" class="col_heading level0 col9" >L1_dcache_misses</th>
#       <th id="T_8a9c8_level0_col10" class="col_heading level0 col10" >L1_dcache_accesses</th>
#       <th id="T_8a9c8_level0_col11" class="col_heading level0 col11" >branches</th>
#       <th id="T_8a9c8_level0_col12" class="col_heading level0 col12" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a9c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a9c8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8a9c8_row0_col1" class="data row0 col1" >1024</td>
#       <td id="T_8a9c8_row0_col2" class="data row0 col2" >array</td>
#       <td id="T_8a9c8_row0_col3" class="data row0 col3" >514311433</td>
#       <td id="T_8a9c8_row0_col4" class="data row0 col4" >106354446</td>
#       <td id="T_8a9c8_row0_col5" class="data row0 col5" >0.206790</td>
#       <td id="T_8a9c8_row0_col6" class="data row0 col6" >0.239191</td>
#       <td id="T_8a9c8_row0_col7" class="data row0 col7" >0.025439</td>
#       <td id="T_8a9c8_row0_col8" class="data row0 col8" >0.000019</td>
#       <td id="T_8a9c8_row0_col9" class="data row0 col9" >1952</td>
#       <td id="T_8a9c8_row0_col10" class="data row0 col10" >102785455</td>
#       <td id="T_8a9c8_row0_col11" class="data row0 col11" >102934900</td>
#       <td id="T_8a9c8_row0_col12" class="data row0 col12" >100666</td>
#     </tr>
#     <tr>
#       <th id="T_8a9c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a9c8_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_8a9c8_row1_col1" class="data row1 col1" >1024</td>
#       <td id="T_8a9c8_row1_col2" class="data row1 col2" >list</td>
#       <td id="T_8a9c8_row1_col3" class="data row1 col3" >411925737</td>
#       <td id="T_8a9c8_row1_col4" class="data row1 col4" >516135403</td>
#       <td id="T_8a9c8_row1_col5" class="data row1 col5" >1.252982</td>
#       <td id="T_8a9c8_row1_col6" class="data row1 col6" >0.205504</td>
#       <td id="T_8a9c8_row1_col7" class="data row1 col7" >0.106068</td>
#       <td id="T_8a9c8_row1_col8" class="data row1 col8" >0.000071</td>
#       <td id="T_8a9c8_row1_col9" class="data row1 col9" >7368</td>
#       <td id="T_8a9c8_row1_col10" class="data row1 col10" >103069190</td>
#       <td id="T_8a9c8_row1_col11" class="data row1 col11" >103153628</td>
#       <td id="T_8a9c8_row1_col12" class="data row1 col12" >101686</td>
#     </tr>
#     <tr>
#       <th id="T_8a9c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a9c8_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_8a9c8_row2_col1" class="data row2 col1" >4096</td>
#       <td id="T_8a9c8_row2_col2" class="data row2 col2" >array</td>
#       <td id="T_8a9c8_row2_col3" class="data row2 col3" >2050732957</td>
#       <td id="T_8a9c8_row2_col4" class="data row2 col4" >414860986</td>
#       <td id="T_8a9c8_row2_col5" class="data row2 col5" >0.202299</td>
#       <td id="T_8a9c8_row2_col6" class="data row2 col6" >0.208995</td>
#       <td id="T_8a9c8_row2_col7" class="data row2 col7" >0.086704</td>
#       <td id="T_8a9c8_row2_col8" class="data row2 col8" >0.250980</td>
#       <td id="T_8a9c8_row2_col9" class="data row2 col9" >102939857</td>
#       <td id="T_8a9c8_row2_col10" class="data row2 col10" >410151754</td>
#       <td id="T_8a9c8_row2_col11" class="data row2 col11" >410205601</td>
#       <td id="T_8a9c8_row2_col12" class="data row2 col12" >101169</td>
#     </tr>
#     <tr>
#       <th id="T_8a9c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8a9c8_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_8a9c8_row3_col1" class="data row3 col1" >4096</td>
#       <td id="T_8a9c8_row3_col2" class="data row3 col2" >list</td>
#       <td id="T_8a9c8_row3_col3" class="data row3 col3" >1644955414</td>
#       <td id="T_8a9c8_row3_col4" class="data row3 col4" >3568796280</td>
#       <td id="T_8a9c8_row3_col5" class="data row3 col5" >2.169540</td>
#       <td id="T_8a9c8_row3_c

# %%
! make -C linked_list clean ; make -C linked_list
#! echo "size,list,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "4096,array," >> stats.csv
! linked_list/linked_list 4096 0 100000
! echo -n "4096,list," >> stats.csv
! linked_list/linked_list 4096 1 100000
# Out:
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# rm -f linked_list linked_list.s
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# cc -c -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H perfstats.c
# cc -c -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.c
# cc -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.o perfstats.o  linked_list_main.c -o linked_list
# cc -S -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.c
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# depth: 4096
# depth: 4096

# %%
display_df_mono(render_csv("stats.csv"))
# Out:
# <style type="text/css">
# #T_043cc_row0_col0, #T_043cc_row0_col1, #T_043cc_row0_col2, #T_043cc_row0_col3, #T_043cc_row0_col4, #T_043cc_row0_col5, #T_043cc_row0_col6, #T_043cc_row0_col7, #T_043cc_row0_col8, #T_043cc_row0_col9, #T_043cc_row0_col10, #T_043cc_row0_col11, #T_043cc_row0_col12, #T_043cc_row1_col0, #T_043cc_row1_col1, #T_043cc_row1_col2, #T_043cc_row1_col3, #T_043cc_row1_col4, #T_043cc_row1_col5, #T_043cc_row1_col6, #T_043cc_row1_col7, #T_043cc_row1_col8, #T_043cc_row1_col9, #T_043cc_row1_col10, #T_043cc_row1_col11, #T_043cc_row1_col12, #T_043cc_row2_col0, #T_043cc_row2_col1, #T_043cc_row2_col2, #T_043cc_row2_col3, #T_043cc_row2_col4, #T_043cc_row2_col5, #T_043cc_row2_col6, #T_043cc_row2_col7, #T_043cc_row2_col8, #T_043cc_row2_col9, #T_043cc_row2_col10, #T_043cc_row2_col11, #T_043cc_row2_col12, #T_043cc_row3_col0, #T_043cc_row3_col1, #T_043cc_row3_col2, #T_043cc_row3_col3, #T_043cc_row3_col4, #T_043cc_row3_col5, #T_043cc_row3_col6, #T_043cc_row3_col7, #T_043cc_row3_col8, #T_043cc_row3_col9, #T_043cc_row3_col10, #T_043cc_row3_col11, #T_043cc_row3_col12 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_043cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_043cc_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_043cc_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_043cc_level0_col2" class="col_heading level0 col2" >list</th>
#       <th id="T_043cc_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_043cc_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_043cc_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_043cc_level0_col6" class="col_heading level0 col6" >CT</th>
#       <th id="T_043cc_level0_col7" class="col_heading level0 col7" >ET</th>
#       <th id="T_043cc_level0_col8" class="col_heading level0 col8" >L1_dcache_miss_rate</th>
#       <th id="T_043cc_level0_col9" class="col_heading level0 col9" >L1_dcache_misses</th>
#       <th id="T_043cc_level0_col10" class="col_heading level0 col10" >L1_dcache_accesses</th>
#       <th id="T_043cc_level0_col11" class="col_heading level0 col11" >branches</th>
#       <th id="T_043cc_level0_col12" class="col_heading level0 col12" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_043cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_043cc_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_043cc_row0_col1" class="data row0 col1" >1024</td>
#       <td id="T_043cc_row0_col2" class="data row0 col2" >array</td>
#       <td id="T_043cc_row0_col3" class="data row0 col3" >514310607</td>
#       <td id="T_043cc_row0_col4" class="data row0 col4" >106362204</td>
#       <td id="T_043cc_row0_col5" class="data row0 col5" >0.206805</td>
#       <td id="T_043cc_row0_col6" class="data row0 col6" >0.246911</td>
#       <td id="T_043cc_row0_col7" class="data row0 col7" >0.026262</td>
#       <td id="T_043cc_row0_col8" class="data row0 col8" >0.000020</td>
#       <td id="T_043cc_row0_col9" class="data row0 col9" >2068</td>
#       <td id="T_043cc_row0_col10" class="data row0 col10" >102784551</td>
#       <td id="T_043cc_row0_col11" class="data row0 col11" >102934944</td>
#       <td id="T_043cc_row0_col12" class="data row0 col12" >100620</td>
#     </tr>
#     <tr>
#       <th id="T_043cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_043cc_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_043cc_row1_col1" class="data row1 col1" >1024</td>
#       <td id="T_043cc_row1_col2" class="data row1 col2" >list</td>
#       <td id="T_043cc_row1_col3" class="data row1 col3" >411945709</td>
#       <td id="T_043cc_row1_col4" class="data row1 col4" >516211638</td>
#       <td id="T_043cc_row1_col5" class="data row1 col5" >1.253106</td>
#       <td id="T_043cc_row1_col6" class="data row1 col6" >0.205557</td>
#       <td id="T_043cc_row1_col7" class="data row1 col7" >0.106111</td>
#       <td id="T_043cc_row1_col8" class="data row1 col8" >0.000078</td>
#       <td id="T_043cc_row1_col9" class="data row1 col9" >8068</td>
#       <td id="T_043cc_row1_col10" class="data row1 col10" >103077382</td>
#       <td id="T_043cc_row1_col11" class="data row1 col11" >103156326</td>
#       <td id="T_043cc_row1_col12" class="data row1 col12" >101768</td>
#     </tr>
#     <tr>
#       <th id="T_043cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_043cc_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_043cc_row2_col1" class="data row2 col1" >4096</td>
#       <td id="T_043cc_row2_col2" class="data row2 col2" >array</td>
#       <td id="T_043cc_row2_col3" class="data row2 col3" >2050794513</td>
#       <td id="T_043cc_row2_col4" class="data row2 col4" >414976483</td>
#       <td id="T_043cc_row2_col5" class="data row2 col5" >0.202349</td>
#       <td id="T_043cc_row2_col6" class="data row2 col6" >0.209556</td>
#       <td id="T_043cc_row2_col7" class="data row2 col7" >0.086961</td>
#       <td id="T_043cc_row2_col8" class="data row2 col8" >0.251211</td>
#       <td id="T_043cc_row2_col9" class="data row2 col9" >103039632</td>
#       <td id="T_043cc_row2_col10" class="data row2 col10" >410172273</td>
#       <td id="T_043cc_row2_col11" class="data row2 col11" >410216092</td>
#       <td id="T_043cc_row2_col12" class="data row2 col12" >101403</td>
#     </tr>
#     <tr>
#       <th id="T_043cc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_043cc_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_043cc_row3_col1" class="data row3 col1" >4096</td>
#       <td id="T_043cc_row3_col2" class="data row3 col2" >list</td>
#       <td id="T_043cc_row3_col3" class="data row3 col3" >1646311345</td>
#       <td id="T_043cc_row3_col4" class="data row3 col4" >3570041352</td>
#       <td id="T_043cc_row3_col5" class="data row3 col5" >2.168509</td>
#       <td id="T_043cc_row3_col6" class="data row3 col6" >0.198134</td>
#       <td id="T_043cc_row3_col7" class="data row3 col7" >0.707345</td>
#       <td id="T_043cc_row3_col8" class="data row3 col8" >0.334065</td>
#       <td id="T_043cc_row3_col9" class="data row3 col9" >137803671</td>
#       <td id="T_043cc_row3_col10" class="data row3 col10" >412504984</td>
#       <td id="T_043cc_row3_col11" class="data row3 col11" >411271724</td>
#       <td id="T_043cc_row3_col12" class="data row3 col12" >107455</td>
#     </tr>
#   </tbody>
# </table>

# %%
! make -C linked_list clean ; make -C linked_list
#! echo "size,list,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "8192,array," >> stats.csv
! linked_list/linked_list 8192 0 100000
! echo -n "8192,list," >> stats.csv
! linked_list/linked_list 8192 1 100000
display_df_mono(render_csv("stats.csv"))
# Out:
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# rm -f linked_list linked_list.s
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# cc -c -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H perfstats.c
# cc -c -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.c
# cc -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.o perfstats.o  linked_list_main.c -o linked_list
# cc -S -O1 -w -mno-avx -Wno-implicit-function-declaration -Wno-format-zero-length -DHAVE_LINUX_PERF_EVENT_H linked_list.c
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/linked_list'
# depth: 8192
# depth: 8192
# <style type="text/css">
# #T_b014b_row0_col0, #T_b014b_row0_col1, #T_b014b_row0_col2, #T_b014b_row0_col3, #T_b014b_row0_col4, #T_b014b_row0_col5, #T_b014b_row0_col6, #T_b014b_row0_col7, #T_b014b_row0_col8, #T_b014b_row0_col9, #T_b014b_row0_col10, #T_b014b_row0_col11, #T_b014b_row0_col12, #T_b014b_row1_col0, #T_b014b_row1_col1, #T_b014b_row1_col2, #T_b014b_row1_col3, #T_b014b_row1_col4, #T_b014b_row1_col5, #T_b014b_row1_col6, #T_b014b_row1_col7, #T_b014b_row1_col8, #T_b014b_row1_col9, #T_b014b_row1_col10, #T_b014b_row1_col11, #T_b014b_row1_col12, #T_b014b_row2_col0, #T_b014b_row2_col1, #T_b014b_row2_col2, #T_b014b_row2_col3, #T_b014b_row2_col4, #T_b014b_row2_col5, #T_b014b_row2_col6, #T_b014b_row2_col7, #T_b014b_row2_col8, #T_b014b_row2_col9, #T_b014b_row2_col10, #T_b014b_row2_col11, #T_b014b_row2_col12, #T_b014b_row3_col0, #T_b014b_row3_col1, #T_b014b_row3_col2, #T_b014b_row3_col3, #T_b014b_row3_col4, #T_b014b_row3_col5, #T_b014b_row3_col6, #T_b014b_row3_col7, #T_b014b_row3_col8, #T_b014b_row3_col9, #T_b014b_row3_col10, #T_b014b_row3_col11, #T_b014b_row3_col12, #T_b014b_row4_col0, #T_b014b_row4_col1, #T_b014b_row4_col2, #T_b014b_row4_col3, #T_b014b_row4_col4, #T_b014b_row4_col5, #T_b014b_row4_col6, #T_b014b_row4_col7, #T_b014b_row4_col8, #T_b014b_row4_col9, #T_b014b_row4_col10, #T_b014b_row4_col11, #T_b014b_row4_col12, #T_b014b_row5_col0, #T_b014b_row5_col1, #T_b014b_row5_col2, #T_b014b_row5_col3, #T_b014b_row5_col4, #T_b014b_row5_col5, #T_b014b_row5_col6, #T_b014b_row5_col7, #T_b014b_row5_col8, #T_b014b_row5_col9, #T_b014b_row5_col10, #T_b014b_row5_col11, #T_b014b_row5_col12 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_b014b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b014b_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_b014b_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_b014b_level0_col2" class="col_heading level0 col2" >list</th>
#       <th id="T_b014b_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_b014b_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_b014b_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_b014b_level0_col6" class="col_heading level0 col6" >CT</th>
#       <th id="T_b014b_level0_col7" class="col_heading level0 col7" >ET</th>
#       <th id="T_b014b_level0_col8" class="col_heading level0 col8" >L1_dcache_miss_rate</th>
#       <th id="T_b014b_level0_col9" class="col_heading level0 col9" >L1_dcache_misses</th>
#       <th id="T_b014b_level0_col10" class="col_heading level0 col10" >L1_dcache_accesses</th>
#       <th id="T_b014b_level0_col11" class="col_heading level0 col11" >branches</th>
#       <th id="T_b014b_level0_col12" class="col_heading level0 col12" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b014b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b014b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b014b_row0_col1" class="data row0 col1" >1024</td>
#       <td id="T_b014b_row0_col2" class="data row0 col2" >array</td>
#       <td id="T_b014b_row0_col3" class="data row0 col3" >514310607</td>
#       <td id="T_b014b_row0_col4" class="data row0 col4" >106362204</td>
#       <td id="T_b014b_row0_col5" class="data row0 col5" >0.206805</td>
#       <td id="T_b014b_row0_col6" class="data row0 col6" >0.246911</td>
#       <td id="T_b014b_row0_col7" class="data row0 col7" >0.026262</td>
#       <td id="T_b014b_row0_col8" class="data row0 col8" >0.000020</td>
#       <td id="T_b014b_row0_col9" class="data row0 col9" >2068</td>
#       <td id="T_b014b_row0_col10" class="data row0 col10" >102784551</td>
#       <td id="T_b014b_row0_col11" class="data row0 col11" >102934944</td>
#       <td id="T_b014b_row0_col12" class="data row0 col12" >100620</td>
#     </tr>
#     <tr>
#       <th id="T_b014b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b014b_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b014b_row1_col1" class="data row1 col1" >1024</td>
#       <td id="T_b014b_row1_col2" class="data row1 col2" >list</td>
#       <td id="T_b014b_row1_col3" class="data row1 col3" >411945709</td>
#       <td id="T_b014b_row1_col4" class="data row1 col4" >516211638</td>
#       <td id="T_b014b_row1_col5" class="data row1 col5" >1.253106</td>
#       <td id="T_b014b_row1_col6" class="data row1 col6" >0.205557</td>
#       <td id="T_b014b_row1_col7" class="data row1 col7" >0.106111</td>
#       <td id="T_b014b_row1_col8" class="data row1 col8" >0.000078</td>
#       <td id="T_b014b_row1_col9" class="data row1 col9" >8068</td>
#       <td id="T_b014b_row1_col10" class="data row1 col10" >103077382</td>
#       <td id="T_b014b_row1_col11" class="data row1 col11" >103156326</td>
#       <td id="T_b014b_row1_col12" class="data row1 col12" >101768</td>
#     </tr>
#     <tr>
#       <th id="T_b014b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b014b_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_b014b_row2_col1" class="data row2 col1" >4096</td>
#       <td id="T_b014b_row2_col2" class="data row2 col2" >array</td>
#       <td id="T_b014b_row2_col3" class="data row2 col3" >2050794513</td>
#       <td id="T_b014b_row2_col4" class="data row2 col4" >414976483</td>
#       <td id="T_b014b_row2_col5" class="data row2 col5" >0.202349</td>
#       <td id="T_b014b_row2_col6" class="data row2 col6" >0.209556</td>
#       <td id="T_b014b_row2_col7" class="data row2 col7" >0.086961</td>
#       <td id="T_b014b_row2_col8" class="data row2 col8" >0.251211</td>
#       <td id="T_b014b_row2_col9" class="data row2 col9" >103039632</td>
#       <td id="T_b014b_row2_col10" class="data row2 col10" >410172273</td>
#       <td id="T_b014b_row2_col11" class="data row2 col11" >410216092</td>
#       <td id="T_b014b_row2_col12" class="data row2 col12" >101403</td>
#     </tr>
#     <tr>
#       <th id="T_b014b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b014b_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_b014b_row3_col1" class="data row3 col1" >4096</td>
#       <td id="T_b014b_row3_col2" class="data row3 col2" >list</td>
#       <td id="T_b014b_row3_col3" class="data row3 col3" >1646311345</td>
#       <td id="T_b014b_row3_col4" class="data row3 col4" >3570041352</td>
#       <td id="T_b014b_row3_col5" class="data row3 col5" >2.168509</td>
#       <td id="T_b014b_row3_col6" class="data row3 col6" >0.198134</td>
#       <td id="T_b014b_row3_col7" class="data row3 col7" >0.707345</td>
#       <td id="T_b014b_row3_col8" class="data row3 col8" >0.334065</td>
#       <td id="T_b014b_row3_col9" class="data row3 col9" >137803671</td>
#       <td id="T_b014b_row3_col10" class="data row3 col10" >412504984</td>
#       <td id="T_b014b_row3_col11" class="data row3 col11" >411271724</td>
#       <td id="T_b014b_row3_col12" class="data row3 col12" >107455</td>
#     </tr>
#     <tr>
#       <th id="T_b014b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b014b_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_b014b_row4_col1" class="data row4 col1" >8192</td>
#       <td id="T_b014b_row4_col2" class="data row4 col2" >array</td>
#       <td id="T_b014b_row4_col3" class="data row4 col3" >4100205521</td>
#       <td id="T_b014b_row4_col4" class="data row4 col4" >826257910</td>
#       <td id="T_b014b_row4_col5" class="data row4 col5" >0.201516</td>
#       <td id="T_b014b_row4_col6" class="data row4 col6" >0.208046</td>
#       <td id="T_b014b_row4_col7" class="data row4 col7" >0.171900</td>
#       <td id="T_b014b_row4_col8" class="data row4 col8" >0.250361</td>
#       <td id="T_b014b_row4_col9" class="data row4 col9" >205384808</td>
#       <td id="T_b014b_row4_col10" class="data row4 col10" >820355581</td>
#       <td id="T_b014b_row4_col11" class="data row4 col11" >820036451</td>
#       <td id="T_b014b_row4_col12" class="data row4 col12" >102964</td>
#     </tr>
#     <tr>
#       <th id="T_b014b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b014b

# %%
! make -C bst clean ; make EXTRA_OPTS=-O1 -C bst
#! echo "size,list,IC,Cycles,CPI,CT,ET,L1_dcache_miss_rate,L1_dcache_misses,L1_dcache_accesses,branches,branch_misses" > stats.csv
! echo -n "1024,bst," >> stats.csv
! bst/bstSearch 1024 100000 1
! echo -n "4096,bst," >> stats.csv
! bst/bstSearch 4096 100000 1
! echo -n "8192,bst," >> stats.csv
! bst/bstSearch 8192 100000 0
display_df_mono(render_csv("stats.csv"))
# Out:
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/bst'
# rm -f bstSearch *.o
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/bst'
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/bst'
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O1 -I/nfshome/htseng/courses/CS203/demo/OoO_programming  -o bst.o -c bst.c
# gcc -g -DHAVE_LINUX_PERF_EVENT_H -O1 -I/nfshome/htseng/courses/CS203/demo/OoO_programming  -o perfstats.o -c perfstats.c
# perfstats.c: In function ‘change_cpufrequnecy’:
# perfstats.c:115:11: warning: implicit declaration of function ‘sched_getcpu’; did you mean ‘SYS_getcpu’? [-Wimplicit-function-declaration]
#   115 |     cpu = sched_getcpu();
#       |           ^~~~~~~~~~~~
#       |           SYS_getcpu
# g++ -O3 -DHAVE_LINUX_PERF_EVENT_H -O1 bstSearch.cpp perfstats.o bst.o -o bstSearch
# bstSearch.cpp: In function ‘int main(int, char**)’:
# bstSearch.cpp:52:22: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#    52 |     sprintf(preamble,"");
#       |                      ^~
# /bin/ld: /tmp/ccz6sI5X.o: in function `main':
# bstSearch.cpp:(.text+0x108): undefined reference to `insert(Node**, long)'
# /bin/ld: bstSearch.cpp:(.text+0x149): undefined reference to `inorderTraversal(Node*)'
# collect2: error: ld returned 1 exit status
# make: *** [Makefile:11: bstSearch] Error 1
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/OoO_programming/bst'
# /bin/bash: line 1: bst/bstSearch: No such file or directory
# /bin/bash: line 1: bst/bstSearch: No such file or directory
# /bin/bash: line 1: bst/bstSearch: No such file or directory
# <style type="text/css">
# #T_09ed0_row0_col0, #T_09ed0_row0_col1, #T_09ed0_row0_col2, #T_09ed0_row0_col3, #T_09ed0_row0_col4, #T_09ed0_row0_col5, #T_09ed0_row0_col6, #T_09ed0_row0_col7, #T_09ed0_row0_col8, #T_09ed0_row0_col9, #T_09ed0_row0_col10, #T_09ed0_row0_col11, #T_09ed0_row0_col12, #T_09ed0_row1_col0, #T_09ed0_row1_col1, #T_09ed0_row1_col2, #T_09ed0_row1_col3, #T_09ed0_row1_col4, #T_09ed0_row1_col5, #T_09ed0_row1_col6, #T_09ed0_row1_col7, #T_09ed0_row1_col8, #T_09ed0_row1_col9, #T_09ed0_row1_col10, #T_09ed0_row1_col11, #T_09ed0_row1_col12, #T_09ed0_row2_col0, #T_09ed0_row2_col1, #T_09ed0_row2_col2, #T_09ed0_row2_col3, #T_09ed0_row2_col4, #T_09ed0_row2_col5, #T_09ed0_row2_col6, #T_09ed0_row2_col7, #T_09ed0_row2_col8, #T_09ed0_row2_col9, #T_09ed0_row2_col10, #T_09ed0_row2_col11, #T_09ed0_row2_col12, #T_09ed0_row3_col0, #T_09ed0_row3_col1, #T_09ed0_row3_col2, #T_09ed0_row3_col3, #T_09ed0_row3_col4, #T_09ed0_row3_col5, #T_09ed0_row3_col6, #T_09ed0_row3_col7, #T_09ed0_row3_col8, #T_09ed0_row3_col9, #T_09ed0_row3_col10, #T_09ed0_row3_col11, #T_09ed0_row3_col12, #T_09ed0_row4_col0, #T_09ed0_row4_col1, #T_09ed0_row4_col2, #T_09ed0_row4_col3, #T_09ed0_row4_col4, #T_09ed0_row4_col5, #T_09ed0_row4_col6, #T_09ed0_row4_col7, #T_09ed0_row4_col8, #T_09ed0_row4_col9, #T_09ed0_row4_col10, #T_09ed0_row4_col11, #T_09ed0_row4_col12, #T_09ed0_row5_col0, #T_09ed0_row5_col1, #T_09ed0_row5_col2, #T_09ed0_row5_col3, #T_09ed0_row5_col4, #T_09ed0_row5_col5, #T_09ed0_row5_col6, #T_09ed0_row5_col7, #T_09ed0_row5_col8, #T_09ed0_row5_col9, #T_09ed0_row5_col10, #T_09ed0_row5_col11, #T_09ed0_row5_col12, #T_09ed0_row6_col0, #T_09ed0_row6_col1, #T_09ed0_row6_col2, #T_09ed0_row6_col3, #T_09ed0_row6_col4, #T_09ed0_row6_col5, #T_09ed0_row6_col6, #T_09ed0_row6_col7, #T_09ed0_row6_col8, #T_09ed0_row6_col9, #T_09ed0_row6_col10, #T_09ed0_row6_col11, #T_09ed0_row6_col12 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_09ed0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09ed0_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_09ed0_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_09ed0_level0_col2" class="col_heading level0 col2" >list</th>
#       <th id="T_09ed0_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_09ed0_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_09ed0_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_09ed0_level0_col6" class="col_heading level0 col6" >CT</th>
#       <th id="T_09ed0_level0_col7" class="col_heading level0 col7" >ET</th>
#       <th id="T_09ed0_level0_col8" class="col_heading level0 col8" >L1_dcache_miss_rate</th>
#       <th id="T_09ed0_level0_col9" class="col_heading level0 col9" >L1_dcache_misses</th>
#       <th id="T_09ed0_level0_col10" class="col_heading level0 col10" >L1_dcache_accesses</th>
#       <th id="T_09ed0_level0_col11" class="col_heading level0 col11" >branches</th>
#       <th id="T_09ed0_level0_col12" class="col_heading level0 col12" >branch_misses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09ed0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_09ed0_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_09ed0_row0_col1" class="data row0 col1" >1024</td>
#       <td id="T_09ed0_row0_col2" class="data row0 col2" >array</td>
#       <td id="T_09ed0_row0_col3" class="data row0 col3" >514310607</td>
#       <td id="T_09ed0_row0_col4" class="data row0 col4" >106362204</td>
#       <td id="T_09ed0_row0_col5" class="data row0 col5" >0.206805</td>
#       <td id="T_09ed0_row0_col6" class="data row0 col6" >0.246911</td>
#       <td id="T_09ed0_row0_col7" class="data row0 col7" >0.026262</td>
#       <td id="T_09ed0_row0_col8" class="data row0 col8" >0.000020</td>
#       <td id="T_09ed0_row0_col9" class="data row0 col9" >2068.000000</td>
#       <td id="T_09ed0_row0_col10" class="data row0 col10" >102784551.000000</td>
#       <td id="T_09ed0_row0_col11" class="data row0 col11" >102934944.000000</td>
#       <td id="T_09ed0_row0_col12" class="data row0 col12" >100620.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09ed0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_09ed0_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_09ed0_row1_col1" class="data row1 col1" >1024</td>
#       <td id="T_09ed0_row1_col2" class="data row1 col2" >list</td>
#       <td id="T_09ed0_row1_col3" class="data row1 col3" >411945709</td>
#       <td id="T_09ed0_row1_col4" class="data row1 col4" >516211638</td>
#       <td id="T_09ed0_row1_col5" class="data row1 col5" >1.253106</td>
#       <td id="T_09ed0_row1_col6" class="data row1 col6" >0.205557</td>
#       <td id="T_09ed0_row1_col7" class="data row1 col7" >0.106111</td>
#       <td id="T_09ed0_row1_col8" class="data row1 col8" >0.000078</td>
#       <td id="T_09ed0_row1_col9" class="data row1 col9" >8068.000000</td>
#       <td id="T_09ed0_row1_col10" class="data row1 col10" >103077382.000000</td>
#       <td id="T_09ed0_row1_col11" class="data row1 col11" >103156326.000000</td>
#       <td id="T_09ed0_row1_col12" class="data row1 col12" >101768.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09ed0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_09ed0_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_09ed0_row2_col1" class="data row2 col1" >4096</td>
#       <td id="T_09ed0_row2_col2" class="data row2 col2" >array</td>
#       <td id="T_09ed0_row2_col3" class="data row2 col3" >2050794513</td>
#       <td id="T_09ed0_row2_col4" class="data row2 col4" >414976483</td>
#       <td id="T_09ed0_row2_col5" class="data row2 col5" >0.202349</td>
#       <td id="T_09ed0_row2_col6" class="data row2 col6" >0.209556</td>
#       <td id="T_09ed0_row2_col7" class="data row2 col7" >0.086961</td>
#       <td id="T_09ed0_row2_col8" class="data row2 col8" >0.251211</td>
#       <td id="T_09ed0_row2_col9" class="data row2 col9" >103039632.000000</td>
#       <td id="T_09ed0_row2_col10" class="data row2 col10" >410172273.000000</td>
#       <td id="T_09ed0_row2_col11" class="data row2 col11" >410216092.000000</td>
#       <td id="T_09ed0_row2_col12" class="data row2 col12" >101403.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09ed0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_09ed0_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_09ed0_row3_col1" class="data row3 col1" >4096</td>
#       <td id="T_09ed0_row3_col2" class="data row3 col2" >list</td>
#       <td id="T_09ed0_row3_col3" class="data row3 col3" >1646311345</td>
#       <td id="T_09ed0_row3_col4" class="data row3 col4" >3570041352</td>
#       <td id="T_09ed0_row3_col5" class="data row3 col5" >2.168509</td>
#       <td id="T_09ed0_row3_col6" class="data row3 col6" >0.198134</td>
#       <td id="T_09ed0_row3_col7" class="data row3 col7" >0.707345</td>
#       <td id="T_09ed0_row3_col8" class="data row3 col8" >0.334065</td>
#       <td id="T_09ed0_row3_col9" class="data row3 col9" >137803671.000000</td>
#       <td id="T_09ed0_row3_col10" class="data row3 col10" >412504984.000000</td>
#       <td id="T_09ed0_row3_col11" class="data row3 col11" >411271724.000000</td>
#       <td id="T_09ed0_row3_col12" class="data row3 col12" >107455.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09ed0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_09ed0_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_09ed0_row4_col1" class="data row4 col1" >8192</td>
#       <td id="T_09ed0_row4_col2" class="data row4 col2" >array</td>
#       <td id="T_09ed0_row4_col3" class="data row4 col3" >4100205521</td>
#       <td id="T_09ed0_row4_col4" class="data row4 col4" >826257910</td>
#       <td id="T_09ed0_row4_col5" class="data row4 col5" >0.201516</td>
#       <td id="T_09ed0_row4_col6" class="data row4 col6" >0.208046</td>
#       <td id="T_09ed0_row4_col7" class="data row4 col7" >0.171900</td>
#       <td id="T_09ed0_row4_col8" class="data row4 col8" >0.250361</td>
#       <td id="T_09ed0_row4_col9
