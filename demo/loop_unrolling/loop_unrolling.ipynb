# %%
# %load_ext autoreload
# %autoreload 2
from notebook import *
# if get something about NUMEXPR_MAX_THREADS being set incorrectly, don't worry.  It's not a problem.
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Loop Unrolling

# %%
compare([do_render_code("swap.c", show="swap_array_1"),do_render_code("swap.c", show="swap_array_2")])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# ...

# %%
! gcc -S -O3 swap.c
compare([do_render_code("swap.s",show=["swap_array_1:",".L1:"]),do_render_code("swap.s", show=["swap_array_2:","L20:"])])
#compare([do_render_code("swap.s",show=["swap_array_1:",".L1:"]),do_render_code("swap.s", show=["swap_array_2:","L20:"]),do_render_code("swap.s", show=["L36:","ret"])])
# Out:
# swap.c: In function ‘main’:
# swap.c:60:5: warning: implicit declaration of function ‘perfstats_init’ [-Wimplicit-function-declaration]
#    60 |     perfstats_init();
#       |     ^~~~~~~~~~~~~~
# swap.c:61:5: warning: implicit declaration of function ‘perfstats_enable’ [-Wimplicit-function-declaration]
#    61 |     perfstats_enable(1);
#       |     ^~~~~~~~~~~~~~~~
# swap.c:62:5: warning: implicit declaration of function ‘perfstats_disable’ [-Wimplicit-function-declaration]
#    62 |     perfstats_disable(1);
#       |     ^~~~~~~~~~~~~~~~~
# swap.c:63:5: warning: implicit declaration of function ‘perfstats_print’ [-Wimplicit-function-declaration]
#    63 |     perfstats_print();
#       |     ^~~~~~~~~~~~~~~
# swap.c:64:5: warning: implicit declaration of function ‘perfstats_deinit’ [-Wimplicit-function-declaration]
#    64 |     perfstats_deinit();
#       |     ^~~~~~~~~~~~~~~~
#             <style>
#         .side-by-side {
#             display: flex;
# ...
