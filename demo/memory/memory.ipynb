# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Memory hierarchy

# %% [markdown]
# ## The memory hierarchy of my computer

# %%
# Hung-Wei's Desktop
! lscpu | grep "Model name"
! getconf -a | grep CACHE
# Out:
# Model name:                           13th Gen Intel(R) Core(TM) i7-13700
# LEVEL1_ICACHE_SIZE                 65536
# LEVEL1_ICACHE_ASSOC
# LEVEL1_ICACHE_LINESIZE             64
# LEVEL1_DCACHE_SIZE                 32768
# LEVEL1_DCACHE_ASSOC                8
# LEVEL1_DCACHE_LINESIZE             64
# LEVEL2_CACHE_SIZE                  4194304
# LEVEL2_CACHE_ASSOC                 16
# LEVEL2_CACHE_LINESIZE              64
# LEVEL3_CACHE_SIZE                  31457280
# LEVEL3_CACHE_ASSOC                 12
# LEVEL3_CACHE_LINESIZE              64
# LEVEL4_CACHE_SIZE
# LEVEL4_CACHE_ASSOC
# LEVEL4_CACHE_LINESIZE

# %%
# Hung-Wei's Desktop
! ssh articuno "lscpu | grep 'Model name'; getconf -a | grep CACHE"
# Out:
# Model name:                           Intel(R) Core(TM) i7-14700K
# LEVEL1_ICACHE_SIZE                 65536
# LEVEL1_ICACHE_ASSOC
# LEVEL1_ICACHE_LINESIZE             64
# LEVEL1_DCACHE_SIZE                 32768
# LEVEL1_DCACHE_ASSOC                8
# LEVEL1_DCACHE_LINESIZE             64
# LEVEL2_CACHE_SIZE                  4194304
# LEVEL2_CACHE_ASSOC                 16
# LEVEL2_CACHE_LINESIZE              64
# LEVEL3_CACHE_SIZE                  34603008
# LEVEL3_CACHE_ASSOC                 11
# LEVEL3_CACHE_LINESIZE              64
# LEVEL4_CACHE_SIZE
# LEVEL4_CACHE_ASSOC
# LEVEL4_CACHE_LINESIZE

# %%
# Your CS203 Cluster
! cs203 run "lscpu | grep 'Model name'; getconf -a | grep CACHE"
# Out:
# bash: line 0: cd: /nfshome/htseng/courses/CS203/demo/memory: No such file or directory
# Model name:                           12th Gen Intel(R) Core(TM) i3-12100F
# bash: line 0: cd: /nfshome/htseng/courses/CS203/demo/memory: No such file or directory
# LEVEL1_ICACHE_SIZE                 32768
# LEVEL1_ICACHE_ASSOC                8
# LEVEL1_ICACHE_LINESIZE             64
# LEVEL1_DCACHE_SIZE                 49152
# LEVEL1_DCACHE_ASSOC                12
# LEVEL1_DCACHE_LINESIZE             64
# LEVEL2_CACHE_SIZE                  1310720
# LEVEL2_CACHE_ASSOC                 10
# LEVEL2_CACHE_LINESIZE              64
# LEVEL3_CACHE_SIZE                  12582912
# LEVEL3_CACHE_ASSOC                 12
# LEVEL3_CACHE_LINESIZE              64
# LEVEL4_CACHE_SIZE                  0
# LEVEL4_CACHE_ASSOC                 0
# LEVEL4_CACHE_LINESIZE              0

# %%
# Jetson Nano (NV Tegra X1)
! ssh htseng@nano-4 "lscpu | grep 'Model name'; getconf -a | grep CACHE"
# Out:
# ^C

# %% [markdown]
# ## How much time did I spent on "memory"
#
# Remember our demo long time ago?

# %%
compare([do_render_code("./madd/madd_A.c", lang="c++", show=["//START", "//END"]),do_render_code("./madd/madd_B.c", lang="c++", show=["//START", "//END"])])
# Out:
#             <style>
#         .side-by-side {
#             display: flex;
#             align-items: stretch;
#
#         }
#         .side-by-side-pane {
#             margin-right:1em;
#             border-right-style: solid;
#             border-right-color: black;
#             border-right-width: 1px;
#             flex: 1;
#         }
#         </style>
#         <div class="side-by-side"> <div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #ffffcc }
# .output_html { background: #f8f8f8; }
# .output_html .c { color: #3D7B7B; font-style: italic } /* Comment */
# .output_html .err { border: 1px solid #FF0000 } /* Error */
# .output_html .k { color: #008000; font-weight: bold } /* Keyword */
# .output_html .o { color: #666666 } /* Operator */
# .output_html .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .output_html .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .output_html .cp { color: #9C6500 } /* Comment.Preproc */
# .output_html .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .output_html .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .output_html .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .output_html .gd { color: #A00000 } /* Generic.Deleted */
# .output_html .ge { font-style: italic } /* Generic.Emph */
# .output_html .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .output_html .gr { color: #E40000 } /* Generic.Error */
# .output_html .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .output_html .gi { color: #008400 } /* Generic.Inserted */
# .output_html .go { color: #717171 } /* Generic.Output */
# .output_html .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .output_html .gs { font-weight: bold } /* Generic.Strong */
# .output_html .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .output_html .gt { color: #0044DD } /* Generic.Traceback */
# .output_html .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .output_html .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .output_html .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .output_html .kp { color: #008000 } /* Keyword.Pseudo */
# .output_html .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .output_html .kt { color: #B00040 } /* Keyword.Type */
# .output_html .m { color: #666666 } /* Literal.Number */
# .output_html .s { color: #BA2121 } /* Literal.String */
# .output_html .na { color: #687822 } /* Name.Attribute */
# .output_html .nb { color: #008000 } /* Name.Builtin */
# .output_html .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .output_html .no { color: #880000 } /* Name.Constant */
# .output_html .nd { color: #AA22FF } /* Name.Decorator */
# .output_html .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .output_html .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .output_html .nf { color: #0000FF } /* Name.Function */
# .output_html .nl { color: #767600 } /* Name.Label */
# .output_html .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .output_html .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .output_html .nv { color: #19177C } /* Name.Variable */
# .output_html .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .output_html .w { color: #bbbbbb } /* Text.Whitespace */
# .output_html .mb { color: #666666 } /* Literal.Number.Bin */
# .output_html .mf { color: #666666 } /* Literal.Number.Float */
# .output_html .mh { color: #666666 } /* Literal.Number.Hex */
# .output_html .mi { color: #666666 } /* Literal.Number.Integer */
# .output_html .mo { color: #666666 } /* Literal.Number.Oct */
# .output_html .sa { color: #BA2121 } /* Literal.String.Affix */
# .output_html .sb { color: #BA2121 } /* Literal.String.Backtick */
# .output_html .sc { color: #BA2121 } /* Literal.String.Char */
# .output_html .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .output_html .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .output_html .s2 { color: #BA2121 } /* Literal.String.Double */
# .output_html .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .output_html .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .output_html .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .output_html .sx { color: #008000 } /* Literal.String.Other */
# .output_html .sr { color: #A45A77 } /* Literal.String.Regex */
# .output_html .s1 { color: #BA2121 } /* Literal.String.Single */
# .output_html .ss { color: #19177C } /* Literal.String.Symbol */
# .output_html .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .output_html .fm { color: #0000FF } /* Name.Function.Magic */
# .output_html .vc { color: #19177C } /* Name.Variable.Class */
# .output_html .vg { color: #19177C } /* Name.Variable.Global */
# .output_html .vi { color: #19177C } /* Name.Variable.Instance */
# .output_html .vm { color: #19177C } /* Name.Variable.Magic */
# .output_html .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="c1">// ./madd/madd_A.c:35-43 (9 lines)</span>
# <span class="w">  </span><span class="c1">//START</span>
# <span class="w">    </span><span class="k">for</span><span class="p">(</span><span class="n">i</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="mi">0</span><span class="p">;</span><span class="w"> </span><span class="n">i</span><span class="w"> </span><span class="o">&lt;</span><span class="w"> </span><span class="n">ARRAY_SIZE</span><span class="p">;</span><span class="w"> </span><span class="n">i</span><span class="o">++</span><span class="p">)</span>
# <span class="w">    </span><span class="p">{</span>
# <span class="w">      </span><span class="k">for</span><span class="p">(</span><span class="n">j</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="mi">0</span><span class="p">;</span><span class="w"> </span><span class="n">j</span><span class="w"> </span><span class="o">&lt;</span><span class="w"> </span><span class="n">ARRAY_SIZE</span><span class="p">;</span><span class="w"> </span><span class="n">j</span><span class="o">++</span><span class="p">)</span>
# <span class="w">      </span><span class="p">{</span>
# <span class="w">        </span><span class="n">c</span><span class="p">[</span><span class="n">i</span><span class="p">][</span><span class="n">j</span><span class="p">]</span><span class="w"> </span><span class="o">=</span><span class="w"> </span><span class="n">a</span><span class="p">[</span><span class="n">i</span><span class="p">][</span><span class="n">j</span><span class="p">]</span><span class="o">+</span><span class="n">b</span><span class="p">[</span><span class="n">i</span><span class="p">][</span><span class="n">j</span><span class="p">];</span>
# <span class="w">      </span><span class="p">}</span>
# <span class="w">    </span><span class="p">}</span>
# <span class="w">  </span><span class="c1">//END</span>
# </pre></div>
# </div><div class='side-by-side-pane'><style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .output_html .hll { background-color: #

# %%
render_code("./mv/matvec.c", lang="c++", show=["//I_FIRST_START", "//I_FIRST_END"])
# Out:
# // ./mv/matvec.c:35-49 (15 lines)
#   //I_FIRST_START
#     for(i = 0; i < ARRAY_SIZE; i++)
#     {
#       result = 0.0;
#       for(j = 0; j < ARRAY_SIZE; j++)
#       {
#         result += a[i][j]*b[j];
#         if(dump)
#             printf("&a[%d][%d], %p\n&b[%d], %p\n", i, j, &a[i][j], j, &b[j]);
#       }
#       c[i] = result;
#       if(dump)
#           printf("&c[%d], %p\n", i, &c[i]);
#     }
#   //I_FIRST_END

# %%
! cd mv; make clean; make; ./matvec 16 1 1 >> mv_addresses.csv ; head -n 100 mv_addresses.csv
# Out:
# rm -f matvec
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O3  matvec.c -o matvec
# &a[0][0], 0x55ac54a78330
# &b[0], 0x55ac54a78c30
# &a[0][1], 0x55ac54a78338
# &b[1], 0x55ac54a78c38
# &a[0][2], 0x55ac54a78340
# &b[2], 0x55ac54a78c40
# &a[0][3], 0x55ac54a78348
# &b[3], 0x55ac54a78c48
# &a[0][4], 0x55ac54a78350
# &b[4], 0x55ac54a78c50
# &a[0][5], 0x55ac54a78358
# &b[5], 0x55ac54a78c58
# &a[0][6], 0x55ac54a78360
# &b[6], 0x55ac54a78c60
# &a[0][7], 0x55ac54a78368
# &b[7], 0x55ac54a78c68
# &a[0][8], 0x55ac54a78370
# &b[8], 0x55ac54a78c70
# &a[0][9], 0x55ac54a78378
# &b[9], 0x55ac54a78c78
# &a[0][10], 0x55ac54a78380
# &b[10], 0x55ac54a78c80
# &a[0][11], 0x55ac54a78388
# &b[11], 0x55ac54a78c88
# &a[0][12], 0x55ac54a78390
# &b[12], 0x55ac54a78c90
# &a[0][13], 0x55ac54a78398
# &b[13], 0x55ac54a78c98
# &a[0][14], 0x55ac54a783a0
# &b[14], 0x55ac54a78ca0
# &a[0][15], 0x55ac54a783a8
# &b[15], 0x55ac54a78ca8
# &c[0], 0x55ac54a78cc0
# &a[1][0], 0x55ac54a783c0
# &b[0], 0x55ac54a78c30
# &a[1][1], 0x55ac54a783c8
# &b[1], 0x55ac54a78c38
# &a[1][2], 0x55ac54a783d0
# &b[2], 0x55ac54a78c40
# &a[1][3], 0x55ac54a783d8
# &b[3], 0x55ac54a78c48
# &a[1][4], 0x55ac54a783e0
# &b[4], 0x55ac54a78c50
# &a[1][5], 0x55ac54a783e8
# &b[5], 0x55ac54a78c58
# &a[1][6], 0x55ac54a783f0
# &b[6], 0x55ac54a78c60
# &a[1][7], 0x55ac54a783f8
# &b[7], 0x55ac54a78c68
# &a[1][8], 0x55ac54a78400
# &b[8], 0x55ac54a78c70
# &a[1][9], 0x55ac54a78408
# &b[9], 0x55ac54a78c78
# &a[1][10], 0x55ac54a78410
# &b[10], 0x55ac54a78c80
# &a[1][11], 0x55ac54a78418
# &b[11], 0x55ac54a78c88
# &a[1][12], 0x55ac54a78420
# &b[12], 0x55ac54a78c90
# &a[1][13], 0x55ac54a78428
# &b[13], 0x55ac54a78c98
# &a[1][14], 0x55ac54a78430
# &b[14], 0x55ac54a78ca0
# &a[1][15], 0x55ac54a78438
# &b[15], 0x55ac54a78ca8
# &c[1], 0x55ac54a78cc8
# &a[2][0], 0x55ac54a78450
# &b[0], 0x55ac54a78c30
# &a[2][1], 0x55ac54a78458
# &b[1], 0x55ac54a78c38
# &a[2][2], 0x55ac54a78460
# &b[2], 0x55ac54a78c40
# &a[2][3], 0x55ac54a78468
# &b[3], 0x55ac54a78c48
# &a[2][4], 0x55ac54a78470
# &b[4], 0x55ac54a78c50
# &a[2][5], 0x55ac54a78478
# &b[5], 0x55ac54a78c58
# &a[2][6], 0x55ac54a78480
# &b[6], 0x55ac54a78c60
# &a[2][7], 0x55ac54a78488
# &b[7], 0x55ac54a78c68
# &a[2][8], 0x55ac54a78490
# &b[8], 0x55ac54a78c70
# &a[2][9], 0x55ac54a78498
# &b[9], 0x55ac54a78c78
# &a[2][10], 0x55ac54a784a0
# &b[10], 0x55ac54a78c80
# &a[2][11], 0x55ac54a784a8
# &b[11], 0x55ac54a78c88
# &a[2][12], 0x55ac54a784b0
# &b[12], 0x55ac54a78c90
# &a[2][13], 0x55ac54a784b8
# &b[13], 0x55ac54a78c98
# &a[2][14], 0x55ac54a784c0
# &b[14], 0x55ac54a78ca0
# &a[2][15], 0x55ac54a784c8
# &b[15], 0x55ac54a78ca8
# &c[2], 0x55ac54a78cd0
# &a[3][0], 0x55ac54a784e0

# %%
! cd mv; ./matvec 16 1 0 >> mv_addresses_j_first.csv ; head -n 100 mv_addresses_j_first.csv

# %%
! objdump -D ./mv/matvec
# Out:
# ./mv/matvec:     file format elf64-x86-64
#
#
# Disassembly of section .interp:
#
# 0000000000000318 <.interp>:
#  318:	2f                   	(bad)
#  319:	6c                   	insb   (%dx),%es:(%rdi)
#  31a:	69 62 36 34 2f 6c 64 	imul   $0x646c2f34,0x36(%rdx),%esp
#  321:	2d 6c 69 6e 75       	sub    $0x756e696c,%eax
#  326:	78 2d                	js     355 <_init-0xcab>
#  328:	78 38                	js     362 <_init-0xc9e>
#  32a:	36 2d 36 34 2e 73    	ss sub $0x732e3436,%eax
#  330:	6f                   	outsl  %ds:(%rsi),(%dx)
#  331:	2e 32 00             	cs xor (%rax),%al
#
# Disassembly of section .note.gnu.property:
#
# 0000000000000338 <.note.gnu.property>:
#  338:	04 00                	add    $0x0,%al
#  33a:	00 00                	add    %al,(%rax)
#  33c:	10 00                	adc    %al,(%rax)
#  33e:	00 00                	add    %al,(%rax)
#  340:	05 00 00 00 47       	add    $0x47000000,%eax
#  345:	4e 55                	rex.WRX push %rbp
#  347:	00 02                	add    %al,(%rdx)
#  349:	00 00                	add    %al,(%rax)
#  34b:	c0 04 00 00          	rolb   $0x0,(%rax,%rax,1)
#  34f:	00 03                	add    %al,(%rbx)
#  351:	00 00                	add    %al,(%rax)
#  353:	00 00                	add    %al,(%rax)
#  355:	00 00                	add    %al,(%rax)
# 	...
#
# Disassembly of section .note.gnu.build-id:
#
# 0000000000000358 <.note.gnu.build-id>:
#  358:	04 00                	add    $0x0,%al
#  35a:	00 00                	add    %al,(%rax)
#  35c:	14 00                	adc    $0x0,%al
#  35e:	00 00                	add    %al,(%rax)
#  360:	03 00                	add    (%rax),%eax
#  362:	00 00                	add    %al,(%rax)
#  364:	47                   	rex.RXB
#  365:	4e 55                	rex.WRX push %rbp
#  367:	00 7d b6             	add    %bh,-0x4a(%rbp)
#  36a:	ce                   	(bad)
#  36b:	8d 16                	lea    (%rsi),%edx
#  36d:	82                   	(bad)
#  36e:	62 ab f5 c1 21       	(bad)
#  373:	db cc                	fcmovne %st(4),%st
#  375:	07                   	(bad)
#  376:	43                   	rex.XB
#  377:	86                   	.byte 0x86
#  378:	83                   	.byte 0x83
#  379:	ad                   	lods   %ds:(%rsi),%eax
#  37a:	d7                   	xlat   %ds:(%rbx)
#  37b:	12                   	.byte 0x12
#
# Disassembly of section .note.ABI-tag:
#
# 000000000000037c <.note.ABI-tag>:
#  37c:	04 00                	add    $0x0,%al
#  37e:	00 00                	add    %al,(%rax)
#  380:	10 00                	adc    %al,(%rax)
#  382:	00 00                	add    %al,(%rax)
#  384:	01 00                	add    %eax,(%rax)
#  386:	00 00                	add    %al,(%rax)
#  388:	47                   	rex.RXB
#  389:	4e 55                	rex.WRX push %rbp
#  38b:	00 00                	add    %al,(%rax)
#  38d:	00 00                	add    %al,(%rax)
#  38f:	00 03                	add    %al,(%rbx)
#  391:	00 00                	add    %al,(%rax)
#  393:	00 02                	add    %al,(%rdx)
#  395:	00 00                	add    %al,(%rax)
#  397:	00 00                	add    %al,(%rax)
#  399:	00 00                	add    %al,(%rax)
# 	...
#
# Disassembly of section .gnu.hash:
#
# 00000000000003a0 <.gnu.hash>:
#  3a0:	02 00                	add    (%rax),%al
#  3a2:	00 00                	add    %al,(%rax)
#  3a4:	0a 00                	or     (%rax),%al
#  3a6:	00 00                	add    %al,(%rax)
#  3a8:	01 00                	add    %eax,(%rax)
#  3aa:	00 00                	add    %al,(%rax)
#  3ac:	06                   	(bad)
#  3ad:	00 00                	add    %al,(%rax)
#  3af:	00 00                	add    %al,(%rax)
#  3b1:	00 81 00 00 00 00    	add    %al,0x0(%rcx)
#  3b7:	00 0a                	add    %cl,(%rdx)
#  3b9:	00 00                	add    %al,(%rax)
#  3bb:	00 00                	add    %al,(%rax)
#  3bd:	00 00                	add    %al,(%rax)
#  3bf:	00 d1                	add    %dl,%cl
#  3c1:	65 ce                	gs (bad)
#  3c3:	6d                   	insl   (%dx),%es:(%rdi)
#
# Disassembly of section .dynsym:
#
# 00000000000003c8 <.dynsym>:
# 	...
#  3e0:	6b 00 00             	imul   $0x0,(%rax),%eax
#  3e3:	00 20                	add    %ah,(%rax)
# 	...
#  3f5:	00 00                	add    %al,(%rax)
#  3f7:	00 1f                	add    %bl,(%rdi)
#  3f9:	00 00                	add    %al,(%rax)
#  3fb:	00 12                	add    %dl,(%rdx)
# 	...
#  40d:	00 00                	add    %al,(%rax)
#  40f:	00 41 00             	add    %al,0x0(%rcx)
#  412:	00 00                	add    %al,(%rax)
#  414:	12 00                	adc    (%rax),%al
# 	...
#  426:	00 00                	add    %al,(%rax)
#  428:	87 00                	xchg   %eax,(%rax)
#  42a:	00 00                	add    %al,(%rax)
#  42c:	20 00                	and    %al,(%rax)
# 	...
#  43e:	00 00                	add    %al,(%rax)
#  440:	18 00                	sbb    %al,(%rax)
#  442:	00 00                	add    %al,(%rax)
#  444:	12 00                	adc    (%rax),%al
# 	...
#  456:	00 00                	add    %al,(%rax)
#  458:	2b 00                	sub    (%rax),%eax
#  45a:	00 00                	add    %al,(%rax)
#  45c:	12 00                	adc    (%rax),%al
# 	...
#  46e:	00 00                	add    %al,(%rax)
#  470:	0b 00                	or     (%rax),%eax
#  472:	00 00                	add    %al,(%rax)
#  474:	12 00                	adc    (%rax),%al
# 	...
#  486:	00 00                	add    %al,(%rax)
#  488:	96                   	xchg   %eax,%esi
#  489:	00 00                	add    %al,(%rax)
#  48b:	00 20                	add    %ah,(%rax)
# 	...
#  49d:	00 00                	add    %al,(%rax)
#  49f:	00 26                	add    %ah,(%rsi)
#  4a1:	00 00                	add    %al,(%rax)
#  4a3:	00 12                	add    %dl,(%rdx)
# 	...
#  4b5:	00 00                	add    %al,(%rax)
#  4b7:	00 32                	add    %dh,(%rdx)
#  4b9:	00 00                	add    %al,(%rax)
#  4bb:	00 22                	add    %ah,(%rdx)
# 	...
#
# Disassembly of section .dynstr:
#
# 00000000000004d0 <.dynstr>:
#  4d0:	00 6c 69 62          	add    %ch,0x62(%rcx,%rbp,2)
#  4d4:	63 2e                	movsxd (%rsi),%ebp
#  4d6:	73 6f                	jae    547 <_init-0xab9>
#  4d8:	2e 36 00 5f 5f       	cs ss add %bl,0x5f(%rdi)
#  4dd:	70 72                	jo     551 <_init-0xaaf>
#  4df:	69 6e 74 66 5f 63 68 	imul   $0x68635f66,0x74(%rsi),%ebp
#  4e6:	6b 00 73             	imul   $0x73,(%rax),%eax
#  4e9:	74 72                	je     55d <_init-0xaa3>
#  4eb:	74 6f                	je     55c <_init-0xaa4>
#  4ed:	6c                   	insb   (%dx),%es:(%rdi)
#  4ee:	00 6d 65             	add    %ch,0x65(%rbp)
#  4f1:	6d                   	insl   (%dx),%es:(%rdi)
#  4f2:	73 65                	jae    559 <_init-0xaa7>
#  4f4:	74 00                	je     4f6 <_init-0xb0a>
#  4f6:	72 61                	jb     559 <_init-0xaa7>
#  4f8:	6e                   	outsb  %ds:(%rsi),(%dx)
#  4f9:	64 00 6d 61          	add    %ch,%fs:0x61(%rbp)
#  4fd:	6c                   	insb   (%dx),%es:(%rdi)
#  4fe:	6c                   	insb   (%dx),%es:(%rdi)
#  4ff:	6f                   	outsl  %ds:(%rsi),(%dx)
#  500:	63 00                	movsxd (%rax),%eax
#  502:	5f                   	pop    %rdi
#  503:	5f                   	pop    %rdi
#  504:	63 78 61             	movsxd 0x61(%rax),%edi
#  507:	5f                   	pop    %rdi
#  508:	66 69 6e 61 6c 69    	imul   $0x696c,0x61(%rsi),%bp
#  50e:	7a 65                	jp     575 <_init-0xa8b>
#  510:	00 5f 5f             	add    %bl,0x5f(%rdi)
#  513:	6c                   	insb   (%dx),%es:(%rdi)
#  514:	69 62 63 5f 73 74 61 	imul   $0x6174735f,0x63(%rdx),%esp
#  51b:	72 74                	jb     591 <_init-0xa6f>
#  51d:	5f                   	pop    %rdi
#  51e:	6d                   	insl   (%dx),%es:(%rdi)
#  51f:	61                   	(bad)
#  520:	69 6e 00 47 4c 49 42 	imul   $0x42494c47,0x0(%rsi),%ebp
#  527:	43 5f                	rex.XB pop %r15
#  529:	32 2e                	xor    (%rsi),%ch
#  52b:	33 2e                	xor    (%rsi),%ebp
#  52d:	34 00                	xor    $0x0,%al
#  52f:	47                   	rex.RXB
#  530:	4c                   	rex.WR
#  531:	49                   	rex.WB
#  532:	42                   	rex.X
#  533:	43 5f                	rex.XB pop %r15
#  535:	32 2e                	xor    (%rsi),%ch
#  537:	32 2e                	xor    (%rsi),%ch
#  539:	35 00 5f 49 54       	xor    $0x54495f00,%eax
#  53e:	4d 5f                	rex.WRB pop %r15
#  540:	64 65 72 65          	fs gs jb 5a9 <_init-0xa57>
#  544:	67 69 73 74 65 72 54 	imul   $0x4d547265,0x74(%ebx),%esi
#  54b:	4d
#  54c:	43 6c                	rex.XB insb (%dx),%es:(%rdi)
#  54e:	6f                   	outsl  %ds:(%rsi),(%dx)
#  54f:	6e                   	outsb  %ds:(%rsi),(%dx)
#  550:	65 54                	gs push %rsp
#  552:	61                   	(bad)
#  553:	62 6c 65             	(bad)
#  556:	00 5f 5f             	add    %bl,0x5f(%rdi)
#  559:	67 6d                	insl   (%dx),%es:(%edi)
#  55b:	6f                   	outsl  %ds:(%rsi),(%dx)
#  55c:	6e                   	outsb  %ds:(%rsi),(%dx)
#  55d:	5f                   	pop    %rdi
#  55e:	73 74                	jae    5d4 <_init-0xa2c>
#  560:	61                   	(bad)
#  561:	72 74                	jb     5d7 <_init-0xa29>
#  563:	5f                   	pop    %rdi
#  564:	5f                   	pop    %rdi
#  565:	00 5f 49             	add    %bl,0x49(%rdi)
#  568:	54                   	push   %rsp
#  569:	4d 5f                	rex.WRB pop %r15
#  56b:	72 65                	jb     5d2 <_init-0xa2e>
#  56d:	67 69 73 74 65 72 54 	imul   $0x4d547265,0x74(%ebx),%esi
#  574:	4d
#  575:	43 6c                	rex.XB insb (%dx),%es:(%rdi)
#  577:	6f                   	outsl  %ds:(%rsi),(%dx)
#  578:	6e                   	outsb  %ds:(%rsi),(%dx)
#  579:	65 54                	gs push %rsp
#  57b:	61                   	(bad)
#  57c:	62                   	.byte 0x62
#  57d:	6c                   	insb   (%dx),%es:(%rdi)
#  57e:	65                   	gs
# 	...
#
# Disassembly of section .gnu.version:
#
# 0000000000000580 <.gnu.version>:
#  580:	00 00                	add    %al,(%rax)
#  582:	00 00                	add    %al,(%rax)
#  584:	02 00                	add    (%rax),%al
#  586:	02 00                	add    (%rax),%al
#  588:	00 00                	add    %al,(%rax)
#  58a:	02 00                	add    (%rax),%al
#  58c:	02 00                	add    (%rax),%al
#  58e:	03 00                	add    (%rax),%eax
#  590:	00 00                	add    %al,(%rax)
#  592:	02 00                	add    (%rax),%al
#  594:	02 00                	add    (%rax),%al
#
# Disassembly of section .gnu.version_r:
#
# 0000000000000598 <.gnu.version_r>:
#  598:	01 00                	add    %eax,(%rax)
#  59a:	02 00                	add    (%rax),%al
#  59c:	01 00                	add    %eax,(%rax)
#  59e:	00 00                	add    %al,(%rax)
#  5a0:	10 00                	adc    %al,(%rax)
#  5a2:	00 00                	add    %al,(%rax)
#  5a4:	00 00                	add    %al,(%rax)
#  5a6:	00 00                	add    %al,(%rax)
#  5a8:	74 19                	je     5c3 <_init-0xa3d>
#  5aa:	69 09 00 00 03 00    	imul   $0x30000,(%rcx),%ecx
#  5b0:	53                   	push   %rbx
#  5b1:	00 00                	add    %al,(%rax)
#  5b3:	00 10                	add    %dl,(%rax)
#  5b5:	00 00                	add    %al,(%rax)
#  5b7:	00 75 1a             	add    %dh,0x1a(%rbp)
#  5ba:	69 09 00 00 02 00    	imul   $0x20000,(%rcx),%ecx
#  5c0:	5f                   	pop    %rdi
#  5c1:	00 00                	add    %al,(%rax)
#  5c3:	00 00                	add    %al,(%rax)
#  5c5:	00 00                	add    %al,(%rax)
# 	...
#
# Disassembly of section .rela.dyn:
#
# 00000000000005c8 <.rela.dyn>:
#  5c8:	98                   	cwtl
#  5c9:	3d 00 00 00 00       	cmp    $0x0,%eax
#  5ce:	00 00                	add    %al,(%rax)
#  5d0:	08 00                	or     %al,(%rax)
#  5d2:	00 00                	add    %al,(%rax)
#  5d4:	00 00                	add    %al,(%rax)
#  5d6:	00 00                	add    %al,(%rax)
#  5d8:	80 16 00             	adcb   $0x0,(%rsi)
#  5db:	00 00                	add    %al,(%rax)
#  5dd:	00 00                	add    %al,(%rax)
#  5df:	00 a0 3d 00 00 00    	add    %ah,0x3d(%rax)
#  5e5:	00 00                	add    %al,(%rax)
#  5e7:	00 08                	add    %cl,(%rax)
#  5e9:	00 00                	add    %al,(%rax)
#  5eb:	00 00                	add    %al,(%rax)
#  5ed:	00 00                	add    %al,(%rax)
#  5ef:	00 40 16             	add    %al,0x16(%rax)
#  5f2:	00 00                	add    %al,(%rax)
#  5f4:	00 00                	add    %al,(%rax)
#  5f6:	00 00                	add    %al,(%rax)
#  5f8:	08 40 00             	or     %al,0x0(%rax)
#  5fb:	00 00                	add    %al,(%rax)
#  5fd:	00 00                	add    %al,(%rax)
#  5ff:	00 08                	add    %cl,(%rax)
#  601:	00 00                	add    %al,(%rax)
#  603:	00 00                	add    %al,(%rax)
#  605:	00 00                	add    %al,(%rax)
#  607:	00 08                	add    %cl,(%rax)
#  609:	40 00 00             	rex add %al,(%rax)
#  60c:	00 00                	add    %al,(%rax)
#  60e:	00 00                	add    %al,(%rax)
#  610:	d8 3f                	fdivrs (%rdi)
#  612:	00 00                	add    %al,(%rax)
#  614:	00 00                	add    %al,(%rax)
#  616:	00 00                	add    %al,(%rax)
#  618:	06                   	(bad)
#  619:	00 00                	add    %al,(%rax)
#  61b:	00 01                	add    %al,(%rcx)
# 	...
#  625:	00 00                	add    %al,(%rax)
#  627:	00 e0                	add    %ah,%al
#  629:	3f                   	(bad)
#  62a:	00 00                	add    %al,(%rax)
#  62c:	00 00                	add    %al,(%rax)
#  62e:	00 00                	add    %al,(%rax)
#  630:	06                   	(bad)
#  631:	00 00                	add    %al,(%rax)
#  633:	00 03                	add    %al,(%rbx)
# 	...
#  63d:	00 00                	add    %al,(%rax)
#  63f:	00 e8                	add    %ch,%al
#  641:	3f                   	(bad)
#  642:	00 00                	add    %al,(%rax)
#  644:	00 00                	add    %al,(%rax)
#  646:	00 00                	add    %al,(%rax)
#  648:	06                   	(bad)
#  649:	00 00                	add    %al,(%rax)
#  64b:	00 04 00             	add    %al,(%rax,%rax,1)
# 	...
#  656:	00 00                	add    %al,(%rax)
#  658:	f0 3f                	lock (bad)
#  65a:	00 00                	add    %al,(%rax)
#  65c:	00 00                	add    %al,(%rax)
#  65e:	00 00                	add    %al,(%rax)
#  660:	06                   	(bad)
#  661:	00 00                	add    %al,(%rax)
#  663:	00 08                	add    %cl,(%rax)
# 	...
#  66d:	00 00                	add    %al,(%rax)
#  66f:	00 f8                	add    %bh,%al
#  671:	3f                   	(bad)
#  672:	00 00                	add    %al,(%rax)
#  674:	00 00                	add    %al,(%rax)
#  676:	00 00                	add    %al,(%rax)
#  678:	06                   	(bad)
#  679:	00 00                	add    %al,(%rax)
#  67b:	00 0a                	add    %cl,(%rdx)
# 	...
#
# Disassembly of section .rela.plt:
#
# 0000000000000688 <.rela.plt>:
#  688:	b0 3f                	mov    $0x3f,%al
#  68a:	00 00                	add    %al,(%rax)
#  68c:	00 00                	add    %al,(%rax)
#  68e:	00 00                	add    %al,(%rax)
#  690:	07                   	(bad)
#  691:	00 00                	add    %al,(%rax)
#  693:	00 02                	add    %al,(%rdx)
# 	...
#  69d:	00 00                	add    %al,(%rax)
#  69f:	00 b8 3f 00 00 00    	add    %bh,0x3f(%rax)
#  6a5:	00 00                	add    %al,(%rax)
#  6a7:	00 07                	add    %al,(%rdi)
#  6a9:	00 00                	add    %al,(%rax)
#  6ab:	00 05 00 00 00 00    	add    %al,0x0(%rip)        # 6b1 <_init-0x94f>
#  6b1:	00 00                	add    %al,(%rax)
#  6b3:	00 00                	add    %al,(%rax)
#  6b5:	00 00                	add    %al,(%rax)
#  6b7:	00 c0                	add    %al,%al
#  6b9:	3f                   	(bad)
#  6ba:	00 00                	add    %al,(%rax)
#  6bc:	00 00                	add    %al,(%rax)
#  6be:	00 00                	add    %al,(%rax)
#  6c0:	07                   	(bad)
#  6c1:	00 00                	add    %al,(%rax)
#  6c3:	00 06                	add    %al,(%rsi)
# 	...
#  6cd:	00 00                	add    %al,(%rax)
#  6cf:	00 c8                	add    %cl,%al
#  6d1:	3f                   	(bad)
#  6d2:	00 00                	add    %al,(%rax)
#  6d4:	00 00                	add    %al,(%rax)
#  6d6:	00 00                	add    %al,(%rax)
#  6d8:	07                   	(bad)
#  6d9:	00 00                	add    %al,(%rax)
#  6db:	00 07                	add    %al,(%rdi)
# 	...
#  6e5:	00 00                	add    %al,(%rax)
#  6e7:	00 d0                	add    %dl,%al
#  6e9:	3f                   	(bad)
#  6ea:	00 00                	add    %al,(%rax)
#  6ec:	00 00                	add    %al,(%rax)
#  6ee:	00 00                	add    %al,(%rax)
#  6f0:	07                   	(bad)
#  6f1:	00 00                	add    %al,(%rax)
#  6f3:	00 09                	add    %cl,(%rcx)
# 	...
#
# Disassembly of section .init:
#
# 0000000000001000 <_init>:
#     1000:	f3 0f 1e fa          	endbr64
#     1004:	48 83 ec 08          	sub    $0x8,%rsp
#     1008:	48 8b 05 d9 2f 00 00 	mov    0x2fd9(%rip),%rax        # 3fe8 <__gmon_start__>
#     100f:	48 85 c0             	test   %rax,%rax
#     1012:	74 02                	je     1016 <_init+0x16>
#     1014:	ff d0                	call   *%rax
#     1016:	48 83 c4 08          	add    $0x8,%rsp
#     101a:	c3                   	ret
#
# Disassembly of section .plt:
#
# 0000000000001020 <.plt>:
#     1020:	ff 35 7a 2f 00 00    	push   0x2f7a(%rip)        # 3fa0 <_GLOBAL_OFFSET_TABLE_+0x8>
#     1026:	f2 ff 25 7b 2f 00 00 	bnd jmp *0x2f7b(%rip)        # 3fa8 <_GLOBAL_OFFSET_TABLE_+0x10>
#     102d:	0f 1f 00             	nopl   (%rax)
#     1030:	f3 0f 1e fa          	endbr64
#     1034:	68 00 00 00 00       	push   $0x0
#     1039:	f2 e9 e1 ff ff ff    	bnd jmp 1020 <.plt>
#     103f:	90                   	nop
#     1040:	f3 0f 1e fa          	endbr64
#     1044:	68 01 00 00 00       	push   $0x1
#     1049:	f2 e9 d1 ff ff ff    	bnd jmp 1020 <.plt>
#     104f:	90                   	nop
#     1050:	f3 0f 1e fa          	endbr64
#     1054:	68 02 00 00 00       	push   $0x2
#     1059:	f2 e9 c1 ff ff ff    	bnd jmp 1020 <.plt>
#     105f:	90                   	nop
#     1060:	f3 0f 1e fa          	endbr64
#     1064:	68 03 00 00 00       	push   $0x3
#     1069:	f2 e9 b1 ff ff ff    	bnd jmp 1020 <.plt>
#     106f:	90                   	nop
#     1070:	f3 0f 1e fa          	endbr64
#     1074:	68 04 00 00 00       	push   $0x4
#     1079:	f2 e9 a1 ff ff ff    	bnd jmp 1020 <.plt>
#     107f:	90                   	nop
#
# Disassembly of section .plt.got:
#
# 0000000000001080 <__cxa_finalize@plt>:
#     1080:	f3 0f 1e fa          	endbr64
#     1084:	f2 ff 25 6d 2f 00 00 	bnd jmp *0x2f6d(%rip)        # 3ff8 <__cxa_finalize@GLIBC_2.2.5>
#     108b:	0f 1f 44 00 00       	nopl   0x0(%rax,%rax,1)
#
# Disassembly of section .plt.sec:
#
# 0000000000001090 <memset@plt>:
#     1090:	f3 0f 1e fa          	endbr64
#     1094:	f2 ff 25 15 2f 00 00 	bnd jmp *0x2f15(%rip)        # 3fb0 <memset@GLIBC_2.2.5>
#     109b:	0f 1f 44 00 00       	nopl   0x0(%rax,%rax,1)
#
# 00000000000010a0 <strtol@plt>:
#     10a0:	f3 0f 1e fa          	endbr64
#     10a4:	f2 ff 25 0d 2f 00 00 	bnd jmp *0x2f0d(%rip)        # 3fb8 <strtol@GLIBC_2.2.5>
#     10ab:	0f 1f 44 00 00       	nopl   0x0(%rax,%rax,1)
#
# 00000000000010b0 <malloc@plt>:
#     10b0:	f3 0f 1e fa          	endbr64
#     10b4:	f2 ff 25 05 2f 00 00 	bnd jmp *0x2f05(%rip)        # 3fc0 <malloc@GLIBC_2.2.5>
#     10bb:	0f 1f 44 00 00       	nopl   0x0(%rax,%rax,1)
#
# 00000000000010c0 <__printf_chk@plt>:
#     10c0:	f3 0f 1e fa          	endbr64
#     10c4:	f2 ff 25 fd 2e 00 00 	bnd jmp *0x2efd(%rip)        # 3fc8 <__printf_chk@GLIBC_2.3.4>
#     10cb:	0f 1f 44 00 00       	nopl   0x0(%rax,%rax,1)
#
# 00000000000010d0 <rand@plt>:
#     10d0:	f3 0f 1e fa          	endbr64
#     10d4:	f2 ff 25 f5 2e 00 00 	bnd jmp *0x2ef5(%rip)        # 3fd0 <rand@GLIBC_2.2.5>
#     10db:	0f 1f 44 00 00       	nopl   0x0(%rax,%rax,1)
#
# Disassembly of section .text:
#
# 00000000000010e0 <main>:
#     10e0:	f3 0f 1e fa          	endbr64
#     10e4:	41 57                	push   %r15
#     10e6:	41 56                	push   %r14
#     10e8:	41 55                	push   %r13
#     10ea:	41 54                	push   %r12
#     10ec:	55                   	push   %rbp
#     10ed:	53                   	push   %rbx
#     10ee:	48 83 ec 38          	sub    $0x38,%rsp
#     10f2:	83 ff 01             	cmp    $0x1,%edi
#     10f5:	0f 8f 2b 04 00 00    	jg     1526 <main+0x446>
#     10fb:	c7 44 24 14 00 00 00 	movl   $0x0,0x14(%rsp)
#     1102:	00
#     1103:	c7 04 24 01 00 00 00 	movl   $0x1,(%rsp)
#     110a:	4c 63 2d ff 2e 00 00 	movslq 0x2eff(%rip),%r13        # 4010 <ARRAY_SIZE>
#     1111:	4a 8d 3c ed 00 00 00 	lea    0x0(,%r13,8),%rdi
#     1118:	00
#     1119:	4d 89 ec             	mov    %r13,%r12
#     111c:	e8 8f ff ff ff       	call   10b0 <malloc@plt>
#     1121:	48 89 c5             	mov    %rax,%rbp
#     1124:	45 85 ed             	test   %r13d,%r13d
#     1127:	0f 8e 4e 04 00 00    	jle    157b <main+0x49b>
#     112d:	45 31 ff             	xor    %r15d,%r15d
#     1130:	4a 8d 3c ed 00 00 00 	lea    0x0(,%r13,8),%rdi
#     1137:	00
#     1138:	e8 73 ff ff ff       	call   10b0 <malloc@plt>
#     113d:	4a 89 44 fd 00       	mov    %rax,0x0(%rbp,%r15,8)
#     1142:	48 89 c3             	mov    %rax,%rbx
#     1145:	45 85 e4             	test   %r12d,%r12d
#     1148:	7e 49                	jle    1193 <main+0xb3>
#     114a:	45 31 ed             	xor    %r13d,%r13d
#     114d:	0f 1f 00             	nopl   (%rax)
#     1150:	e8 7b ff ff ff       	call   10d0 <rand@plt>
#     1155:	66 0f ef c0          	pxor   %xmm0,%xmm0
#     1159:	44 8b 25 b0 2e 00 00 	mov    0x2eb0(%rip),%r12d        # 4010 <ARRAY_SIZE>
#     1160:	48 63 d0             	movslq %eax,%rdx
#     1163:	89 c1                	mov    %eax,%ecx
#     1165:	48 69 d2 1f 85 eb 51 	imul   $0x51eb851f,%rdx,%rdx
#     116c:	c1 f9 1f             	sar    $0x1f,%ecx
#     116f:	48 c1 fa 25          	sar    $0x25,%rdx
#     1173:	29 ca                	sub    %ecx,%edx
#     1175:	6b d2 64             	imul   $0x64,%edx,%edx
#     1178:	29 d0                	sub    %edx,%eax
#     117a:	83 c0 01             	add    $0x1,%eax
#     117d:	f2 0f 2a c0          	cvtsi2sd %eax,%xmm0
#     1181:	f2 42 0f 11 04 eb    	movsd  %xmm0,(%rbx,%r13,8)
#     1187:	49 83 c5 01          	add    $0x1,%r13
#     118b:	45 39 ec             	cmp    %r13d,%r12d
#     118e:	7f c0                	jg     1150 <main+0x70>
#     1190:	4d 63 ec             	movslq %r12d,%r13
#     1193:	49 83 c7 01          	add    $0x1,%r15
#     1197:	45 39 fc             	cmp    %r15d,%r12d
#     119a:	7f 94                	jg     1130 <main+0x50>
#     119c:	4a 8d 3c ed 00 00 00 	lea    0x0(,%r13,8),%rdi
#     11a3:	00
#     11a4:	e8 07 ff ff ff       	call   10b0 <malloc@plt>
#     11a9:	49 89 c6             	mov    %rax,%r14
#     11ac:	45 85 e4             	test   %r12d,%r12d
#     11af:	0f 8e c6 03 00 00    	jle    157b <main+0x49b>
#     11b5:	45 31 ed             	xor    %r13d,%r13d
#     11b8:	0f 1f 84 00 00 00 00 	nopl   0x0(%rax,%rax,1)
#     11bf:	00
#     11c0:	e8 0b ff ff ff       	call   10d0 <rand@plt>
#     11c5:	66 0f ef c0          	pxor   %xmm0,%xmm0
#     11c9:	8b 1d 41 2e 00 00    	mov    0x2e41(%rip),%ebx        # 4010 <ARRAY_SIZE>
#     11cf:	48 63 d0             	movslq %eax,%rdx
#     11d2:	89 c1                	mov    %eax,%ecx
#     11d4:	48 69 d2 1f 85 eb 51 	imul   $0x51eb851f,%rdx,%rdx
#     11db:	c1 f9 1f             	sar    $0x1f,%ecx
#     11de:	48 c1 fa 25          	sar    $0x25,%rdx
#     11e2:	29 ca                	sub    %ecx,%edx
#     11e4:	6b d2 64             	imul   $0x64,%edx,%edx
#     11e7:	29 d0                	sub    %edx,%eax
#     11e9:	83 c0 01             	add    $0x1,%eax
#     11ec:	f2 0f 2a c0          	cvtsi2sd %eax,%xmm0
#     11f0:	f2 43 0f 11 04 ee    	movsd  %xmm0,(%r14,%r13,8)
#     11f6:	49 83 c5 01          	add    $0x1,%r13
#     11fa:	44 39 eb             	cmp    %r13d,%ebx
#     11fd:	7f c1                	jg     11c0 <main+0xe0>
#     11ff:	48 63 fb             	movslq %ebx,%rdi
#     1202:	48 c1 e7 03          	shl    $0x3,%rdi
#     1206:	e8 a5 fe ff ff       	call   10b0 <malloc@plt>
#     120b:	48 89 44 24 20       	mov    %rax,0x20(%rsp)
#     1210:	49 89 c7             	mov    %rax,%r15
#     1213:	85 db                	test   %ebx,%ebx
#     1215:	0f 8e ab 00 00 00    	jle    12c6 <main+0x1e6>
#     121b:	8d 43 ff             	lea    -0x1(%rbx),%eax
#     121e:	31 f6                	xor    %esi,%esi
#     1220:	4c 89 ff             	mov    %r15,%rdi
#     1223:	48 8d 14 c5 08 00 00 	lea    0x8(,%rax,8),%rdx
#     122a:	00
#     122b:	e8 60 fe ff ff       	call   1090 <memset@plt>
#     1230:	44 8b 14 24          	mov    (%rsp),%r10d
#     1234:	45 85 d2             	test   %r10d,%r10d
#     1237:	0f 84 e1 00 00 00    	je     131e <main+0x23e>
#     123d:	48 c7 44 24 08 00 00 	movq   $0x0,0x8(%rsp)
#     1244:	00 00
#     1246:	48 89 6c 24 28       	mov    %rbp,0x28(%rsp)
#     124b:	4c 89 7c 24 18       	mov    %r15,0x18(%rsp)
#     1250:	4c 8d 3d ad 0d 00 00 	lea    0xdad(%rip),%r15        # 2004 <_IO_stdin_used+0x4>
#     1257:	66 0f 1f 84 00 00 00 	nopw   0x0(%rax,%rax,1)
#     125e:	00 00
#     1260:	8b 6c 24 08          	mov    0x8(%rsp),%ebp
#     1264:	85 db                	test   %ebx,%ebx
#     1266:	0f 8e a1 02 00 00    	jle    150d <main+0x42d>
#     126c:	48 8b 44 24 28       	mov    0x28(%rsp),%rax
#     1271:	48 8b 74 24 08       	mov    0x8(%rsp),%rsi
#     1276:	44 8b 4c 24 14       	mov    0x14(%rsp),%r9d
#     127b:	4c 8b 04 f0          	mov    (%rax,%rsi,8),%r8
#     127f:	45 85 c9             	test   %r9d,%r9d
#     1282:	0f 85 d0 01 00 00    	jne    1458 <main+0x378>
#     1288:	31 c0                	xor    %eax,%eax
#     128a:	66 0f ef c9          	pxor   %xmm1,%xmm1
#     128e:	66 90                	xchg   %ax,%ax
#     1290:	f2 41 0f 10 04 c6    	movsd  (%r14,%rax,8),%xmm0
#     1296:	f2 41 0f 59 04 c0    	mulsd  (%r8,%rax,8),%xmm0
#     129c:	48 83 c0 01          	add    $0x1,%rax
#     12a0:	f2 0f 58 c8          	addsd  %xmm0,%xmm1
#     12a4:	39 c3                	cmp    %eax,%ebx
#     12a6:	7f e8                	jg     1290 <main+0x1b0>
#     12a8:	48 8b 44 24 18       	mov    0x18(%rsp),%rax
#     12ad:	f2 0f 11 08          	movsd  %xmm1,(%rax)
#     12b1:	48 83 44 24 08 01    	addq   $0x1,0x8(%rsp)
#     12b7:	48 8b 44 24 08       	mov    0x8(%rsp),%rax
#     12bc:	48 83 44 24 18 08    	addq   $0x8,0x18(%rsp)
#     12c2:	39 c3                	cmp    %eax,%ebx
#     12c4:	7f 9a                	jg     1260 <main+0x180>
#     12c6:	e8 05 fe ff ff       	call   10d0 <rand@plt>
#     12cb:	48 8b 5c 24 20       	mov    0x20(%rsp),%rbx
#     12d0:	99                   	cltd
#     12d1:	f7 3d 39 2d 00 00    	idivl  0x2d39(%rip)        # 4010 <ARRAY_SIZE>
#     12d7:	48 63 d2             	movslq %edx,%rdx
#     12da:	f2 44 0f 2c 24 d3    	cvttsd2si (%rbx,%rdx,8),%r12d
#     12e0:	e8 eb fd ff ff       	call   10d0 <rand@plt>
#     12e5:	48 8d 35 3f 0d 00 00 	lea    0xd3f(%rip),%rsi        # 202b <_IO_stdin_used+0x2b>
#     12ec:	bf 01 00 00 00       	mov    $0x1,%edi
#     12f1:	99                   	cltd
#     12f2:	f7 3d 18 2d 00 00    	idivl  0x2d18(%rip)        # 4010 <ARRAY_SIZE>
#     12f8:	b8 01 00 00 00       	mov    $0x1,%eax
#     12fd:	48 63 d2             	movslq %edx,%rdx
#     1300:	f2 0f 10 04 d3       	movsd  (%rbx,%rdx,8),%xmm0
#     1305:	44 89 e2             	mov    %r12d,%edx
#     1308:	e8 b3 fd ff ff       	call   10c0 <__printf_chk@plt>
#     130d:	48 83 c4 38          	add    $0x38,%rsp
#     1311:	31 c0                	xor    %eax,%eax
#     1313:	5b                   	pop    %rbx
#     1314:	5d                   	pop    %rbp
#     1315:	41 5c                	pop    %r12
#     1317:	41 5d                	pop    %r13
#     1319:	41 5e                	pop    %r14
#     131b:	41 5f                	pop    %r15
#     131d:	c3                   	ret
#     131e:	48 c7 44 24 08 00 00 	movq   $0x0,0x8(%rsp)
#     1325:	00 00
#     1327:	4d 89 f4             	mov    %r14,%r12
#     132a:	66 0f 1f 44 00 00    	nopw   0x0(%rax,%rax,1)
#     1330:	44 8b 7c 24 08       	mov    0x8(%rsp),%r15d
#     1335:	31 d2                	xor    %edx,%edx
#     1337:	31 c9                	xor    %ecx,%ecx
#     1339:	66 0f ef c0          	pxor   %xmm0,%xmm0
#     133d:	85 db                	test   %ebx,%ebx
#     133f:	7e 57                	jle    1398 <main+0x2b8>
#     1341:	48 8b 44 24 08       	mov    0x8(%rsp),%rax
#     1346:	8b 74 24 14          	mov    0x14(%rsp),%esi
#     134a:	4c 8d 2c c5 00 00 00 	lea    0x0(,%rax,8),%r13
#     1351:	00
#     1352:	85 f6                	test   %esi,%esi
#     1354:	0f 85 8e 00 00 00    	jne    13e8 <main+0x308>
#     135a:	f2 41 0f 10 14 24    	movsd  (%r12),%xmm2
#     1360:	31 c0                	xor    %eax,%eax
#     1362:	66 0f ef c0          	pxor   %xmm0,%xmm0
#     1366:	66 2e 0f 1f 84 00 00 	cs nopw 0x0(%rax,%rax,1)
#     136d:	00 00 00
#     1370:	48 8b 54 c5 00       	mov    0x0(%rbp,%rax,8),%rdx
#     1375:	48 83 c0 01          	add    $0x1,%rax
#     1379:	f2 42 0f 10 0c 2a    	movsd  (%rdx,%r13,1),%xmm1
#     137f:	f2 0f 59 ca          	mulsd  %xmm2,%xmm1
#     1383:	f2 0f 58 c1          	addsd  %xmm1,%xmm0
#     1387:	39 c3                	cmp    %eax,%ebx
#     1389:	7f e5                	jg     1370 <main+0x290>
#     138b:	89 d8                	mov    %ebx,%eax
#     138d:	48 63 cb             	movslq %ebx,%rcx
#     1390:	89 da                	mov    %ebx,%edx
#     1392:	89 c3                	mov    %eax,%ebx
#     1394:	48 c1 e1 03          	shl    $0x3,%rcx
#     1398:	8b 44 24 14          	mov    0x14(%rsp),%eax
#     139c:	48 03 4c 24 20       	add    0x20(%rsp),%rcx
#     13a1:	f2 0f 11 01          	movsd  %xmm0,(%rcx)
#     13a5:	85 c0                	test   %eax,%eax
#     13a7:	75 1f                	jne    13c8 <main+0x2e8>
#     13a9:	48 83 44 24 08 01    	addq   $0x1,0x8(%rsp)
#     13af:	48 8b 44 24 08       	mov    0x8(%rsp),%rax
#     13b4:	49 83 c4 08          	add    $0x8,%r12
#     13b8:	39 c3                	cmp    %eax,%ebx
#     13ba:	0f 8f 70 ff ff ff    	jg     1330 <main+0x250>
#     13c0:	e9 01 ff ff ff       	jmp    12c6 <main+0x1e6>
#     13c5:	0f 1f 00             	nopl   (%rax)
#     13c8:	48 8d 35 50 0c 00 00 	lea    0xc50(%rip),%rsi        # 201f <_IO_stdin_used+0x1f>
#     13cf:	bf 01 00 00 00       	mov    $0x1,%edi
#     13d4:	31 c0                	xor    %eax,%eax
#     13d6:	e8 e5 fc ff ff       	call   10c0 <__printf_chk@plt>
#     13db:	8b 1d 2f 2c 00 00    	mov    0x2c2f(%rip),%ebx        # 4010 <ARRAY_SIZE>
#     13e1:	eb c6                	jmp    13a9 <main+0x2c9>
#     13e3:	0f 1f 44 00 00       	nopl   0x0(%rax,%rax,1)
#     13e8:	49 89 ee             	mov    %rbp,%r14
#     13eb:	31 db                	xor    %ebx,%ebx
#     13ed:	66 0f ef c0          	pxor   %xmm0,%xmm0
#     13f1:	0f 1f 80 00 00 00 00 	nopl   0x0(%rax)
#     13f8:	4d 8b 06             	mov    (%r14),%r8
#     13fb:	48 83 ec 08          	sub    $0x8,%rsp
#     13ff:	89 da                	mov    %ebx,%edx
#     1401:	44 89 f9             	mov    %r15d,%ecx
#     1404:	31 c0                	xor    %eax,%eax
#     1406:	45 89 f9             	mov    %r15d,%r9d
#     1409:	48 8d 35 f4 0b 00 00 	lea    0xbf4(%rip),%rsi        # 2004 <_IO_stdin_used+0x4>
#     1410:	83 c3 01             	add    $0x1,%ebx
#     1413:	4d 01 e8             	add    %r13,%r8
#     1416:	bf 01 00 00 00       	mov    $0x1,%edi
#     141b:	49 83 c6 08          	add    $0x8,%r14
#     141f:	f2 41 0f 10 08       	movsd  (%r8),%xmm1
#     1424:	f2 41 0f 59 0c 24    	mulsd  (%r12),%xmm1
#     142a:	f2 0f 58 c1          	addsd  %xmm1,%xmm0
#     142e:	f2 0f 11 44 24 08    	movsd  %xmm0,0x8(%rsp)
#     1434:	41 54                	push   %r12
#     1436:	e8 85 fc ff ff       	call   10c0 <__printf_chk@plt>
#     143b:	8b 05 cf 2b 00 00    	mov    0x2bcf(%rip),%eax        # 4010 <ARRAY_SIZE>
#     1441:	5a                   	pop    %rdx
#     1442:	59                   	pop    %rcx
#     1443:	f2 0f 10 04 24       	movsd  (%rsp),%xmm0
#     1448:	39 c3                	cmp    %eax,%ebx
#     144a:	7c ac                	jl     13f8 <main+0x318>
#     144c:	e9 3c ff ff ff       	jmp    138d <main+0x2ad>
#     1451:	0f 1f 80 00 00 00 00 	nopl   0x0(%rax)
#     1458:	4c 89 c3             	mov    %r8,%rbx
#     145b:	4d 89 f4             	mov    %r14,%r12
#     145e:	66 0f ef c9          	pxor   %xmm1,%xmm1
#     1462:	45 31 ed             	xor    %r13d,%r13d
#     1465:	0f 1f 00             	nopl   (%rax)
#     1468:	f2 0f 10 03          	movsd  (%rbx),%xmm0
#     146c:	f2 41 0f 59 04 24    	mulsd  (%r12),%xmm0
#     1472:	48 83 ec 08          	sub    $0x8,%rsp
#     1476:	31 c0                	xor    %eax,%eax
#     1478:	49 89 d8             	mov    %rbx,%r8
#     147b:	45 89 e9             	mov    %r13d,%r9d
#     147e:	44 89 e9             	mov    %r13d,%ecx
#     1481:	bf 01 00 00 00       	mov    $0x1,%edi
#     1486:	89 ea                	mov    %ebp,%edx
#     1488:	4c 89 fe             	mov    %r15,%rsi
#     148b:	41 83 c5 01          	add    $0x1,%r13d
#     148f:	48 83 c3 08          	add    $0x8,%rbx
#     1493:	f2 0f 58 c8          	addsd  %xmm0,%xmm1
#     1497:	f2 0f 11 4c 24 08    	movsd  %xmm1,0x8(%rsp)
#     149d:	41 54                	push   %r12
#     149f:	49 83 c4 08          	add    $0x8,%r12
#     14a3:	e8 18 fc ff ff       	call   10c0 <__printf_chk@plt>
#     14a8:	44 3b 2d 61 2b 00 00 	cmp    0x2b61(%rip),%r13d        # 4010 <ARRAY_SIZE>
#     14af:	5f                   	pop    %rdi
#     14b0:	41 58                	pop    %r8
#     14b2:	f2 0f 10 0c 24       	movsd  (%rsp),%xmm1
#     14b7:	7c af                	jl     1468 <main+0x388>
#     14b9:	48 8b 44 24 18       	mov    0x18(%rsp),%rax
#     14be:	f2 0f 11 08          	movsd  %xmm1,(%rax)
#     14c2:	4c 8b 64 24 18       	mov    0x18(%rsp),%r12
#     14c7:	89 ea                	mov    %ebp,%edx
#     14c9:	48 8d 35 4f 0b 00 00 	lea    0xb4f(%rip),%rsi        # 201f <_IO_stdin_used+0x1f>
#     14d0:	31 c0                	xor    %eax,%eax
#     14d2:	bf 01 00 00 00       	mov    $0x1,%edi
#     14d7:	4c 89 e1             	mov    %r12,%rcx
#     14da:	49 83 c4 08          	add    $0x8,%r12
#     14de:	e8 dd fb ff ff       	call   10c0 <__printf_chk@plt>
#     14e3:	8b 1d 27 2b 00 00    	mov    0x2b27(%rip),%ebx        # 4010 <ARRAY_SIZE>
#     14e9:	48 83 44 24 08 01    	addq   $0x1,0x8(%rsp)
#     14ef:	48 8b 44 24 08       	mov    0x8(%rsp),%rax
#     14f4:	4c 89 64 24 18       	mov    %r12,0x18(%rsp)
#     14f9:	39 c3                	cmp    %eax,%ebx
#     14fb:	0f 8e c5 fd ff ff    	jle    12c6 <main+0x1e6>
#     1501:	8b 6c 24 08          	mov    0x8(%rsp),%ebp
#     1505:	85 db                	test   %ebx,%ebx
#     1507:	0f 8f 5f fd ff ff    	jg     126c <main+0x18c>
#     150d:	48 8b 44 24 18       	mov    0x18(%rsp),%rax
#     1512:	83 7c 24 14 00       	cmpl   $0x0,0x14(%rsp)
#     1517:	48 c7 00 00 00 00 00 	movq   $0x0,(%rax)
#     151e:	0f 84 8d fd ff ff    	je     12b1 <main+0x1d1>
#     1524:	eb 9c                	jmp    14c2 <main+0x3e2>
#     1526:	89 fb                	mov    %edi,%ebx
#     1528:	48 8b 7e 08          	mov    0x8(%rsi),%rdi
#     152c:	48 89 f5             	mov    %rsi,%rbp
#     152f:	ba 0a 00 00 00       	mov    $0xa,%edx
#     1534:	31 f6                	xor    %esi,%esi
#     1536:	e8 65 fb ff ff       	call   10a0 <strtol@plt>
#     153b:	89 05 cf 2a 00 00    	mov    %eax,0x2acf(%rip)        # 4010 <ARRAY_SIZE>
#     1541:	83 fb 02             	cmp    $0x2,%ebx
#     1544:	0f 84 b1 fb ff ff    	je     10fb <main+0x1b>
#     154a:	48 8b 7d 10          	mov    0x10(%rbp),%rdi
#     154e:	ba 0a 00 00 00       	mov    $0xa,%edx
#     1553:	31 f6                	xor    %esi,%esi
#     1555:	e8 46 fb ff ff       	call   10a0 <strtol@plt>
#     155a:	89 44 24 14          	mov    %eax,0x14(%rsp)
#     155e:	83 fb 03             	cmp    $0x3,%ebx
#     1561:	74 2f                	je     1592 <main+0x4b2>
#     1563:	48 8b 7d 18          	mov    0x18(%rbp),%rdi
#     1567:	ba 0a 00 00 00       	mov    $0xa,%edx
#     156c:	31 f6                	xor    %esi,%esi
#     156e:	e8 2d fb ff ff       	call   10a0 <strtol@plt>
#     1573:	89 04 24             	mov    %eax,(%rsp)
#     1576:	e9 8f fb ff ff       	jmp    110a <main+0x2a>
#     157b:	4a 8d 3c ed 00 00 00 	lea    0x0(,%r13,8),%rdi
#     1582:	00
#     1583:	e8 28 fb ff ff       	call   10b0 <malloc@plt>
#     1588:	48 89 44 24 20       	mov    %rax,0x20(%rsp)
#     158d:	e9 34 fd ff ff       	jmp    12c6 <main+0x1e6>
#     1592:	c7 04 24 01 00 00 00 	movl   $0x1,(%rsp)
#     1599:	e9 6c fb ff ff       	jmp    110a <main+0x2a>
#     159e:	66 90                	xchg   %ax,%ax
#
# 00000000000015a0 <_start>:
#     15a0:	f3 0f 1e fa          	endbr64
#     15a4:	31 ed                	xor    %ebp,%ebp
#     15a6:	49 89 d1             	mov    %rdx,%r9
#     15a9:	5e                   	pop    %rsi
#     15aa:	48 89 e2             	mov    %rsp,%rdx
#     15ad:	48 83 e4 f0          	and    $0xfffffffffffffff0,%rsp
#     15b1:	50                   	push   %rax
#     15b2:	54                   	push   %rsp
#     15b3:	4c 8d 05 46 01 00 00 	lea    0x146(%rip),%r8        # 1700 <__libc_csu_fini>
#     15ba:	48 8d 0d cf 00 00 00 	lea    0xcf(%rip),%rcx        # 1690 <__libc_csu_init>
#     15c1:	48 8d 3d 18 fb ff ff 	lea    -0x4e8(%rip),%rdi        # 10e0 <main>
#     15c8:	ff 15 12 2a 00 00    	call   *0x2a12(%rip)        # 3fe0 <__libc_start_main@GLIBC_2.2.5>
#     15ce:	f4                   	hlt
#     15cf:	90                   	nop
#
# 00000000000015d0 <deregister_tm_clones>:
#     15d0:	48 8d 3d 41 2a 00 00 	lea    0x2a41(%rip),%rdi        # 4018 <__TMC_END__>
#     15d7:	48 8d 05 3a 2a 00 00 	lea    0x2a3a(%rip),%rax        # 4018 <__TMC_END__>
#     15de:	48 39 f8             	cmp    %rdi,%rax
#     15e1:	74 15                	je     15f8 <deregister_tm_clones+0x28>
#     15e3:	48 8b 05 ee 29 00 00 	mov    0x29ee(%rip),%rax        # 3fd8 <_ITM_deregisterTMCloneTable>
#     15ea:	48 85 c0             	test   %rax,%rax
#     15ed:	74 09                	je     15f8 <deregister_tm_clones+0x28>
#     15ef:	ff e0                	jmp    *%rax
#     15f1:	0f 1f 80 00 00 00 00 	nopl   0x0(%rax)
#     15f8:	c3                   	ret
#     15f9:	0f 1f 80 00 00 00 00 	nopl   0x0(%rax)
#
# 0000000000001600 <register_tm_clones>:
#     1600:	48 8d 3d 11 2a 00 00 	lea    0x2a11(%rip),%rdi        # 4018 <__TMC_END__>
#     1607:	48 8d 35 0a 2a 00 00 	lea    0x2a0a(%rip),%rsi        # 4018 <__TMC_END__>
#     160e:	48 29 fe             	sub    %rdi,%rsi
#     1611:	48 89 f0             	mov    %rsi,%rax
#     1614:	48 c1 ee 3f          	shr    $0x3f,%rsi
#     1618:	48 c1 f8 03          	sar    $0x3,%rax
#     161c:	48 01 c6             	add    %rax,%rsi
#     161f:	48 d1 fe             	sar    $1,%rsi
#     1622:	74 14                	je     1638 <register_tm_clones+0x38>
#     1624:	48 8b 05 c5 29 00 00 	mov    0x29c5(%rip),%rax        # 3ff0 <_ITM_registerTMCloneTable>
#     162b:	48 85 c0             	test   %rax,%rax
#     162e:	74 08                	je     1638 <register_tm_clones+0x38>
#     1630:	ff e0                	jmp    *%rax
#     1632:	66 0f 1f 44 00 00    	nopw   0x0(%rax,%rax,1)
#     1638:	c3                   	ret
#     1639:	0f 1f 80 00 00 00 00 	nopl   0x0(%rax)
#
# 0000000000001640 <__do_global_dtors_aux>:
#     1640:	f3 0f 1e fa          	endbr64
#     1644:	80 3d c9 29 00 00 00 	cmpb   $0x0,0x29c9(%rip)        # 4014 <completed.8061>
#     164b:	75 2b                	jne    1678 <__do_global_dtors_aux+0x38>
#     164d:	55                   	push   %rbp
#     164e:	48 83 3d a2 29 00 00 	cmpq   $0x0,0x29a2(%rip)        # 3ff8 <__cxa_finalize@GLIBC_2.2.5>
#     1655:	00
#     1656:	48 89 e5             	mov    %rsp,%rbp
#     1659:	74 0c                	je     1667 <__do_global_dtors_aux+0x27>
#     165b:	48 8b 3d a6 29 00 00 	mov    0x29a6(%rip),%rdi        # 4008 <__dso_handle>
#     1662:	e8 19 fa ff ff       	call   1080 <__cxa_finalize@plt>
#     1667:	e8 64 ff ff ff       	call   15d0 <deregister_tm_clones>
#     166c:	c6 05 a1 29 00 00 01 	movb   $0x1,0x29a1(%rip)        # 4014 <completed.8061>
#     1673:	5d                   	pop    %rbp
#     1674:	c3                   	ret
#     1675:	0f 1f 00             	nopl   (%rax)
#     1678:	c3                   	ret
#     1679:	0f 1f 80 00 00 00 00 	nopl   0x0(%rax)
#
# 0000000000001680 <frame_dummy>:
#     1680:	f3 0f 1e fa          	endbr64
#     1684:	e9 77 ff ff ff       	jmp    1600 <register_tm_clones>
#     1689:	0f 1f 80 00 00 00 00 	nopl   0x0(%rax)
#
# 0000000000001690 <__libc_csu_init>:
#     1690:	f3 0f 1e fa          	endbr64
#     1694:	41 57                	push   %r15
#     1696:	4c 8d 3d fb 26 00 00 	lea    0x26fb(%rip),%r15        # 3d98 <__frame_dummy_init_array_entry>
#     169d:	41 56                	push   %r14
#     169f:	49 89 d6             	mov    %rdx,%r14
#     16a2:	41 55                	push   %r13
#     16a4:	49 89 f5             	mov    %rsi,%r13
#     16a7:	41 54                	push   %r12
#     16a9:	41 89 fc             	mov    %edi,%r12d
#     16ac:	55                   	push   %rbp
#     16ad:	48 8d 2d ec 26 00 00 	lea    0x26ec(%rip),%rbp        # 3da0 <__do_global_dtors_aux_fini_array_entry>
#     16b4:	53                   	push   %rbx
#     16b5:	4c 29 fd             	sub    %r15,%rbp
#     16b8:	48 83 ec 08          	sub    $0x8,%rsp
#     16bc:	e8 3f f9 ff ff       	call   1000 <_init>
#     16c1:	48 c1 fd 03          	sar    $0x3,%rbp
#     16c5:	74 1f                	je     16e6 <__libc_csu_init+0x56>
#     16c7:	31 db                	xor    %ebx,%ebx
#     16c9:	0f 1f 80 00 00 00 00 	nopl   0x0(%rax)
#     16d0:	4c 89 f2             	mov    %r14,%rdx
#     16d3:	4c 89 ee             	mov    %r13,%rsi
#     16d6:	44 89 e7             	mov    %r12d,%edi
#     16d9:	41 ff 14 df          	call   *(%r15,%rbx,8)
#     16dd:	48 83 c3 01          	add    $0x1,%rbx
#     16e1:	48 39 dd             	cmp    %rbx,%rbp
#     16e4:	75 ea                	jne    16d0 <__libc_csu_init+0x40>
#     16e6:	48 83 c4 08          	add    $0x8,%rsp
#     16ea:	5b                   	pop    %rbx
#     16eb:	5d                   	pop    %rbp
#     16ec:	41 5c                	pop    %r12
#     16ee:	41 5d                	pop    %r13
#     16f0:	41 5e                	pop    %r14
#     16f2:	41 5f                	pop    %r15
#     16f4:	c3                   	ret
#     16f5:	66 66 2e 0f 1f 84 00 	data16 cs nopw 0x0(%rax,%rax,1)
#     16fc:	00 00 00 00
#
# 0000000000001700 <__libc_csu_fini>:
#     1700:	f3 0f 1e fa          	endbr64
#     1704:	c3                   	ret
#
# Disassembly of section .fini:
#
# 0000000000001708 <_fini>:
#     1708:	f3 0f 1e fa          	endbr64
#     170c:	48 83 ec 08          	sub    $0x8,%rsp
#     1710:	48 83 c4 08          	add    $0x8,%rsp
#     1714:	c3                   	ret
#
# Disassembly of section .rodata:
#
# 0000000000002000 <_IO_stdin_used>:
#     2000:	01 00                	add    %eax,(%rax)
#     2002:	02 00                	add    (%rax),%al
#     2004:	26 61                	es (bad)
#     2006:	5b                   	pop    %rbx
#     2007:	25 64 5d 5b 25       	and    $0x255b5d64,%eax
#     200c:	64 5d                	fs pop %rbp
#     200e:	2c 20                	sub    $0x20,%al
#     2010:	25 70 0a 26 62       	and    $0x62260a70,%eax
#     2015:	5b                   	pop    %rbx
#     2016:	25 64 5d 2c 20       	and    $0x202c5d64,%eax
#     201b:	25 70 0a 00 26       	and    $0x26000a70,%eax
#     2020:	63 5b 25             	movsxd 0x25(%rbx),%ebx
#     2023:	64 5d                	fs pop %rbp
#     2025:	2c 20                	sub    $0x20,%al
#     2027:	25 70 0a 00 25       	and    $0x25000a70,%eax
#     202c:	6c                   	insb   (%dx),%es:(%rdi)
#     202d:	66 2c 25             	data16 sub $0x25,%al
#     2030:	64 0a 00             	or     %fs:(%rax),%al
#
# Disassembly of section .eh_frame_hdr:
#
# 0000000000002034 <__GNU_EH_FRAME_HDR>:
#     2034:	01 1b                	add    %ebx,(%rbx)
#     2036:	03 3b                	add    (%rbx),%edi
#     2038:	40 00 00             	rex add %al,(%rax)
#     203b:	00 07                	add    %al,(%rdi)
#     203d:	00 00                	add    %al,(%rax)
#     203f:	00 ec                	add    %ch,%ah
#     2041:	ef                   	out    %eax,(%dx)
#     2042:	ff                   	(bad)
#     2043:	ff 74 00 00          	push   0x0(%rax,%rax,1)
#     2047:	00 4c f0 ff          	add    %cl,-0x1(%rax,%rsi,8)
#     204b:	ff 9c 00 00 00 5c f0 	lcall  *-0xfa40000(%rax,%rax,1)
#     2052:	ff                   	(bad)
#     2053:	ff b4 00 00 00 ac f0 	push   -0xf540000(%rax,%rax,1)
#     205a:	ff                   	(bad)
#     205b:	ff cc                	dec    %esp
#     205d:	00 00                	add    %al,(%rax)
#     205f:	00 6c f5 ff          	add    %ch,-0x1(%rbp,%rsi,8)
#     2063:	ff 5c 00 00          	lcall  *0x0(%rax,%rax,1)
#     2067:	00 5c f6 ff          	add    %bl,-0x1(%rsi,%rsi,8)
#     206b:	ff 34 01             	push   (%rcx,%rax,1)
#     206e:	00 00                	add    %al,(%rax)
#     2070:	cc                   	int3
#     2071:	f6 ff                	idiv   %bh
#     2073:	ff                   	(bad)
#     2074:	7c 01                	jl     2077 <__GNU_EH_FRAME_HDR+0x43>
# 	...
#
# Disassembly of section .eh_frame:
#
# 0000000000002078 <__FRAME_END__-0x14c>:
#     2078:	14 00                	adc    $0x0,%al
#     207a:	00 00                	add    %al,(%rax)
#     207c:	00 00                	add    %al,(%rax)
#     207e:	00 00                	add    %al,(%rax)
#     2080:	01 7a 52             	add    %edi,0x52(%rdx)
#     2083:	00 01                	add    %al,(%rcx)
#     2085:	78 10                	js     2097 <__GNU_EH_FRAME_HDR+0x63>
#     2087:	01 1b                	add    %ebx,(%rbx)
#     2089:	0c 07                	or     $0x7,%al
#     208b:	08 90 01 00 00 14    	or     %dl,0x14000001(%rax)
#     2091:	00 00                	add    %al,(%rax)
#     2093:	00 1c 00             	add    %bl,(%rax,%rax,1)
#     2096:	00 00                	add    %al,(%rax)
#     2098:	08 f5                	or     %dh,%ch
#     209a:	ff                   	(bad)
#     209b:	ff 2f                	ljmp   *(%rdi)
#     209d:	00 00                	add    %al,(%rax)
#     209f:	00 00                	add    %al,(%rax)
#     20a1:	44 07                	rex.R (bad)
#     20a3:	10 00                	adc    %al,(%rax)
#     20a5:	00 00                	add    %al,(%rax)
#     20a7:	00 24 00             	add    %ah,(%rax,%rax,1)
#     20aa:	00 00                	add    %al,(%rax)
#     20ac:	34 00                	xor    $0x0,%al
#     20ae:	00 00                	add    %al,(%rax)
#     20b0:	70 ef                	jo     20a1 <__GNU_EH_FRAME_HDR+0x6d>
#     20b2:	ff                   	(bad)
#     20b3:	ff 60 00             	jmp    *0x0(%rax)
#     20b6:	00 00                	add    %al,(%rax)
#     20b8:	00 0e                	add    %cl,(%rsi)
#     20ba:	10 46 0e             	adc    %al,0xe(%rsi)
#     20bd:	18 4a 0f             	sbb    %cl,0xf(%rdx)
#     20c0:	0b 77 08             	or     0x8(%rdi),%esi
#     20c3:	80 00 3f             	addb   $0x3f,(%rax)
#     20c6:	1a 3a                	sbb    (%rdx),%bh
#     20c8:	2a 33                	sub    (%rbx),%dh
#     20ca:	24 22                	and    $0x22,%al
#     20cc:	00 00                	add    %al,(%rax)
#     20ce:	00 00                	add    %al,(%rax)
#     20d0:	14 00                	adc    $0x0,%al
#     20d2:	00 00                	add    %al,(%rax)
#     20d4:	5c                   	pop    %rsp
#     20d5:	00 00                	add    %al,(%rax)
#     20d7:	00 a8 ef ff ff 10    	add    %ch,0x10ffffef(%rax)
# 	...
#     20e5:	00 00                	add    %al,(%rax)
#     20e7:	00 14 00             	add    %dl,(%rax,%rax,1)
#     20ea:	00 00                	add    %al,(%rax)
#     20ec:	74 00                	je     20ee <__GNU_EH_FRAME_HDR+0xba>
#     20ee:	00 00                	add    %al,(%rax)
#     20f0:	a0 ef ff ff 50 00 00 	movabs 0x50ffffef,%al
#     20f7:	00 00
#     20f9:	00 00                	add    %al,(%rax)
#     20fb:	00 00                	add    %al,(%rax)
#     20fd:	00 00                	add    %al,(%rax)
#     20ff:	00 64 00 00          	add    %ah,0x0(%rax,%rax,1)
#     2103:	00 8c 00 00 00 d8 ef 	add    %cl,-0x10280000(%rax,%rax,1)
#     210a:	ff                   	(bad)
#     210b:	ff                   	(bad)
#     210c:	be 04 00 00 00       	mov    $0x4,%esi
#     2111:	46 0e                	rex.RX (bad)
#     2113:	10 8f 02 42 0e 18    	adc    %cl,0x180e4202(%rdi)
#     2119:	8e 03                	mov    (%rbx),%es
#     211b:	42 0e                	rex.X (bad)
#     211d:	20 8d 04 42 0e 28    	and    %cl,0x280e4204(%rbp)
#     2123:	8c 05 41 0e 30 86    	mov    %es,-0x79cff1bf(%rip)        # ffffffff86302f6a <__TMC_END__+0xffffffff862fef52>
#     2129:	06                   	(bad)
#     212a:	41 0e                	rex.B (bad)
#     212c:	38 83 07 44 0e 70    	cmp    %al,0x700e4407(%rbx)
#     2132:	03 1f                	add    (%rdi),%ebx
#     2134:	02 0a                	add    (%rdx),%cl
#     2136:	0e                   	(bad)
# ...
#  6f3:	9f                   	lahf
#  6f4:	e3 13                	jrcxz  709 <_init-0x8f7>
#  6f6:	00 00                	add    %al,(%rax)
#  6f8:	00 00                	add    %al,(%rax)
#  6fa:	00 00                	add    %al,(%rax)
#  6fc:	51                   	push   %rcx
#  6fd:	14 00                	adc    $0x0,%al
#  6ff:	00 00                	add    %al,(%rax)
#  701:	00 00                	add    %al,(%rax)
#  703:	00 01                	add    %al,(%rcx)
#  705:	00 5f 51             	add    %bl,0x51(%rdi)
#  708:	14 00                	adc    $0x0,%al
#  70a:	00 00                	add    %al,(%rax)
#  70c:	00 00                	add    %al,(%rax)
#  70e:	00 65 14             	add    %ah,0x14(%rbp)
#  711:	00 00                	add    %al,(%rax)
#  713:	00 00                	add    %al,(%rax)
#  715:	00 00                	add    %al,(%rax)
#  717:	02 00                	add    (%rax),%al
#  719:	30 9f 65 14 00 00    	xor    %bl,0x1465(%rdi)
#  71f:	00 00                	add    %al,(%rax)
#  721:	00 00                	add    %al,(%rax)
#  723:	8f                   	(bad)
#  724:	14 00                	adc    $0x0,%al
#  726:	00 00                	add    %al,(%rax)
#  728:	00 00                	add    %al,(%rax)
#  72a:	00 01                	add    %al,(%rcx)
#  72c:	00 5d 8f             	add    %bl,-0x71(%rbp)
#  72f:	14 00                	adc    $0x0,%al
#  731:	00 00                	add    %al,(%rax)
#  733:	00 00                	add    %al,(%rax)
#  735:	00 a7 14 00 00 00    	add    %ah,0x14(%rdi)
#  73b:	00 00                	add    %al,(%rax)
#  73d:	00 01                	add    %al,(%rcx)
#  73f:	00 52 a7             	add    %dl,-0x59(%rdx)
#  742:	14 00                	adc    $0x0,%al
#  744:	00 00                	add    %al,(%rax)
#  746:	00 00                	add    %al,(%rax)
#  748:	00 a8 14 00 00 00    	add    %ch,0x14(%rax)
#  74e:	00 00                	add    %al,(%rax)
#  750:	00 03                	add    %al,(%rbx)
#  752:	00 7d 7f             	add    %bh,0x7f(%rbp)
#  755:	9f                   	lahf
#  756:	a8 14                	test   $0x14,%al
#  758:	00 00                	add    %al,(%rax)
#  75a:	00 00                	add    %al,(%rax)
#  75c:	00 00                	add    %al,(%rax)
#  75e:	c2 14 00             	ret    $0x14
#  761:	00 00                	add    %al,(%rax)
#  763:	00 00                	add    %al,(%rax)
#  765:	00 01                	add    %al,(%rcx)
#  767:	00 5d 05             	add    %bl,0x5(%rbp)
#  76a:	15 00 00 00 00       	adc    $0x0,%eax
#  76f:	00 00                	add    %al,(%rax)
#  771:	26 15 00 00 00 00    	es adc $0x0,%eax
#  777:	00 00                	add    %al,(%rax)
#  779:	02 00                	add    (%rax),%al
#  77b:	30 9f 00 00 00 00    	xor    %bl,0x0(%rdi)
# 	...
#  78d:	02 00                	add    (%rax),%al
#  78f:	00 00                	add    %al,(%rax)
#  791:	00 00                	add    %al,(%rax)
#  793:	00 00                	add    %al,(%rax)
#  795:	e4 10                	in     $0x10,%al
#  797:	00 00                	add    %al,(%rax)
#  799:	00 00                	add    %al,(%rax)
#  79b:	00 00                	add    %al,(%rax)
#  79d:	0a 11                	or     (%rcx),%dl
#  79f:	00 00                	add    %al,(%rax)
#  7a1:	00 00                	add    %al,(%rax)
#  7a3:	00 00                	add    %al,(%rax)
#  7a5:	02 00                	add    (%rax),%al
#  7a7:	30 9f 26 15 00 00    	xor    %bl,0x1526(%rdi)
#  7ad:	00 00                	add    %al,(%rax)
#  7af:	00 00                	add    %al,(%rax)
#  7b1:	5e                   	pop    %rsi
#  7b2:	15 00 00 00 00       	adc    $0x0,%eax
#  7b7:	00 00                	add    %al,(%rax)
#  7b9:	02 00                	add    (%rax),%al
#  7bb:	30 9f 5e 15 00 00    	xor    %bl,0x155e(%rdi)
#  7c1:	00 00                	add    %al,(%rax)
#  7c3:	00 00                	add    %al,(%rax)
#  7c5:	72 15                	jb     7dc <_init-0x824>
#  7c7:	00 00                	add    %al,(%rax)
#  7c9:	00 00                	add    %al,(%rax)
#  7cb:	00 00                	add    %al,(%rax)
#  7cd:	01 00                	add    %eax,(%rax)
#  7cf:	50                   	push   %rax
#  7d0:	92                   	xchg   %eax,%edx
#  7d1:	15 00 00 00 00       	adc    $0x0,%eax
#  7d6:	00 00                	add    %al,(%rax)
#  7d8:	9e                   	sahf
#  7d9:	15 00 00 00 00       	adc    $0x0,%eax
#  7de:	00 00                	add    %al,(%rax)
#  7e0:	01 00                	add    %eax,(%rax)
#  7e2:	50                   	push   %rax
# 	...
#  7f3:	02 00                	add    (%rax),%al
# 	...
#  801:	e4 10                	in     $0x10,%al
#  803:	00 00                	add    %al,(%rax)
#  805:	00 00                	add    %al,(%rax)
#  807:	00 00                	add    %al,(%rax)
#  809:	0a 11                	or     (%rcx),%dl
#  80b:	00 00                	add    %al,(%rax)
#  80d:	00 00                	add    %al,(%rax)
#  80f:	00 00                	add    %al,(%rax)
#  811:	02 00                	add    (%rax),%al
#  813:	31 9f 0a 11 00 00    	xor    %ebx,0x110a(%rdi)
#  819:	00 00                	add    %al,(%rax)
#  81b:	00 00                	add    %al,(%rax)
#  81d:	57                   	push   %rdi
#  81e:	12 00                	adc    (%rax),%al
#  820:	00 00                	add    %al,(%rax)
#  822:	00 00                	add    %al,(%rax)
#  824:	00 02                	add    %al,(%rdx)
#  826:	00 77 00             	add    %dh,0x0(%rdi)
#  829:	1e                   	(bad)
#  82a:	13 00                	adc    (%rax),%eax
#  82c:	00 00                	add    %al,(%rax)
#  82e:	00 00                	add    %al,(%rax)
#  830:	00 2a                	add    %ch,(%rdx)
#  832:	13 00                	adc    (%rax),%eax
#  834:	00 00                	add    %al,(%rax)
#  836:	00 00                	add    %al,(%rax)
#  838:	00 02                	add    %al,(%rdx)
#  83a:	00 77 00             	add    %dh,0x0(%rdi)
#  83d:	26 15 00 00 00 00    	es adc $0x0,%eax
#  843:	00 00                	add    %al,(%rax)
#  845:	76 15                	jbe    85c <_init-0x7a4>
#  847:	00 00                	add    %al,(%rax)
#  849:	00 00                	add    %al,(%rax)
#  84b:	00 00                	add    %al,(%rax)
#  84d:	02 00                	add    (%rax),%al
#  84f:	31 9f 76 15 00 00    	xor    %ebx,0x1576(%rdi)
#  855:	00 00                	add    %al,(%rax)
#  857:	00 00                	add    %al,(%rax)
#  859:	7b 15                	jnp    870 <_init-0x790>
#  85b:	00 00                	add    %al,(%rax)
#  85d:	00 00                	add    %al,(%rax)
#  85f:	00 00                	add    %al,(%rax)
#  861:	01 00                	add    %eax,(%rax)
#  863:	50                   	push   %rax
#  864:	7b 15                	jnp    87b <_init-0x785>
#  866:	00 00                	add    %al,(%rax)
#  868:	00 00                	add    %al,(%rax)
#  86a:	00 00                	add    %al,(%rax)
#  86c:	92                   	xchg   %eax,%edx
#  86d:	15 00 00 00 00       	adc    $0x0,%eax
#  872:	00 00                	add    %al,(%rax)
#  874:	02 00                	add    (%rax),%al
#  876:	77 00                	ja     878 <_init-0x788>
#  878:	92                   	xchg   %eax,%edx
#  879:	15 00 00 00 00       	adc    $0x0,%eax
#  87e:	00 00                	add    %al,(%rax)
#  880:	9e                   	sahf
#  881:	15 00 00 00 00       	adc    $0x0,%eax
#  886:	00 00                	add    %al,(%rax)
#  888:	02 00                	add    (%rax),%al
#  88a:	31 9f 00 00 00 00    	xor    %ebx,0x0(%rdi)
# 	...
#  89c:	02 00                	add    (%rax),%al
#  89e:	97                   	xchg   %eax,%edi
#  89f:	14 00                	adc    $0x0,%al
#  8a1:	00 00                	add    %al,(%rax)
#  8a3:	00 00                	add    %al,(%rax)
#  8a5:	00 a8 14 00 00 00    	add    %ch,0x14(%rax)
#  8ab:	00 00                	add    %al,(%rax)
#  8ad:	00 0a                	add    %cl,(%rdx)
#  8af:	00 03                	add    %al,(%rbx)
#  8b1:	04 20                	add    $0x20,%al
#  8b3:	00 00                	add    %al,(%rax)
#  8b5:	00 00                	add    %al,(%rax)
#  8b7:	00 00                	add    %al,(%rax)
#  8b9:	9f                   	lahf
# 	...
#  8ca:	00 00                	add    %al,(%rax)
#  8cc:	e5 12                	in     $0x12,%eax
#  8ce:	00 00                	add    %al,(%rax)
#  8d0:	00 00                	add    %al,(%rax)
#  8d2:	00 00                	add    %al,(%rax)
#  8d4:	0d 13 00 00 00       	or     $0x13,%eax
#  8d9:	00 00                	add    %al,(%rax)
#  8db:	00 0a                	add    %cl,(%rdx)
#  8dd:	00 03                	add    %al,(%rbx)
#  8df:	2b 20                	sub    (%rax),%esp
#  8e1:	00 00                	add    %al,(%rax)
#  8e3:	00 00                	add    %al,(%rax)
#  8e5:	00 00                	add    %al,(%rax)
#  8e7:	9f                   	lahf
# 	...
#  8f8:	01 00                	add    %eax,(%rax)
#  8fa:	c5 13 00             	(bad)
#  8fd:	00 00                	add    %al,(%rax)
#  8ff:	00 00                	add    %al,(%rax)
#  901:	00 e1                	add    %ah,%cl
#  903:	13 00                	adc    (%rax),%eax
#  905:	00 00                	add    %al,(%rax)
#  907:	00 00                	add    %al,(%rax)
#  909:	00 0a                	add    %cl,(%rdx)
#  90b:	00 03                	add    %al,(%rbx)
#  90d:	1f                   	(bad)
#  90e:	20 00                	and    %al,(%rax)
#  910:	00 00                	add    %al,(%rax)
#  912:	00 00                	add    %al,(%rax)
#  914:	00 9f 00 00 00 00    	add    %bl,0x0(%rdi)
# 	...
#  926:	02 00                	add    (%rax),%al
#  928:	2e 14 00             	cs adc $0x0,%al
#  92b:	00 00                	add    %al,(%rax)
#  92d:	00 00                	add    %al,(%rax)
#  92f:	00 41 14             	add    %al,0x14(%rcx)
#  932:	00 00                	add    %al,(%rax)
#  934:	00 00                	add    %al,(%rax)
#  936:	00 00                	add    %al,(%rax)
#  938:	0a 00                	or     (%rax),%al
#  93a:	03 04 20             	add    (%rax,%riz,1),%eax
#  93d:	00 00                	add    %al,(%rax)
#  93f:	00 00                	add    %al,(%rax)
#  941:	00 00                	add    %al,(%rax)
#  943:	9f                   	lahf
# 	...
#  954:	02 00                	add    (%rax),%al
#  956:	c2 14 00             	ret    $0x14
#  959:	00 00                	add    %al,(%rax)
#  95b:	00 00                	add    %al,(%rax)
#  95d:	00 e9                	add    %ch,%cl
#  95f:	14 00                	adc    $0x0,%al
#  961:	00 00                	add    %al,(%rax)
#  963:	00 00                	add    %al,(%rax)
#  965:	00 0a                	add    %cl,(%rdx)
#  967:	00 03                	add    %al,(%rbx)
#  969:	1f                   	(bad)
#  96a:	20 00                	and    %al,(%rax)
#  96c:	00 00                	add    %al,(%rax)
#  96e:	00 00                	add    %al,(%rax)
#  970:	00 9f 00 00 00 00    	add    %bl,0x0(%rdi)
# 	...
#  982:	01 00                	add    %eax,(%rax)
#  984:	2f                   	(bad)
#  985:	15 00 00 00 00       	adc    $0x0,%eax
#  98a:	00 00                	add    %al,(%rax)
#  98c:	3a 15 00 00 00 00    	cmp    0x0(%rip),%dl        # 992 <_init-0x66e>
#  992:	00 00                	add    %al,(%rax)
#  994:	01 00                	add    %eax,(%rax)
#  996:	55                   	push   %rbp
# 	...
#  9a7:	01 00                	add    %eax,(%rax)
#  9a9:	4a 15 00 00 00 00    	rex.WX adc $0x0,%rax
#  9af:	00 00                	add    %al,(%rax)
#  9b1:	59                   	pop    %rcx
#  9b2:	15 00 00 00 00       	adc    $0x0,%eax
#  9b7:	00 00                	add    %al,(%rax)
#  9b9:	02 00                	add    (%rax),%al
#  9bb:	76 10                	jbe    9cd <_init-0x633>
# 	...
#  9cd:	01 00                	add    %eax,(%rax)
#  9cf:	63 15 00 00 00 00    	movsxd 0x0(%rip),%edx        # 9d5 <_init-0x62b>
#  9d5:	00 00                	add    %al,(%rax)
#  9d7:	72 15                	jb     9ee <_init-0x612>
#  9d9:	00 00                	add    %al,(%rax)
#  9db:	00 00                	add    %al,(%rax)
#  9dd:	00 00                	add    %al,(%rax)
#  9df:	02 00                	add    (%rax),%al
#  9e1:	76 18                	jbe    9fb <_init-0x605>
# 	...
#
# Disassembly of section .debug_ranges:
#
# 0000000000000000 <.debug_ranges>:
#    0:	50                   	push   %rax
#    1:	12 00                	adc    (%rax),%al
#    3:	00 00                	add    %al,(%rax)
#    5:	00 00                	add    %al,(%rax)
#    7:	00 64 12 00          	add    %ah,0x0(%rdx,%rdx,1)
#    b:	00 00                	add    %al,(%rax)
#    d:	00 00                	add    %al,(%rax)
#    f:	00 72 14             	add    %dh,0x14(%rdx)
#   12:	00 00                	add    %al,(%rax)
#   14:	00 00                	add    %al,(%rax)
#   16:	00 00                	add    %al,(%rax)
#   18:	8b 14 00             	mov    (%rax,%rax,1),%edx
#   1b:	00 00                	add    %al,(%rax)
#   1d:	00 00                	add    %al,(%rax)
#   1f:	00 97 14 00 00 00    	add    %dl,0x14(%rdi)
#   25:	00 00                	add    %al,(%rax)
#   27:	00 97 14 00 00 00    	add    %dl,0x14(%rdi)
#   2d:	00 00                	add    %al,(%rax)
#   2f:	00 9d 14 00 00 00    	add    %bl,0x14(%rbp)
#   35:	00 00                	add    %al,(%rax)
#   37:	00 a8 14 00 00 00    	add    %ch,0x14(%rax)
# 	...
#   4d:	00 00                	add    %al,(%rax)
#   4f:	00 e5                	add    %ah,%ch
#   51:	12 00                	adc    (%rax),%al
#   53:	00 00                	add    %al,(%rax)
#   55:	00 00                	add    %al,(%rax)
#   57:	00 f1                	add    %dh,%cl
#   59:	12 00                	adc    (%rax),%al
#   5b:	00 00                	add    %al,(%rax)
#   5d:	00 00                	add    %al,(%rax)
#   5f:	00 f8                	add    %bh,%al
#   61:	12 00                	adc    (%rax),%al
#   63:	00 00                	add    %al,(%rax)
#   65:	00 00                	add    %al,(%rax)
#   67:	00 fd                	add    %bh,%ch
#   69:	12 00                	adc    (%rax),%al
#   6b:	00 00                	add    %al,(%rax)
#   6d:	00 00                	add    %al,(%rax)
#   6f:	00 00                	add    %al,(%rax)
#   71:	13 00                	adc    (%rax),%eax
#   73:	00 00                	add    %al,(%rax)
#   75:	00 00                	add    %al,(%rax)
#   77:	00 0d 13 00 00 00    	add    %cl,0x13(%rip)        # 90 <_init-0xf70>
# 	...
#   8d:	00 00                	add    %al,(%rax)
#   8f:	00 fb                	add    %bh,%bl
#   91:	13 00                	adc    (%rax),%eax
#   93:	00 00                	add    %al,(%rax)
#   95:	00 00                	add    %al,(%rax)
#   97:	00 10                	add    %dl,(%rax)
#   99:	14 00                	adc    $0x0,%al
#   9b:	00 00                	add    %al,(%rax)
#   9d:	00 00                	add    %al,(%rax)
#   9f:	00 16                	add    %dl,(%rsi)
#   a1:	14 00                	adc    $0x0,%al
#   a3:	00 00                	add    %al,(%rax)
#   a5:	00 00                	add    %al,(%rax)
#   a7:	00 1f                	add    %bl,(%rdi)
#   a9:	14 00                	adc    $0x0,%al
#   ab:	00 00                	add    %al,(%rax)
#   ad:	00 00                	add    %al,(%rax)
#   af:	00 2e                	add    %ch,(%rsi)
#   b1:	14 00                	adc    $0x0,%al
#   b3:	00 00                	add    %al,(%rax)
#   b5:	00 00                	add    %al,(%rax)
#   b7:	00 2e                	add    %ch,(%rsi)
#   b9:	14 00                	adc    $0x0,%al
#   bb:	00 00                	add    %al,(%rax)
#   bd:	00 00                	add    %al,(%rax)
#   bf:	00 34 14             	add    %dh,(%rsp,%rdx,1)
#   c2:	00 00                	add    %al,(%rax)
#   c4:	00 00                	add    %al,(%rax)
#   c6:	00 00                	add    %al,(%rax)
#   c8:	41 14 00             	rex.B adc $0x0,%al
# 	...
#   df:	00 28                	add    %ch,(%rax)
#   e1:	15 00 00 00 00       	adc    $0x0,%eax
#   e6:	00 00                	add    %al,(%rax)
#   e8:	2f                   	(bad)
#   e9:	15 00 00 00 00       	adc    $0x0,%eax
#   ee:	00 00                	add    %al,(%rax)
#   f0:	2f                   	(bad)
#   f1:	15 00 00 00 00       	adc    $0x0,%eax
#   f6:	00 00                	add    %al,(%rax)
#   f8:	41 15 00 00 00 00    	rex.B adc $0x0,%eax
# 	...
#  10e:	00 00                	add    %al,(%rax)
#  110:	e0 10                	loopne 122 <_init-0xede>
#  112:	00 00                	add    %al,(%rax)
#  114:	00 00                	add    %al,(%rax)
#  116:	00 00                	add    %al,(%rax)
#  118:	9e                   	sahf
#  119:	15 00 00 00 00       	adc    $0x0,%eax
# 	...

# %% [markdown]
# ## How blocks are stored in a cache?
#
# How these address are stored "if" they're in a direct-mapped, 16B-sized blocks, 16-block cache?

# %%
! cd mv; make clean; make; ./matvec 16 1
# Out:
# rm -f matvec
# cc -DHAVE_LINUX_PERF_EVENT_H -g -O3  matvec.c -o matvec
# &a[0][0], 0x55b4d818d330
# &b[0], 0x55b4d818dc30
# &a[0][1], 0x55b4d818d338
# &b[1], 0x55b4d818dc38
# &a[0][2], 0x55b4d818d340
# &b[2], 0x55b4d818dc40
# &a[0][3], 0x55b4d818d348
# &b[3], 0x55b4d818dc48
# &a[0][4], 0x55b4d818d350
# &b[4], 0x55b4d818dc50
# &a[0][5], 0x55b4d818d358
# &b[5], 0x55b4d818dc58
# &a[0][6], 0x55b4d818d360
# &b[6], 0x55b4d818dc60
# &a[0][7], 0x55b4d818d368
# &b[7], 0x55b4d818dc68
# &a[0][8], 0x55b4d818d370
# &b[8], 0x55b4d818dc70
# &a[0][9], 0x55b4d818d378
# &b[9], 0x55b4d818dc78
# &a[0][10], 0x55b4d818d380
# &b[10], 0x55b4d818dc80
# &a[0][11], 0x55b4d818d388
# &b[11], 0x55b4d818dc88
# &a[0][12], 0x55b4d818d390
# &b[12], 0x55b4d818dc90
# &a[0][13], 0x55b4d818d398
# &b[13], 0x55b4d818dc98
# &a[0][14], 0x55b4d818d3a0
# &b[14], 0x55b4d818dca0
# &a[0][15], 0x55b4d818d3a8
# &b[15], 0x55b4d818dca8
# &c[0], 0x55b4d818dcc0
# &a[1][0], 0x55b4d818d3c0
# &b[0], 0x55b4d818dc30
# &a[1][1], 0x55b4d818d3c8
# &b[1], 0x55b4d818dc38
# &a[1][2], 0x55b4d818d3d0
# &b[2], 0x55b4d818dc40
# &a[1][3], 0x55b4d818d3d8
# &b[3], 0x55b4d818dc48
# &a[1][4], 0x55b4d818d3e0
# &b[4], 0x55b4d818dc50
# &a[1][5], 0x55b4d818d3e8
# &b[5], 0x55b4d818dc58
# &a[1][6], 0x55b4d818d3f0
# &b[6], 0x55b4d818dc60
# &a[1][7], 0x55b4d818d3f8
# &b[7], 0x55b4d818dc68
# &a[1][8], 0x55b4d818d400
# &b[8], 0x55b4d818dc70
# &a[1][9], 0x55b4d818d408
# &b[9], 0x55b4d818dc78
# &a[1][10], 0x55b4d818d410
# &b[10], 0x55b4d818dc80
# &a[1][11], 0x55b4d818d418
# &b[11], 0x55b4d818dc88
# &a[1][12], 0x55b4d818d420
# &b[12], 0x55b4d818dc90
# &a[1][13], 0x55b4d818d428
# &b[13], 0x55b4d818dc98
# &a[1][14], 0x55b4d818d430
# &b[14], 0x55b4d818dca0
# &a[1][15], 0x55b4d818d438
# &b[15], 0x55b4d818dca8
# &c[1], 0x55b4d818dcc8
# &a[2][0], 0x55b4d818d450
# &b[0], 0x55b4d818dc30
# &a[2][1], 0x55b4d818d458
# &b[1], 0x55b4d818dc38
# &a[2][2], 0x55b4d818d460
# &b[2], 0x55b4d818dc40
# &a[2][3], 0x55b4d818d468
# &b[3], 0x55b4d818dc48
# &a[2][4], 0x55b4d818d470
# &b[4], 0x55b4d818dc50
# &a[2][5], 0x55b4d818d478
# &b[5], 0x55b4d818dc58
# &a[2][6], 0x55b4d818d480
# &b[6], 0x55b4d818dc60
# &a[2][7], 0x55b4d818d488
# &b[7], 0x55b4d818dc68
# &a[2][8], 0x55b4d818d490
# &b[8], 0x55b4d818dc70
# &a[2][9], 0x55b4d818d498
# &b[9], 0x55b4d818dc78
# &a[2][10], 0x55b4d818d4a0
# &b[10], 0x55b4d818dc80
# &a[2][11], 0x55b4d818d4a8
# &b[11], 0x55b4d818dc88
# &a[2][12], 0x55b4d818d4b0
# &b[12], 0x55b4d818dc90
# &a[2][13], 0x55b4d818d4b8
# &b[13], 0x55b4d818dc98
# &a[2][14], 0x55b4d818d4c0
# &b[14], 0x55b4d818dca0
# &a[2][15], 0x55b4d818d4c8
# &b[15], 0x55b4d818dca8
# &c[2], 0x55b4d818dcd0
# &a[3][0], 0x55b4d818d4e0
# &b[0], 0x55b4d818dc30
# &a[3][1], 0x55b4d818d4e8
# &b[1], 0x55b4d818dc38
# &a[3][2], 0x55b4d818d4f0
# &b[2], 0x55b4d818dc40
# &a[3][3], 0x55b4d818d4f8
# &b[3], 0x55b4d818dc48
# &a[3][4], 0x55b4d818d500
# &b[4], 0x55b4d818dc50
# &a[3][5], 0x55b4d818d508
# &b[5], 0x55b4d818dc58
# &a[3][6], 0x55b4d818d510
# &b[6], 0x55b4d818dc60
# &a[3][7], 0x55b4d818d518
# &b[7], 0x55b4d818dc68
# &a[3][8], 0x55b4d818d520
# &b[8], 0x55b4d818dc70
# &a[3][9], 0x55b4d818d528
# &b[9], 0x55b4d818dc78
# &a[3][10], 0x55b4d818d530
# &b[10], 0x55b4d818dc80
# &a[3][11], 0x55b4d818d538
# &b[11], 0x55b4d818dc88
# &a[3][12], 0x55b4d818d540
# &b[12], 0x55b4d818dc90
# &a[3][13], 0x55b4d818d548
# &b[13], 0x55b4d818dc98
# &a[3][14], 0x55b4d818d550
# &b[14], 0x55b4d818dca0
# &a[3][15], 0x55b4d818d558
# &b[15], 0x55b4d818dca8
# &c[3], 0x55b4d818dcd8
# &a[4][0], 0x55b4d818d570
# &b[0], 0x55b4d818dc30
# &a[4][1], 0x55b4d818d578
# &b[1], 0x55b4d818dc38
# &a[4][2], 0x55b4d818d580
# &b[2], 0x55b4d818dc40
# &a[4][3], 0x55b4d818d588
# &b[3], 0x55b4d818dc48
# &a[4][4], 0x55b4d818d590
# &b[4], 0x55b4d818dc50
# &a[4][5], 0x55b4d818d598
# &b[5], 0x55b4d818dc58
# &a[4][6], 0x55b4d818d5a0
# &b[6], 0x55b4d818dc60
# &a[4][7], 0x55b4d818d5a8
# &b[7], 0x55b4d818dc68
# &a[4][8], 0x55b4d818d5b0
# &b[8], 0x55b4d818dc70
# &a[4][9], 0x55b4d818d5b8
# &b[9], 0x55b4d818dc78
# &a[4][10], 0x55b4d818d5c0
# &b[10], 0x55b4d818dc80
# &a[4][11], 0x55b4d818d5c8
# &b[11], 0x55b4d818dc88
# &a[4][12], 0x55b4d818d5d0
# &b[12], 0x55b4d818dc90
# &a[4][13], 0x55b4d818d5d8
# &b[13], 0x55b4d818dc98
# &a[4][14], 0x55b4d818d5e0
# &b[14], 0x55b4d818dca0
# &a[4][15], 0x55b4d818d5e8
# &b[15], 0x55b4d818dca8
# &c[4], 0x55b4d818dce0
# &a[5][0], 0x55b4d818d600
# &b[0], 0x55b4d818dc30
# &a[5][1], 0x55b4d818d608
# &b[1], 0x55b4d818dc38
# &a[5][2], 0x55b4d818d610
# &b[2], 0x55b4d818dc40
# &a[5][3], 0x55b4d818d618
# &b[3], 0x55b4d818dc48
# &a[5][4], 0x55b4d818d620
# &b[4], 0x55b4d818dc50
# &a[5][5], 0x55b4d818d628
# &b[5], 0x55b4d818dc58
# &a[5][6], 0x55b4d818d630
# &b[6], 0x55b4d818dc60
# &a[5][7], 0x55b4d818d638
# &b[7], 0x55b4d818dc68
# &a[5][8], 0x55b4d818d640
# &b[8], 0x55b4d818dc70
# &a[5][9], 0x55b4d818d648
# &b[9], 0x55b4d818dc78
# &a[5][10], 0x55b4d818d650
# &b[10], 0x55b4d818dc80
# &a[5][11], 0x55b4d818d658
# &b[11], 0x55b4d818dc88
# &a[5][12], 0x55b4d818d660
# &b[12], 0x55b4d818dc90
# &a[5][13], 0x55b4d818d668
# &b[13], 0x55b4d818dc98
# &a[5][14], 0x55b4d818d670
# &b[14], 0x55b4d818dca0
# &a[5][15], 0x55b4d818d678
# &b[15], 0x55b4d818dca8
# &c[5], 0x55b4d818dce8
# &a[6][0], 0x55b4d818d690
# &b[0], 0x55b4d818dc30
# &a[6][1], 0x55b4d818d698
# &b[1], 0x55b4d818dc38
# &a[6][2], 0x55b4d818d6a0
# &b[2], 0x55b4d818dc40
# &a[6][3], 0x55b4d818d6a8
# &b[3], 0x55b4d818dc48
# &a[6][4], 0x55b4d818d6b0
# &b[4], 0x55b4d818dc50
# &a[6][5], 0x55b4d818d6b8
# &b[5], 0x55b4d818dc58
# &a[6][6], 0x55b4d818d6c0
# &b[6], 0x55b4d818dc60
# &a[6][7], 0x55b4d818d6c8
# &b[7], 0x55b4d818dc68
# &a[6][8], 0x55b4d818d6d0
# &b[8], 0x55b4d818dc70
# &a[6][9], 0x55b4d818d6d8
# &b[9], 0x55b4d818dc78
# &a[6][10], 0x55b4d818d6e0
# &b[10], 0x55b4d818dc80
# &a[6][11], 0x55b4d818d6e8
# &b[11], 0x55b4d818dc88
# &a[6][12], 0x55b4d818d6f0
# &b[12], 0x55b4d818dc90
# &a[6][13], 0x55b4d818d6f8
# &b[13], 0x55b4d818dc98
# &a[6][14], 0x55b4d818d700
# &b[14], 0x55b4d818dca0
# &a[6][15], 0x55b4d818d708
# &b[15], 0x55b4d818dca8
# &c[6], 0x55b4d818dcf0
# &a[7][0], 0x55b4d818d720
# &b[0], 0x55b4d818dc30
# &a[7][1], 0x55b4d818d728
# &b[1], 0x55b4d818dc38
# &a[7][2], 0x55b4d818d730
# &b[2], 0x55b4d818dc40
# &a[7][3], 0x55b4d818d738
# &b[3], 0x55b4d818dc48
# &a[7][4], 0x55b4d818d740
# &b[4], 0x55b4d818dc50
# &a[7][5], 0x55b4d818d748
# &b[5], 0x55b4d818dc58
# &a[7][6], 0x55b4d818d750
# &b[6], 0x55b4d818dc60
# &a[7][7], 0x55b4d818d758
# &b[7], 0x55b4d818dc68
# &a[7][8], 0x55b4d818d760
# &b[8], 0x55b4d818dc70
# &a[7][9], 0x55b4d818d768
# &b[9], 0x55b4d818dc78
# &a[7][10], 0x55b4d818d770
# &b[10], 0x55b4d818dc80
# &a[7][11], 0x55b4d818d778
# &b[11], 0x55b4d818dc88
# &a[7][12], 0x55b4d818d780
# &b[12], 0x55b4d818dc90
# &a[7][13], 0x55b4d818d788
# &b[13], 0x55b4d818dc98
# &a[7][14], 0x55b4d818d790
# &b[14], 0x55b4d818dca0
# &a[7][15], 0x55b4d818d798
# &b[15], 0x55b4d818dca8
# &c[7], 0x55b4d818dcf8
# &a[8][0], 0x55b4d818d7b0
# &b[0], 0x55b4d818dc30
# &a[8][1], 0x55b4d818d7b8
# &b[1], 0x55b4d818dc38
# &a[8][2], 0x55b4d818d7c0
# &b[2], 0x55b4d818dc40
# &a[8][3], 0x55b4d818d7c8
# &b[3], 0x55b4d818dc48
# &a[8][4], 0x55b4d818d7d0
# &b[4], 0x55b4d818dc50
# &a[8][5], 0x55b4d818d7d8
# &b[5], 0x55b4d818dc58
# &a[8][6], 0x55b4d818d7e0
# &b[6], 0x55b4d818dc60
# &a[8][7], 0x55b4d818d7e8
# &b[7], 0x55b4d818dc68
# &a[8][8], 0x55b4d818d7f0
# &b[8], 0x55b4d818dc70
# &a[8][9], 0x55b4d818d7f8
# &b[9], 0x55b4d818dc78
# &a[8][10], 0x55b4d818d800
# &b[10], 0x55b4d818dc80
# &a[8][11], 0x55b4d818d808
# &b[11], 0x55b4d818dc88
# &a[8][12], 0x55b4d818d810
# &b[12], 0x55b4d818dc90
# &a[8][13], 0x55b4d818d818
# &b[13], 0x55b4d818dc98
# &a[8][14], 0x55b4d818d820
# &b[14], 0x55b4d818dca0
# &a[8][15], 0x55b4d818d828
# &b[15], 0x55b4d818dca8
# &c[8], 0x55b4d818dd00
# &a[9][0], 0x55b4d818d840
# &b[0], 0x55b4d818dc30
# &a[9][1], 0x55b4d818d848
# &b[1], 0x55b4d818dc38
# &a[9][2], 0x55b4d818d850
# &b[2], 0x55b4d818dc40
# &a[9][3], 0x55b4d818d858
# &b[3], 0x55b4d818dc48
# &a[9][4], 0x55b4d818d860
# &b[4], 0x55b4d818dc50
# &a[9][5], 0x55b4d818d868
# &b[5], 0x55b4d818dc58
# &a[9][6], 0x55b4d818d870
# &b[6], 0x55b4d818dc60
# &a[9][7], 0x55b4d818d878
# &b[7], 0x55b4d818dc68
# &a[9][8], 0x55b4d818d880
# &b[8], 0x55b4d818dc70
# &a[9][9], 0x55b4d818d888
# &b[9], 0x55b4d818dc78
# &a[9][10], 0x55b4d818d890
# &b[10], 0x55b4d818dc80
# &a[9][11], 0x55b4d818d898
# &b[11], 0x55b4d818dc88
# &a[9][12], 0x55b4d818d8a0
# &b[12], 0x55b4d818dc90
# &a[9][13], 0x55b4d818d8a8
# &b[13], 0x55b4d818dc98
# &a[9][14], 0x55b4d818d8b0
# &b[14], 0x55b4d818dca0
# &a[9][15], 0x55b4d818d8b8
# &b[15], 0x55b4d818dca8
# &c[9], 0x55b4d818dd08
# &a[10][0], 0x55b4d818d8d0
# &b[0], 0x55b4d818dc30
# &a[10][1], 0x55b4d818d8d8
# &b[1], 0x55b4d818dc38
# &a[10][2], 0x55b4d818d8e0
# &b[2], 0x55b4d818dc40
# &a[10][3], 0x55b4d818d8e8
# &b[3], 0x55b4d818dc48
# &a[10][4], 0x55b4d818d8f0
# &b[4], 0x55b4d818dc50
# &a[10][5], 0x55b4d818d8f8
# &b[5], 0x55b4d818dc58
# &a[10][6], 0x55b4d818d900
# &b[6], 0x55b4d818dc60
# &a[10][7], 0x55b4d818d908
# &b[7], 0x55b4d818dc68
# &a[10][8], 0x55b4d818d910
# &b[8], 0x55b4d818dc70
# &a[10][9], 0x55b4d818d918
# &b[9], 0x55b4d818dc78
# &a[10][10], 0x55b4d818d920
# &b[10], 0x55b4d818dc80
# &a[10][11], 0x55b4d818d928
# &b[11], 0x55b4d818dc88
# &a[10][12], 0x55b4d818d930
# &b[12], 0x55b4d818dc90
# &a[10][13], 0x55b4d818d938
# &b[13], 0x55b4d818dc98
# &a[10][14], 0x55b4d818d940
# &b[14], 0x55b4d818dca0
# &a[10][15], 0x55b4d818d948
# &b[15], 0x55b4d818dca8
# &c[10], 0x55b4d818dd10
# &a[11][0], 0x55b4d818d960
# &b[0], 0x55b4d818dc30
# &a[11][1], 0x55b4d818d968
# &b[1], 0x55b4d818dc38
# &a[11][2], 0x55b4d818d970
# &b[2], 0x55b4d818dc40
# &a[11][3], 0x55b4d818d978
# &b[3], 0x55b4d818dc48
# &a[11][4], 0x55b4d818d980
# &b[4], 0x55b4d818dc50
# &a[11][5], 0x55b4d818d988
# &b[5], 0x55b4d818dc58
# &a[11][6], 0x55b4d818d990
# &b[6], 0x55b4d818dc60
# &a[11][7], 0x55b4d818d998
# &b[7], 0x55b4d818dc68
# &a[11][8], 0x55b4d818d9a0
# &b[8], 0x55b4d818dc70
# &a[11][9], 0x55b4d818d9a8
# &b[9], 0x55b4d818dc78
# &a[11][10], 0x55b4d818d9b0
# &b[10], 0x55b4d818dc80
# &a[11][11], 0x55b4d818d9b8
# &b[11], 0x55b4d818dc88
# &a[11][12], 0x55b4d818d9c0
# &b[12], 0x55b4d818dc90
# &a[11][13], 0x55b4d818d9c8
# &b[13], 0x55b4d818dc98
# &a[11][14], 0x55b4d818d9d0
# &b[14], 0x55b4d818dca0
# &a[11][15], 0x55b4d818d9d8
# &b[15], 0x55b4d818dca8
# &c[11], 0x55b4d818dd18
# &a[12][0], 0x55b4d818d9f0
# &b[0], 0x55b4d818dc30
# &a[12][1], 0x55b4d818d9f8
# &b[1], 0x55b4d818dc38
# &a[12][2], 0x55b4d818da00
# &b[2], 0x55b4d818dc40
# &a[12][3], 0x55b4d818da08
# &b[3], 0x55b4d818dc48
# &a[12][4], 0x55b4d818da10
# &b[4], 0x55b4d818dc50
# &a[12][5], 0x55b4d818da18
# &b[5], 0x55b4d818dc58
# &a[12][6], 0x55b4d818da20
# &b[6], 0x55b4d818dc60
# &a[12][7], 0x55b4d818da28
# &b[7], 0x55b4d818dc68
# &a[12][8], 0x55b4d818da30
# &b[8], 0x55b4d818dc70
# &a[12][9], 0x55b4d818da38
# &b[9], 0x55b4d818dc78
# &a[12][10], 0x55b4d818da40
# &b[10], 0x55b4d818dc80
# &a[12][11], 0x55b4d818da48
# &b[11], 0x55b4d818dc88
# &a[12][12], 0x55b4d818da50
# &b[12], 0x55b4d818dc90
# &a[12][13], 0x55b4d818da58
# &b[13], 0x55b4d818dc98
# &a[12][14], 0x55b4d818da60
# &b[14], 0x55b4d818dca0
# &a[12][15], 0x55b4d818da68
# &b[15], 0x55b4d818dca8
# &c[12], 0x55b4d818dd20
# &a[13][0], 0x55b4d818da80
# &b[0], 0x55b4d818dc30
# &a[13][1], 0x55b4d818da88
# &b[1], 0x55b4d818dc38
# &a[13][2], 0x55b4d818da90
# &b[2], 0x55b4d818dc40
# &a[13][3], 0x55b4d818da98
# &b[3], 0x55b4d818dc48
# &a[13][4], 0x55b4d818daa0
# &b[4], 0x55b4d818dc50
# &a[13][5], 0x55b4d818daa8
# &b[5], 0x55b4d818dc58
# &a[13][6], 0x55b4d818dab0
# &b[6], 0x55b4d818dc60
# &a[13][7], 0x55b4d818dab8
# &b[7], 0x55b4d818dc68
# &a[13][8], 0x55b4d818dac0
# &b[8], 0x55b4d818dc70
# &a[13][9], 0x55b4d818dac8
# &b[9], 0x55b4d818dc78
# &a[13][10], 0x55b4d818dad0
# &b[10], 0x55b4d818dc80
# &a[13][11], 0x55b4d818dad8
# &b[11], 0x55b4d818dc88
# &a[13][12], 0x55b4d818dae0
# &b[12], 0x55b4d818dc90
# &a[13][13], 0x55b4d818dae8
# &b[13], 0x55b4d818dc98
# &a[13][14], 0x55b4d818daf0
# &b[14], 0x55b4d818dca0
# &a[13][15], 0x55b4d818daf8
# &b[15], 0x55b4d818dca8
# &c[13], 0x55b4d818dd28
# &a[14][0], 0x55b4d818db10
# &b[0], 0x55b4d818dc30
# &a[14][1], 0x55b4d818db18
# &b[1], 0x55b4d818dc38
# &a[14][2], 0x55b4d818db20
# &b[2], 0x55b4d818dc40
# &a[14][3], 0x55b4d818db28
# &b[3], 0x55b4d818dc48
# &a[14][4], 0x55b4d818db30
# &b[4], 0x55b4d818dc50
# &a[14][5], 0x55b4d818db38
# &b[5], 0x55b4d818dc58
# &a[14][6], 0x55b4d818db40
# &b[6], 0x55b4d818dc60
# &a[14][7], 0x55b4d818db48
# &b[7], 0x55b4d818dc68
# &a[14][8], 0x55b4d818db50
# &b[8], 0x55b4d818dc70
# &a[14][9], 0x55b4d818db58
# &b[9], 0x55b4d818dc78
# &a[14][10], 0x55b4d818db60
# &b[10], 0x55b4d818dc80
# &a[14][11], 0x55b4d818db68
# &b[11], 0x55b4d818dc88
# &a[14][12], 0x55b4d818db70
# &b[12], 0x55b4d818dc90
# &a[14][13], 0x55b4d818db78
# &b[13], 0x55b4d818dc98
# &a[14][14], 0x55b4d818db80
# &b[14], 0x55b4d818dca0
# &a[14][15], 0x55b4d818db88
# &b[15], 0x55b4d818dca8
# &c[14], 0x55b4d818dd30
# &a[15][0], 0x55b4d818dba0
# &b[0], 0x55b4d818dc30
# &a[15][1], 0x55b4d818dba8
# &b[1], 0x55b4d818dc38
# &a[15][2], 0x55b4d818dbb0
# &b[2], 0x55b4d818dc40
# &a[15][3], 0x55b4d818dbb8
# &b[3], 0x55b4d818dc48
# &a[15][4], 0x55b4d818dbc0
# &b[4], 0x55b4d818dc50
# &a[15][5], 0x55b4d818dbc8
# &b[5], 0x55b4d818dc58
# &a[15][6], 0x55b4d818dbd0
# &b[6], 0x55b4d818dc60
# &a[15][7], 0x55b4d818dbd8
# &b[7], 0x55b4d818dc68
# &a[15][8], 0x55b4d818dbe0
# &b[8], 0x55b4d818dc70
# &a[15][9], 0x55b4d818dbe8
# &b[9], 0x55b4d818dc78
# &a[15][10], 0x55b4d818dbf0
# &b[10], 0x55b4d818dc80
# &a[15][11], 0x55b4d818dbf8
# &b[11], 0x55b4d818dc88
# &a[15][12], 0x55b4d818dc00
# &b[12], 0x55b4d818dc90
# &a[15][13], 0x55b4d818dc08
# &b[13], 0x55b4d818dc98
# &a[15][14], 0x55b4d818dc10
# &b[14], 0x55b4d818dca0
# &a[15][15], 0x55b4d818dc18
# &b[15], 0x55b4d818dca8
# &c[15], 0x55b4d818dd38
# 28799.000000,22046

# %%
# !echo "element,address"> addresses.csv; ./mv/matvec 16 1 >> addresses.csv
df = pd.read_csv("addresses.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
block_size = 16
offset_bits = int(math.log2(block_size))
number_of_blocks = 16
index_bits = int(math.log2(number_of_blocks))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits) % number_of_blocks))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)
# Out:
# <style type="text/css">
# #T_83334_row0_col0, #T_83334_row0_col1, #T_83334_row0_col2, #T_83334_row0_col3, #T_83334_row1_col0, #T_83334_row1_col1, #T_83334_row1_col2, #T_83334_row1_col3, #T_83334_row2_col0, #T_83334_row2_col1, #T_83334_row2_col2, #T_83334_row2_col3, #T_83334_row3_col0, #T_83334_row3_col1, #T_83334_row3_col2, #T_83334_row3_col3, #T_83334_row4_col0, #T_83334_row4_col1, #T_83334_row4_col2, #T_83334_row4_col3, #T_83334_row5_col0, #T_83334_row5_col1, #T_83334_row5_col2, #T_83334_row5_col3, #T_83334_row6_col0, #T_83334_row6_col1, #T_83334_row6_col2, #T_83334_row6_col3, #T_83334_row7_col0, #T_83334_row7_col1, #T_83334_row7_col2, #T_83334_row7_col3, #T_83334_row8_col0, #T_83334_row8_col1, #T_83334_row8_col2, #T_83334_row8_col3, #T_83334_row9_col0, #T_83334_row9_col1, #T_83334_row9_col2, #T_83334_row9_col3, #T_83334_row10_col0, #T_83334_row10_col1, #T_83334_row10_col2, #T_83334_row10_col3, #T_83334_row11_col0, #T_83334_row11_col1, #T_83334_row11_col2, #T_83334_row11_col3, #T_83334_row12_col0, #T_83334_row12_col1, #T_83334_row12_col2, #T_83334_row12_col3, #T_83334_row13_col0, #T_83334_row13_col1, #T_83334_row13_col2, #T_83334_row13_col3, #T_83334_row14_col0, #T_83334_row14_col1, #T_83334_row14_col2, #T_83334_row14_col3, #T_83334_row15_col0, #T_83334_row15_col1, #T_83334_row15_col2, #T_83334_row15_col3, #T_83334_row16_col0, #T_83334_row16_col1, #T_83334_row16_col2, #T_83334_row16_col3, #T_83334_row17_col0, #T_83334_row17_col1, #T_83334_row17_col2, #T_83334_row17_col3, #T_83334_row18_col0, #T_83334_row18_col1, #T_83334_row18_col2, #T_83334_row18_col3, #T_83334_row19_col0, #T_83334_row19_col1, #T_83334_row19_col2, #T_83334_row19_col3, #T_83334_row20_col0, #T_83334_row20_col1, #T_83334_row20_col2, #T_83334_row20_col3, #T_83334_row21_col0, #T_83334_row21_col1, #T_83334_row21_col2, #T_83334_row21_col3, #T_83334_row22_col0, #T_83334_row22_col1, #T_83334_row22_col2, #T_83334_row22_col3, #T_83334_row23_col0, #T_83334_row23_col1, #T_83334_row23_col2, #T_83334_row23_col3, #T_83334_row24_col0, #T_83334_row24_col1, #T_83334_row24_col2, #T_83334_row24_col3, #T_83334_row25_col0, #T_83334_row25_col1, #T_83334_row25_col2, #T_83334_row25_col3, #T_83334_row26_col0, #T_83334_row26_col1, #T_83334_row26_col2, #T_83334_row26_col3, #T_83334_row27_col0, #T_83334_row27_col1, #T_83334_row27_col2, #T_83334_row27_col3, #T_83334_row28_col0, #T_83334_row28_col1, #T_83334_row28_col2, #T_83334_row28_col3, #T_83334_row29_col0, #T_83334_row29_col1, #T_83334_row29_col2, #T_83334_row29_col3, #T_83334_row30_col0, #T_83334_row30_col1, #T_83334_row30_col2, #T_83334_row30_col3, #T_83334_row31_col0, #T_83334_row31_col1, #T_83334_row31_col2, #T_83334_row31_col3, #T_83334_row32_col0, #T_83334_row32_col1, #T_83334_row32_col2, #T_83334_row32_col3, #T_83334_row33_col0, #T_83334_row33_col1, #T_83334_row33_col2, #T_83334_row33_col3, #T_83334_row34_col0, #T_83334_row34_col1, #T_83334_row34_col2, #T_83334_row34_col3, #T_83334_row35_col0, #T_83334_row35_col1, #T_83334_row35_col2, #T_83334_row35_col3, #T_83334_row36_col0, #T_83334_row36_col1, #T_83334_row36_col2, #T_83334_row36_col3, #T_83334_row37_col0, #T_83334_row37_col1, #T_83334_row37_col2, #T_83334_row37_col3, #T_83334_row38_col0, #T_83334_row38_col1, #T_83334_row38_col2, #T_83334_row38_col3, #T_83334_row39_col0, #T_83334_row39_col1, #T_83334_row39_col2, #T_83334_row39_col3, #T_83334_row40_col0, #T_83334_row40_col1, #T_83334_row40_col2, #T_83334_row40_col3, #T_83334_row41_col0, #T_83334_row41_col1, #T_83334_row41_col2, #T_83334_row41_col3, #T_83334_row42_col0, #T_83334_row42_col1, #T_83334_row42_col2, #T_83334_row42_col3, #T_83334_row43_col0, #T_83334_row43_col1, #T_83334_row43_col2, #T_83334_row43_col3, #T_83334_row44_col0, #T_83334_row44_col1, #T_83334_row44_col2, #T_83334_row44_col3, #T_83334_row45_col0, #T_83334_row45_col1, #T_83334_row45_col2, #T_83334_row45_col3, #T_83334_row46_col0, #T_83334_row46_col1, #T_83334_row46_col2, #T_83334_row46_col3, #T_83334_row47_col0, #T_83334_row47_col1, #T_83334_row47_col2, #T_83334_row47_col3, #T_83334 ...

# %% [markdown]
# What if we have a 2-way, 16-byte blocked, 16-block cache?

# %%
df = pd.read_csv("addresses.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
block_size = 16
offset_bits = int(math.log2(block_size))
number_of_blocks = 16
way_assoc=2
number_of_sets = number_of_blocks/way_assoc
index_bits = int(math.log2(number_of_sets))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits) % number_of_blocks))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)

# %% [markdown]
# ## Cache performance of code on "real machines"
#
# ### NVIDIA Jetson Nano -- Tegra X1

# %%
render_code("4way_madd/madd.c", show=["//START","//END"])
# Out:
# // 4way_madd/madd.c:55-67 (13 lines)
#     //START
#     for(i = 0; i < RUN_ARRAY_SIZE; i++)
#     {
#         e[i] = (a[i] * b[i] + c[i])/d[i];
# #ifdef DUMP
#         fprintf(stderr, "a[%d], %p\n",i,&a[i]);
#         fprintf(stderr, "b[%d], %p\n",i,&b[i]);
#         fprintf(stderr, "c[%d], %p\n",i,&c[i]);
#         fprintf(stderr, "d[%d], %p\n",i,&d[i]);
#         fprintf(stderr, "e[%d], %p\n",i,&e[i]);
# #endif
#     }
#   //END

# %% [markdown]
# Let's run it without the above loop code to figure the baseline memory accesses without running the loop on a Jetson nano.
#
# #### Run without the 4-way matrix add loop code.

# %%
# Run it "without" the above code.
! ssh htseng@nano-2 "lscpu; cd courses/CS203/demo/memory/4way_madd/; make clean madd_nano; valgrind --tool=cachegrind ./madd_nano 16384 0 "
# Out:
# Architecture:        aarch64
# Byte Order:          Little Endian
# CPU(s):              4
# On-line CPU(s) list: 0-3
# Thread(s) per core:  1
# Core(s) per socket:  4
# Socket(s):           1
# Vendor ID:           ARM
# Model:               1
# Model name:          Cortex-A57
# Stepping:            r1p1
# CPU max MHz:         1479.0000
# CPU min MHz:         102.0000
# BogoMIPS:            38.40
# L1d cache:           32K
# L1i cache:           48K
# L2 cache:            2048K
# Flags:               fp asimd evtstrm aes pmull sha1 sha2 crc32
# make: Warning: File 'Makefile' has modification time 20816 s in the future
# rm -f madd_intel madd_nano *_O3 *~ madd_A_fission cachegrind* *.perf madd_dump *.o
# cc -O3 -DHAVE_LINUX_PERF_EVENT_H -g -DNANO perfstats.c madd.c -o madd_nano
# make: warning:  Clock skew detected.  Your build may be incomplete.
# ==14267== Cachegrind, a cache and branch-prediction profiler
# ==14267== Copyright (C) 2002-2017, and GNU GPL'd, by Nicholas Nethercote et al.
# ==14267== Using Valgrind-3.13.0 and LibVEX; rerun with -h for copyright info
# ==14267== Command: ./madd_nano 16384 0
# ==14267==
# --14267-- Warning: Cannot auto-detect cache config, using defaults.
# --14267--          Run with -v to see.
# 2379360,2642878,1.110752,0.216809,0.000573,0.013930,23545,1690279
# ==14267==
# ==14267== I   refs:      6,825,671
# ==14267== I1  misses:        1,484
# ==14267== LLi misses:        1,277
# ==14267== I1  miss rate:      0.02%
# ==14267== LLi miss rate:      0.02%
# ==14267==
# ==14267== D   refs:      3,009,913  (1,847,750 rd   + 1,162,163 wr)
# ==14267== D1  misses:       13,793  (    2,865 rd   +    10,928 wr)
# ==14267== LLd misses:       13,035  (    2,179 rd   +    10,856 wr)
# ==14267== D1  miss rate:       0.5% (      0.2%     +       0.9%  )
# ==14267== LLd miss rate:       0.4% (      0.1%     +       0.9%  )
# ==14267==
# ==14267== LL refs:          15,277  (    4,349 rd   +    10,928 wr)
# ==14267== LL misses:        14,312  (    3,456 rd   +    10,856 wr)
# ==14267== LL miss rate:        0.1% (      0.0%     +       0.9%  )

# %% [markdown]
# Too much detail! Let's use grep to narrow down the outputs.

# %%
# Run it "without" the above code.
! ssh htseng@nano-2 "cd courses/CS203/demo/memory/4way_madd/; valgrind --tool=cachegrind ./madd_nano 16384 0 >& nano_without_loop.perf; grep 'D   refs\|D1' nano_without_loop.perf"
# Out:
# ==14322== D   refs:      3,009,912  (1,847,751 rd   + 1,162,161 wr)
# ==14322== D1  misses:       13,794  (    2,866 rd   +    10,928 wr)
# ==14322== D1  miss rate:       0.5% (      0.2%     +       0.9%  )

# %% [markdown]
# Let's run it with the above loop code again and observe the changes in L1 cache misses/accesses
#
# #### Run with the 4-way matrix add loop code.

# %%
! ssh htseng@nano-2 "cd courses/CS203/demo/memory/4way_madd/;valgrind --tool=cachegrind ./madd_nano 16384 8192 >& nano_with_loop.perf; grep 'D   refs\|D1' nano_with_loop.perf"
# Out:
# ==14376== D   refs:      3,030,476  (1,864,184 rd   + 1,166,292 wr)
# ==14376== D1  misses:       34,293  (   19,266 rd   +    15,027 wr)
# ==14376== D1  miss rate:       1.1% (      1.0%     +       1.3%  )

# %%
# Let's do some math here
total_number_of_accesses_before_the_loop =     3009912
total_number_of_accesses_after_the_loop =   3030476 
total_number_of_accesses_in_the_loop = total_number_of_accesses_after_the_loop-total_number_of_accesses_before_the_loop
total_number_of_misses_before_the_loop =  13794
total_number_of_misses_after_the_loop = 34293
total_number_of_misses_in_the_loop = total_number_of_misses_after_the_loop-total_number_of_misses_before_the_loop
miss_rate_of_the_loop = total_number_of_misses_in_the_loop/total_number_of_accesses_in_the_loop

print(f"access in the loop: %d misses in the loop %d miss_rate %lf" % (total_number_of_accesses_in_the_loop, total_number_of_misses_in_the_loop, miss_rate_of_the_loop))
# Out:
# access in the loop: 20484 misses in the loop 20493 miss_rate 1.000439

# %%
! cd 4way_madd; make madd_dump; cd ..; 
# !echo "element,address"> addresses_madd.csv; 
# !./4way_madd/madd_dump 8192 8192 2>> addresses_madd.csv
! head -n 101 addresses_madd.csv > addresses_digest.csv
df = pd.read_csv("addresses_digest.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
C = 32768
B = 64
A = 4
offset_bits = int(math.log2(B))
S = int(C/(B*A))
index_bits = int(math.log2(S))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits)%S))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)

# %% [markdown]
# ### Intel Core i7 13700 -- 12-way L1, 64B-blocked, 48KB cache
#
# Let's run it without the above loop code to figure the baseline memory accesses without running the loop on a Jetson nano.
#
# Let's again dump, parse and simulation the address sequence.

# %%
! cd 4way_madd; make clean; make EXTRA_CFLAGS="-mno-avx -O4" madd_dump; cd ..; 
# !echo "element,address"> addresses_madd.csv; 
# !./4way_madd/madd_dump 8192 8192 2>> addresses_madd.csv
! head -n 101 addresses_madd.csv > addresses_digest.csv
df = pd.read_csv("addresses_digest.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
C = 49152
B = 64
A = 12
offset_bits = int(math.log2(B))
S = int(C/(B*A))
index_bits = int(math.log2(S))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits) % S))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)
# Out:
# rm -f madd_intel madd_nano *_O3 *~ madd_A_fission cachegrind* *.perf madd_dump *.o
# cc -O3 -mno-avx -O4 -DDUMP madd.c -o madd_dump
# <style type="text/css">
# #T_e7ad0_row0_col0, #T_e7ad0_row0_col1, #T_e7ad0_row0_col2, #T_e7ad0_row0_col3, #T_e7ad0_row1_col0, #T_e7ad0_row1_col1, #T_e7ad0_row1_col2, #T_e7ad0_row1_col3, #T_e7ad0_row2_col0, #T_e7ad0_row2_col1, #T_e7ad0_row2_col2, #T_e7ad0_row2_col3, #T_e7ad0_row3_col0, #T_e7ad0_row3_col1, #T_e7ad0_row3_col2, #T_e7ad0_row3_col3, #T_e7ad0_row4_col0, #T_e7ad0_row4_col1, #T_e7ad0_row4_col2, #T_e7ad0_row4_col3, #T_e7ad0_row5_col0, #T_e7ad0_row5_col1, #T_e7ad0_row5_col2, #T_e7ad0_row5_col3, #T_e7ad0_row6_col0, #T_e7ad0_row6_col1, #T_e7ad0_row6_col2, #T_e7ad0_row6_col3, #T_e7ad0_row7_col0, #T_e7ad0_row7_col1, #T_e7ad0_row7_col2, #T_e7ad0_row7_col3, #T_e7ad0_row8_col0, #T_e7ad0_row8_col1, #T_e7ad0_row8_col2, #T_e7ad0_row8_col3, #T_e7ad0_row9_col0, #T_e7ad0_row9_col1, #T_e7ad0_row9_col2, #T_e7ad0_row9_col3, #T_e7ad0_row10_col0, #T_e7ad0_row10_col1, #T_e7ad0_row10_col2, #T_e7ad0_row10_col3, #T_e7ad0_row11_col0, #T_e7ad0_row11_col1, #T_e7ad0_row11_col2, #T_e7ad0_row11_col3, #T_e7ad0_row12_col0, #T_e7ad0_row12_col1, #T_e7ad0_row12_col2, #T_e7ad0_row12_col3, #T_e7ad0_row13_col0, #T_e7ad0_row13_col1, #T_e7ad0_row13_col2, #T_e7ad0_row13_col3, #T_e7ad0_row14_col0, #T_e7ad0_row14_col1, #T_e7ad0_row14_col2, #T_e7ad0_row14_col3, #T_e7ad0_row15_col0, #T_e7ad0_row15_col1, #T_e7ad0_row15_col2, #T_e7ad0_row15_col3, #T_e7ad0_row16_col0, #T_e7ad0_row16_col1, #T_e7ad0_row16_col2, #T_e7ad0_row16_col3, #T_e7ad0_row17_col0, #T_e7ad0_row17_col1, #T_e7ad0_row17_col2, #T_e7ad0_row17_col3, #T_e7ad0_row18_col0, #T_e7ad0_row18_col1, #T_e7ad0_row18_col2, #T_e7ad0_row18_col3, #T_e7ad0_row19_col0, #T_e7ad0_row19_col1, #T_e7ad0_row19_col2, #T_e7ad0_row19_col3, #T_e7ad0_row20_col0, #T_e7ad0_row20_col1, #T_e7ad0_row20_col2, #T_e7ad0_row20_col3, #T_e7ad0_row21_col0, #T_e7ad0_row21_col1, #T_e7ad0_row21_col2, #T_e7ad0_row21_col3, #T_e7ad0_row22_col0, #T_e7ad0_row22_col1, #T_e7ad0_row22_col2, #T_e7ad0_row22_col3, #T_e7ad0_row23_col0, #T_e7ad0_row23_col1, #T_e7ad0_row23_col2, #T_e7ad0_row23_col3, #T_e7ad0_row24_col0, #T_e7ad0_row24_col1, #T_e7ad0_row24_col2, #T_e7ad0_row24_col3, #T_e7ad0_row25_col0, #T_e7ad0_row25_col1, #T_e7ad0_row25_col2, #T_e7ad0_row25_col3, #T_e7ad0_row26_col0, #T_e7ad0_row26_col1, #T_e7ad0_row26_col2, #T_e7ad0_row26_col3, #T_e7ad0_row27_col0, #T_e7ad0_row27_col1, #T_e7ad0_row27_col2, #T_e7ad0_row27_col3, #T_e7ad0_row28_col0, #T_e7ad0_row28_col1, #T_e7ad0_row28_col2, #T_e7ad0_row28_col3, #T_e7ad0_row29_col0, #T_e7ad0_row29_col1, #T_e7ad0_row29_col2, #T_e7ad0_row29_col3, #T_e7ad0_row30_col0, #T_e7ad0_row30_col1, #T_e7ad0_row30_col2, #T_e7ad0_row30_col3, #T_e7ad0_row31_col0, #T_e7ad0_row31_col1, #T_e7ad0_row31_col2, #T_e7ad0_row31_col3, #T_e7ad0_row32_col0, #T_e7ad0_row32_col1, #T_e7ad0_row32_col2, #T_e7ad0_row32_col3, #T_e7ad0_row33_col0, #T_e7ad0_row33_col1, #T_e7ad0_row33_col2, #T_e7ad0_row33_col3, #T_e7ad0_row34_col0, #T_e7ad0_row34_col1, #T_e7ad0_row34_col2, #T_e7ad0_row34_col3, #T_e7ad0_row35_col0, #T_e7ad0_row35_col1, #T_e7ad0_row35_col2, #T_e7ad0_row35_col3, #T_e7ad0_row36_col0, #T_e7ad0_row36_col1, #T_e7ad0_row36_col2, #T_e7ad0_row36_col3, #T_e7ad0_row37_col0, #T_e7ad0_row37_col1, #T_e7ad0_row37_col2, #T_e7ad0_row37_col3, #T_e7ad0_row38_col0, #T_e7ad0_row38_col1, #T_e7ad0_row38_col2, #T_e7ad0_row38_col3, #T_e7ad0_row39_col0, #T_e7ad0_row39_col1, #T_e7ad0_row39_col2, #T_e7ad0_row39_col3, #T_e7ad0_row40_col0, #T_e7ad0_row40_col1, #T_e7ad0_row40_col2, #T_e7ad0_row40_col3, #T_e7ad0_row41_col0, #T_e7ad0_row41_col1, #T_e7ad0_row41_col2, #T_e7ad0_row41_col3, #T_e7ad0_row42_col0, #T_e7ad0_row42_col1, #T_e7ad0_row42_col2, #T_e7ad0_row42_col3, #T_e7ad0_row43_col0, #T_e7ad0_row43_col1, #T_e7ad0_row43_col2, #T_e7ad0_row43_col3, #T_e7ad0_row44_col0, #T_e7ad0_row44_col1, #T_e7ad0_row44_col2, #T_e7ad0_row44_col3, #T_e7ad0_row45_col0, #T_e7ad0_row45_col1, #T_e7ad0_row45_col2, #T_e7ad0_row45_col3, #T_e7ad0_row46_col0, #T_e7ad0_row46_col1, #T_e7ad0_row46_col2, #T_e7ad0_row46_col3, #T_e7ad0_row47_col0, #T_e7ad0_row47_col1, #T_e7ad0_row47_col2, #T_e7ad0_row47_col3, #T_e7ad0 ...

# %% [markdown]
# #### Run without the 4-way matrix add loop code.

# %%
# Run it "without" the above code.
! lscpu; cd ~/courses/CS203/demo/memory/4way_madd/; rm madd_intel; make EXTRA_CFLAGS="-mno-avx -O4" madd_intel; valgrind --tool=cachegrind ./madd_intel 16384 0 >& intel_without_loop.perf; grep 'D   refs\|D1' intel_without_loop.perf
# Out:
# Architecture:                       x86_64
# CPU op-mode(s):                     32-bit, 64-bit
# Byte Order:                         Little Endian
# Address sizes:                      46 bits physical, 48 bits virtual
# CPU(s):                             24
# On-line CPU(s) list:                0-23
# Thread(s) per core:                 1
# Core(s) per socket:                 16
# Socket(s):                          1
# NUMA node(s):                       1
# Vendor ID:                          GenuineIntel
# CPU family:                         6
# Model:                              183
# Model name:                         13th Gen Intel(R) Core(TM) i7-13700
# Stepping:                           1
# CPU MHz:                            2100.000
# CPU max MHz:                        5200.0000
# CPU min MHz:                        800.0000
# BogoMIPS:                           4224.00
# Virtualization:                     VT-x
# L1d cache:                          384 KiB
# L1i cache:                          256 KiB
# L2 cache:                           16 MiB
# NUMA node0 CPU(s):                  0-23
# Vulnerability Gather data sampling: Not affected
# Vulnerability Itlb multihit:        Not affected
# Vulnerability L1tf:                 Not affected
# Vulnerability Mds:                  Not affected
# Vulnerability Meltdown:             Not affected
# Vulnerability Mmio stale data:      Not affected
# Vulnerability Retbleed:             Not affected
# Vulnerability Spec rstack overflow: Not affected
# Vulnerability Spec store bypass:    Mitigation; Speculative Store Bypass disable
#                                     d via prctl and seccomp
# Vulnerability Spectre v1:           Mitigation; usercopy/swapgs barriers and __u
#                                     ser pointer sanitization
# Vulnerability Spectre v2:           Mitigation; Enhanced IBRS, IBPB conditional,
#                                      RSB filling, PBRSB-eIBRS SW sequence
# Vulnerability Srbds:                Not affected
# Vulnerability Tsx async abort:      Not affected
# Flags:                              fpu vme de pse tsc msr pae mce cx8 apic sep
#                                     mtrr pge mca cmov pat pse36 clflush dts acpi
#                                      mmx fxsr sse sse2 ss ht tm pbe syscall nx p
#                                     dpe1gb rdtscp lm constant_tsc art arch_perfm
#                                     on pebs bts rep_good nopl xtopology nonstop_
#                                     tsc cpuid aperfmperf tsc_known_freq pni pclm
#                                     ulqdq dtes64 monitor ds_cpl vmx smx est tm2
#                                     ssse3 sdbg fma cx16 xtpr pdcm sse4_1 sse4_2
#                                     x2apic movbe popcnt tsc_deadline_timer aes x
#                                     save avx f16c rdrand lahf_lm abm 3dnowprefet
#                                     ch cpuid_fault ssbd ibrs ibpb stibp ibrs_enh
#                                     anced tpr_shadow vnmi flexpriority ept vpid
#                                     ept_ad fsgsbase tsc_adjust bmi1 avx2 smep bm
#                                     i2 erms invpcid rdseed adx smap clflushopt c
#                                     lwb intel_pt sha_ni xsaveopt xsavec xgetbv1
#                                     xsaves split_lock_detect avx_vnni dtherm ida
#                                      arat pln pts hwp hwp_notify hwp_act_window
#                                     hwp_epp hwp_pkg_req umip pku ospke waitpkg g
#                                     fni vaes vpclmulqdq tme rdpid movdiri movdir
#                                     64b fsrm md_clear serialize pconfig arch_lbr
#                                      flush_l1d arch_capabilities
# rm: cannot remove 'madd_intel': No such file or directory
# cc -O3 -mno-avx -O4 madd.c perfstats.c -o madd_intel
# ==1562829== D   refs:      2,286,839  (1,618,611 rd   + 668,228 wr)
# ==1562829== D1  misses:       13,458  (    2,543 rd   +  10,915 wr)
# ==1562829== D1  miss rate:       0.6% (      0.2%     +     1.6%  )

# %% [markdown]
# Let's run it with the above loop code again and observe the changes in L1 cache misses/accesses
#
# #### Run with the 4-way matrix add loop code.

# %%
# Run it "with" the above code.
! cd ~/courses/CS203/demo/memory/4way_madd/; valgrind --tool=cachegrind ./madd_intel 16384 16384  >& intel_with_loop.perf; grep 'D   refs\|D1' intel_with_loop.perf
# Out:
# ==1562888== D   refs:      2,327,805  (1,651,385 rd   + 676,420 wr)
# ==1562888== D1  misses:       23,705  (   10,741 rd   +  12,964 wr)
# ==1562888== D1  miss rate:       1.0% (      0.7%     +     1.9%  )

# %%
# Let's do some math here
total_number_of_accesses_before_the_loop =2286839
total_number_of_accesses_after_the_loop = 2327805
total_number_of_accesses_in_the_loop = total_number_of_accesses_after_the_loop-total_number_of_accesses_before_the_loop
total_number_of_misses_before_the_loop = 13458
total_number_of_misses_after_the_loop = 23705
total_number_of_misses_in_the_loop = total_number_of_misses_after_the_loop-total_number_of_misses_before_the_loop
miss_rate_of_the_loop = total_number_of_misses_in_the_loop/total_number_of_accesses_in_the_loop

print(f"access in the loop: %d misses in the loop %d miss_rate %lf" % (total_number_of_accesses_in_the_loop, total_number_of_misses_in_the_loop, miss_rate_of_the_loop))
# Out:
# access in the loop: 40966 misses in the loop 10247 miss_rate 0.250134

# %% [markdown]
# Let's use performance counters to examine the cache/code performance
#
# #### Run with the 4-way matrix add loop code.

# %%
! echo "architecture,IC,Cycles,CPI,CycleTime,ET,DL1_Miss_Rate,DL1_MISSES,DL1_ACCESSES" > 4_way_loop.csv
! echo -n "jetson_nano," >> 4_way_loop.csv
! ssh htseng@nano-2 "cd courses/CS203/demo/memory/4way_madd/;./madd_nano 16384 8192" >> 4_way_loop.csv
display_df_mono(render_csv("4_way_loop.csv"))
# Out:
# <style type="text/css">
# #T_c2504_row0_col0, #T_c2504_row0_col1, #T_c2504_row0_col2, #T_c2504_row0_col3, #T_c2504_row0_col4, #T_c2504_row0_col5, #T_c2504_row0_col6, #T_c2504_row0_col7, #T_c2504_row0_col8 {
#   background-color: grey;
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_c2504">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2504_level0_col0" class="col_heading level0 col0" >architecture</th>
#       <th id="T_c2504_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_c2504_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_c2504_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_c2504_level0_col4" class="col_heading level0 col4" >CycleTime</th>
#       <th id="T_c2504_level0_col5" class="col_heading level0 col5" >ET</th>
#       <th id="T_c2504_level0_col6" class="col_heading level0 col6" >DL1_Miss_Rate</th>
#       <th id="T_c2504_level0_col7" class="col_heading level0 col7" >DL1_MISSES</th>
#       <th id="T_c2504_level0_col8" class="col_heading level0 col8" >DL1_ACCESSES</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2504_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2504_row0_col0" class="data row0 col0" >jetson_nano</td>
#       <td id="T_c2504_row0_col1" class="data row0 col1" >63470</td>
#       <td id="T_c2504_row0_col2" class="data row0 col2" >258096</td>
#       <td id="T_c2504_row0_col3" class="data row0 col3" >4.066425</td>
#       <td id="T_c2504_row0_col4" class="data row0 col4" >1.604054</td>
#       <td id="T_c2504_row0_col5" class="data row0 col5" >0.000414</td>
#       <td id="T_c2504_row0_col6" class="data row0 col6" >0.139661</td>
#       <td id="T_c2504_row0_col7" class="data row0 col7" >9033</td>
#       <td id="T_c2504_row0_col8" class="data row0 col8" >64678</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !cat ../cacti/
s = 1
!
# Out:
# cat: ../cacti/: Is a directory
# 1

# %%
# !./cacti $cache_size $line_size $associativity $rw_ports $excl_read_ports $excl_write_ports \ 
        $single_ended_read_ports $search_ports $banks $tech_node $output_width $specific_tag $tag_width\
        $access_mode $cache $main_mem $obj_func_delay $obj_func_dynamic_power $obj_func_leakage_power \ 
        $obj_func_cycle_time $obj_func_area $dev_func_delay $dev_func_dynamic_power $dev_func_leakage_power \
        $dev_func_area $dev_func_cycle_time $ed_ed2_none temp $wt $data_arr_ram_cell_tech_flavor_in \
        $data_arr_peri_global_tech_flavor_in $tag_arr_ram_cell_tech_flavor_in $tag_arr_peri_global_tech_flavor_in \
        $interconnect_projection_type_in $wire_inside_mat_type_in $wire_outside_mat_type_in \
        $REPEATERS_IN_HTREE_SEGMENTS_in $VERTICAL_HTREE_WIRES_OVER_THE_ARRAY_in \ 
  $BROADCAST_ADDR_DATAIN_OVER_VERTICAL_HTREES_in $PAGE_SIZE_BITS_in $BURST_LENGTH_in \
  $INTERNAL_PREFETCH_WIDTH_in $force_wiretype $wiretype $force_config $ndwl $ndbl $nspd $ndcm \
  $ndsam1 $ndsam2 $ecc
# Out:
#   File <tokenize>:9
#     $BROADCAST_ADDR_DATAIN_OVER_VERTICAL_HTREES_in $PAGE_SIZE_BITS_in $BURST_LENGTH_in \
#     ^
# IndentationError: unindent does not match any outer indentation level
