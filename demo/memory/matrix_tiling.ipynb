# %%
# Please execute/shift-return this cell everytime you run the notebook.  Don't edit it. 
# %load_ext autoreload
# %autoreload 2
from notebook import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Case study: matrix multiplications
#
# GEMM that computes C = A $\times$ B is the core of many AI/ML applications. The most naive implementation of GEMM takes $O(n^3)$. Assume it takes 1 second to perform GEMM on 1,024$\times$1,024$\times$1,024 matrices. How much time do you expect it would take for 2,048$\times$2,048$\times$2,048 matrices?

# %%
render_code("matrix_mul/mm.c", show=["//START","//END"])
# Out:
# // matrix_mul/mm.c:54-75 (22 lines)
# //START
# void mm(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   uint64_t i,j,k;
#   for(i = 0; i < M; i++)
#   {
#     for(j = 0; j < K; j++)
#     {
#       for(k = 0; k < N; k++)
#       {
#         c[i][j] += a[i][k]*b[k][j];
#         #ifdef DUMP
#           fprintf(stderr, "a[%ld][%ld], %p\n",i,k, &a[i][k]);
#           fprintf(stderr, "b[%ld][%ld], %p\n",k,j, &b[k][j]);
#           fprintf(stderr, "c[%ld][%ld], %p\n",i,j, &c[i][j]);
#         #endif
#       }
#     }
#   }
#   return;
# }
# //END

# %%
! cd matrix_mul; make clean; make mm
# Out:
# rm -f blockmm mm blockmm_transpose cachegrind.* mm_dump
# gcc -DHAVE_LINUX_PERF_EVENT_H -O3 mm.c perfstats.c -o mm

# %%
! cd matrix_mul; echo "IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > mm.csv
! ./matrix_mul/mm 512 >> ./matrix_mul/mm.csv ;./matrix_mul/mm 1024 >> ./matrix_mul/mm.csv ; ./matrix_mul/mm 2048 >> ./matrix_mul/mm.csv
#! cs203 job memory "./matrix_mul/mm 1024 >> ./matrix_mul/mm.csv ; ./matrix_mul/mm 2048 >> ./matrix_mul/mm.csv"
# Out:
# 234410496.000000,1406510080.000000,10521102336.000000,

# %%
display_df_mono(render_csv("matrix_mul/mm.csv"))
# Out:
# <style type="text/css">
# #T_5d422_row0_col0, #T_5d422_row0_col1, #T_5d422_row0_col2, #T_5d422_row0_col3, #T_5d422_row0_col4, #T_5d422_row0_col5, #T_5d422_row0_col6, #T_5d422_row0_col7, #T_5d422_row0_col8, #T_5d422_row1_col0, #T_5d422_row1_col1, #T_5d422_row1_col2, #T_5d422_row1_col3, #T_5d422_row1_col4, #T_5d422_row1_col5, #T_5d422_row1_col6, #T_5d422_row1_col7, #T_5d422_row1_col8, #T_5d422_row2_col0, #T_5d422_row2_col1, #T_5d422_row2_col2, #T_5d422_row2_col3, #T_5d422_row2_col4, #T_5d422_row2_col5, #T_5d422_row2_col6, #T_5d422_row2_col7, #T_5d422_row2_col8 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_5d422">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d422_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_5d422_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_5d422_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_5d422_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_5d422_level0_col4" class="col_heading level0 col4" >CT_ns</th>
#       <th id="T_5d422_level0_col5" class="col_heading level0 col5" >ET_s</th>
#       <th id="T_5d422_level0_col6" class="col_heading level0 col6" >DL1_miss_rate</th>
#       <th id="T_5d422_level0_col7" class="col_heading level0 col7" >DL1_misses</th>
#       <th id="T_5d422_level0_col8" class="col_heading level0 col8" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d422_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d422_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_5d422_row0_col1" class="data row0 col1" >1077432003</td>
#       <td id="T_5d422_row0_col2" class="data row0 col2" >661148573</td>
#       <td id="T_5d422_row0_col3" class="data row0 col3" >0.613634</td>
#       <td id="T_5d422_row0_col4" class="data row0 col4" >0.217316</td>
#       <td id="T_5d422_row0_col5" class="data row0 col5" >0.143678</td>
#       <td id="T_5d422_row0_col6" class="data row0 col6" >0.243293</td>
#       <td id="T_5d422_row0_col7" class="data row0 col7" >130824267</td>
#       <td id="T_5d422_row0_col8" class="data row0 col8" >537722442</td>
#     </tr>
#     <tr>
#       <th id="T_5d422_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d422_row1_col0" class="data row1 col0" >1024</td>
#       <td id="T_5d422_row1_col1" class="data row1 col1" >8586764082</td>
#       <td id="T_5d422_row1_col2" class="data row1 col2" >10945327062</td>
#       <td id="T_5d422_row1_col3" class="data row1 col3" >1.274674</td>
#       <td id="T_5d422_row1_col4" class="data row1 col4" >0.193525</td>
#       <td id="T_5d422_row1_col5" class="data row1 col5" >2.118194</td>
#       <td id="T_5d422_row1_col6" class="data row1 col6" >0.233284</td>
#       <td id="T_5d422_row1_col7" class="data row1 col7" >1000159900</td>
#       <td id="T_5d422_row1_col8" class="data row1 col8" >4287311885</td>
#     </tr>
#     <tr>
#       <th id="T_5d422_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5d422_row2_col0" class="data row2 col0" >2048</td>
#       <td id="T_5d422_row2_col1" class="data row2 col1" >69005155569</td>
#       <td id="T_5d422_row2_col2" class="data row2 col2" >122125385954</td>
#       <td id="T_5d422_row2_col3" class="data row2 col3" >1.769801</td>
#       <td id="T_5d422_row2_col4" class="data row2 col4" >0.192823</td>
#       <td id="T_5d422_row2_col5" class="data row2 col5" >23.548576</td>
#       <td id="T_5d422_row2_col6" class="data row2 col6" >0.308093</td>
#       <td id="T_5d422_row2_col7" class="data row2 col7" >10616080516</td>
#       <td id="T_5d422_row2_col8" class="data row2 col8" >34457335150</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# WOW! Compuational complexty breaks again! The GEMM performance go wild because of cache misses!

# %% [markdown]
# What kind of misses are we seeing?

# %%
! make -C matrix_mul mm_dump; ./matrix_mul/mm_dump 256 >& mm_dump_address.csv
# Out:
# make: Entering directory '/nfshome/htseng/courses/CS203/demo/memory/matrix_mul'
# gcc -DHAVE_LINUX_PERF_EVENT_H -DDUMP -O3 mm.c perfstats.c -o mm_dump
# make: Leaving directory '/nfshome/htseng/courses/CS203/demo/memory/matrix_mul'

# %%
! echo "element,address" > mm_dump_addresses_digest.csv 
! head -n 101 mm_dump_address.csv | grep "b\[" >> mm_dump_addresses_digest.csv
df = pd.read_csv("mm_dump_addresses_digest.csv",skipfooter=1,engine='python')
df["address"] = df["address"].str.replace('0x','')
df["address"]=df[["address"]].apply(lambda x: x.astype(str).map(lambda x: int(x, base=16)))
# only show the first N addresses 
#N = 32
#df2 = df2.iloc[:N]
C = 49152
B = 64
A = 12
offset_bits = int(math.log2(B))
S = int(C/(B*A))
index_bits = int(math.log2(S))
df["tag"]=(df["address"].apply(lambda x: x >> (offset_bits+index_bits)))
df["tag"] = df["tag"].apply(lambda x: hex(x))
df["index"] = df["address"].apply(lambda x: hex((x>>offset_bits)%S))
df["address"] = df["address"].apply(lambda x: hex(x))
display_df_mono(df)
# Out:
# <style type="text/css">
# #T_e1799_row0_col0, #T_e1799_row0_col1, #T_e1799_row0_col2, #T_e1799_row0_col3, #T_e1799_row1_col0, #T_e1799_row1_col1, #T_e1799_row1_col2, #T_e1799_row1_col3, #T_e1799_row2_col0, #T_e1799_row2_col1, #T_e1799_row2_col2, #T_e1799_row2_col3, #T_e1799_row3_col0, #T_e1799_row3_col1, #T_e1799_row3_col2, #T_e1799_row3_col3, #T_e1799_row4_col0, #T_e1799_row4_col1, #T_e1799_row4_col2, #T_e1799_row4_col3, #T_e1799_row5_col0, #T_e1799_row5_col1, #T_e1799_row5_col2, #T_e1799_row5_col3, #T_e1799_row6_col0, #T_e1799_row6_col1, #T_e1799_row6_col2, #T_e1799_row6_col3, #T_e1799_row7_col0, #T_e1799_row7_col1, #T_e1799_row7_col2, #T_e1799_row7_col3, #T_e1799_row8_col0, #T_e1799_row8_col1, #T_e1799_row8_col2, #T_e1799_row8_col3, #T_e1799_row9_col0, #T_e1799_row9_col1, #T_e1799_row9_col2, #T_e1799_row9_col3, #T_e1799_row10_col0, #T_e1799_row10_col1, #T_e1799_row10_col2, #T_e1799_row10_col
col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1799_row2_col0" class="data row2 col0" >b[2][0]</td>
#       <td id="T_e1799_row2_col1" class="data row2 col1" >0x7b7c52f00000</td>
#       <td id="T_e1799_row2_col2" class="data row2 col2" >0x7b7c52f00</td>
#       <td id="T_e1799_row2_col3" class="data row2 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1799_row3_col0" class="data row3 col0" >b[3][0]</td>
#       <td id="T_e1799_row3_col1" class="data row3 col1" >0x7b7c52f00800</td>
#       <td id="T_e1799_row3_col2" class="data row3 col2" >0x7b7c52f00</td>
#       <td id="T_e1799_row3_col3" class="data row3 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1799_row4_col0" class="data row4 col0" >b[4][0]</td>
#       <td id="T_e1799_row4_col1" class="data row4 col1" >0x7b7c52f01000</td>
#       <td id="T_e1799_row4_col2" class="data row4 col2" >0x7b7c52f01</td>
#       <td id="T_e1799_row4_col3" class="data row4 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e1799_row5_col0" class="data row5 col0" >b[5][0]</td>
#       <td id="T_e1799_row5_col1" class="data row5 col1" >0x7b7c52f01800</td>
#       <td id="T_e1799_row5_col2" class="data row5 col2" >0x7b7c52f01</td>
#       <td id="T_e1799_row5_col3" class="data row5 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e1799_row6_col0" class="data row6 col0" >b[6][0]</td>
#       <td id="T_e1799_row6_col1" class="data row6 col1" >0x7b7c52f02000</td>
#       <td id="T_e1799_row6_col2" class="data row6 col2" >0x7b7c52f02</td>
#       <td id="T_e1799_row6_col3" class="data row6 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e1799_row7_col0" class="data row7 col0" >b[7][0]</td>
#       <td id="T_e1799_row7_col1" class="data row7 col1" >0x7b7c52f02800</td>
#       <td id="T_e1799_row7_col2" class="data row7 col2" >0x7b7c52f02</td>
#       <td id="T_e1799_row7_col3" class="data row7 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e1799_row8_col0" class="data row8 col0" >b[8][0]</td>
#       <td id="T_e1799_row8_col1" class="data row8 col1" >0x7b7c52f03000</td>
#       <td id="T_e1799_row8_col2" class="data row8 col2" >0x7b7c52f03</td>
#       <td id="T_e1799_row8_col3" class="data row8 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e1799_row9_col0" class="data row9 col0" >b[9][0]</td>
#       <td id="T_e1799_row9_col1" class="data row9 col1" >0x7b7c52f03800</td>
#       <td id="T_e1799_row9_col2" class="data row9 col2" >0x7b7c52f03</td>
#       <td id="T_e1799_row9_col3" class="data row9 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e1799_row10_col0" class="data row10 col0" >b[10][0]</td>
#       <td id="T_e1799_row10_col1" class="data row10 col1" >0x7b7c52f04000</td>
#       <td id="T_e1799_row10_col2" class="data row10 col2" >0x7b7c52f04</td>
#       <td id="T_e1799_row10_col3" class="data row10 col3" >0x0</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e1799_row11_col0" class="data row11 col0" >b[11][0]</td>
#       <td id="T_e1799_row11_col1" class="data row11 col1" >0x7b7c52f04800</td>
#       <td id="T_e1799_row11_col2" class="data row11 col2" >0x7b7c52f04</td>
#       <td id="T_e1799_row11_col3" class="data row11 col3" >0x20</td>
#     </tr>
#     <tr>
#       <th id="T_e1799_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e1799_row12_col0" class="data row12 col0" >b[12][0

# %% [markdown]
# ### Matrix tiling algorithm
#
# Let's try to partition GEMM into smaller tiles!

# %%
render_code("matrix_mul/blockmm.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm.c:59-77 (19 lines)
# //START
# void blockmm(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   uint64_t i,j,k, ii, jj, kk;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(ii = i; ii < i+tile_size; ii++)
#             for(jj = j; jj < j+tile_size; jj++)
#               for(kk = k; kk < k+tile_size; kk++)
#                 c[ii][jj] += a[ii][kk]*b[kk][jj];
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul/; make clean blockmm
# Out:
# rm -f blockmm mm blockmm_transpose cachegrind.* mm_dump rect_blockmm_trans blockmm_transpose_reg blockmm_reg
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H blockmm.c perfstats.c -o blockmm
# blockmm.c: In function ‘main’:
# blockmm.c:48:16: warning: format ‘%lu’ expects argument of type ‘long unsigned int’, but argument 3 has type ‘int’ [-Wformat=]
#    48 |   printf("%d,%lu,",ARRAY_SIZE,tile_size);
#       |              ~~^              ~~~~~~~~~
#       |                |              |
#       |                |              int
#       |                long unsigned int
#       |              %u

# %%
! cd matrix_mul; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm.csv
! ./matrix_mul/blockmm 512 8 >> ./matrix_mul/blockmm.csv ;./matrix_mul/blockmm 1024 8 >> ./matrix_mul/blockmm.csv ; ./matrix_mul/blockmm 2048 8 >> ./matrix_mul/blockmm.csv; ./matrix_mul/blockmm 4096 8 >> ./matrix_mul/blockmm.csv

# %%
display_df_mono(render_csv("matrix_mul/mm.csv"))
display_df_mono(render_csv("matrix_mul/blockmm.csv"))
# Out:
# <style type="text/css">
# #T_f2d9d_row0_col0, #T_f2d9d_row0_col1, #T_f2d9d_row0_col2, #T_f2d9d_row0_col3, #T_f2d9d_row0_col4, #T_f2d9d_row0_col5, #T_f2d9d_row0_col6, #T_f2d9d_row0_col7, #T_f2d9d_row0_col8, #T_f2d9d_row1_col0, #T_f2d9d_row1_col1, #T_f2d9d_row1_col2, #T_f2d9d_row1_col3, #T_f2d9d_row1_col4, #T_f2d9d_row1_col5, #T_f2d9d_row1_col6, #T_f2d9d_row1_col7, #T_f2d9d_row1_col8, #T_f2d9d_row2_col0, #T_f2d9d_row2_col1, #T_f2d9d_row2_col2, #T_f2d9d_row2_col3, #T_f2d9d_row2_col4, #T_f2d9d_row2_col5, #T_f2d9d_row2_col6, #T_f2d9d_row2_col7, #T_f2d9d_row2_col8 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_f2d9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2d9d_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_f2d9d_level0_col1" class="col_heading level0 col1" >IC</th>
#       <th id="T_f2d9d_level0_col2" class="col_heading level0 col2" >Cycles</th>
#       <th id="T_f2d9d_level0_col3" class="col_heading level0 col3" >CPI</th>
#       <th id="T_f2d9d_level0_col4" class="col_heading level0 col4" >CT_ns</th>
#       <th id="T_f2d9d_level0_col5" class="col_heading level0 col5" >ET_s</th>
#       <th id="T_f2d9d_level0_col6" class="col_heading level0 col6" >DL1_miss_rate</th>
#       <th id="T_f2d9d_level0_col7" class="col_heading level0 col7" >DL1_misses</th>
#       <th id="T_f2d9d_level0_col8" class="col_heading level0 col8" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2d9d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2d9d_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_f2d9d_row0_col1" class="data row0 col1" >1077432003</td>
#       <td id="T_f2d9d_row0_col2" class="data row0 col2" >661148573</td>
#       <td id="T_f2d9d_row0_col3" class="data row0 col3" >0.613634</td>
#       <td id="T_f2d9d_row0_col4" class="data row0 col4" >0.217316</td>
#       <td id="T_f2d9d_row0_col5" class="data row0 col5" >0.143678</td>
#       <td id="T_f2d9d_row0_col6" class="data row0 col6" >0.243293</td>
#       <td id="T_f2d9d_row0_col7" class="data row0 col7" >130824267</td>
#       <td id="T_f2d9d_row0_col8" class="data row0 col8" >537722442</td>
#     </tr>
#     <tr>
#       <th id="T_f2d9d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2d9d_row1_col0" class="data row1 col0" >1024</td>
#       <td id="T_f2d9d_row1_col1" class="data row1 col1" >8586764082</td>
#       <td id="T_f2d9d_row1_col2" class="data row1 col2" >10945327062</td>
#       <td id="T_f2d9d_row1_col3" class="data row1 col3" >1.274674</td>
#       <td id="T_f2d9d_row1_col4" class="data row1 col4" >0.193525</td>
#       <td id="T_f2d9d_row1_col5" class="data row1 col5" >2.118194</td>
#       <td id="T_f2d9d_row1_col6" class="data row1 col6" >0.233284</td>
#       <td id="T_f2d9d_row1_col7" class="data row1 col7" >1000159900</td>
#       <td id="T_f2d9d_row1_col8" class="data row1 col8" >4287311885</td>
#     </tr>
#     <tr>
#       <th id="T_f2d9d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2d9d_row2_col0" class="data row2 col0" >2048</td>
#       <td id="T_f2d9d_row2_col1" class="data row2 col1" >69005155569</td>
#       <td id="T_f2d9d_row2_col2" class="data row2 col2" >122125385954</td>
#       <td id="T_f2d9d_row2_col3" class="data row2 col3" >1.769801</td>
#       <td id="T_f2d9d_row2_col4" class="data row2 col4" >0.192823</td>
#       <td id="T_f2d9d_row2_col5" class="data row2 col5" >23.548576</td>
#       <td id="T_f2d9d_row2_col6" class="data row2 col6" >0.308093</td>
#       <td id="T_f2d9d_row2_col7" class="data row2 col7" >10616080516</td>
#       <td id="T_f2d9d_row2_col8" class="data row2 col8" >34457335150</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c6ff1_row0_col0, #T_c6ff1_row0_col1, #T_c6ff1_row0_col2, #T_c6ff1_row0_col3, #T_c6ff1_row0_col4, #T_c6ff1_row0_col5, #T_c6ff1_row0_col6, #T_c6ff1_row0_col7, #T_c6ff1_row0_col8, #T_c6ff1_row0_col9, #T_c6ff1_row0_col10, #T_c6ff1_row1_col0, #T_c6ff1_row1_col1, #T_c6ff1_row1_col2, #T_c6ff1_row1_col3, #T_c6ff1_row1_col4, #T_c6ff1_row1_col5, #T_c6ff1_row1_col6, #T_c6ff1_row1_col7, #T_c6ff1_row1_col8, #T_c6ff1_row1_col9, #T_c6ff1_row1_col10, #T_c6ff1_row2_col0, #T_c6ff1_row2_col1, #T_c6ff1_row2_col2, #T_c6ff1_row2_col3, #T_c6ff1_row2_col4, #T_c6ff1_row2_col5, #T_c6ff1_row2_col6, #T_c6ff1_row2_col7, #T_c6ff1_row2_col8, #T_c6ff1_row2_col9, #T_c6ff1_row2_col10, #T_c6ff1_row3_col0, #T_c6ff1_row3_col1, #T_c6ff1_row3_col2, #T_c6ff1_row3_col3, #T_c6ff1_row3_col4, #T_c6ff1_row3_col5, #T_c6ff1_row3_col6, #T_c6ff1_row3_col7, #T_c6ff1_row3_col8, #T_c6ff1_row3_col9, #T_c6ff1_row3_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_c6ff1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6ff1_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_c6ff1_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_c6ff1_level0_col2" class="col_heading level0 col2" >tile_size</th>
#       <th id="T_c6ff1_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_c6ff1_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_c6ff1_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_c6ff1_level0_col6" class="col_heading level0 col6" >CT_ns</th>
#       <th id="T_c6ff1_level0_col7" class="col_heading level0 col7" >ET_s</th>
#       <th id="T_c6ff1_level0_col8" class="col_heading level0 col8" >DL1_miss_rate</th>
#       <th id="T_c6ff1_level0_col9" class="col_heading level0 col9" >DL1_misses</th>
#       <th id="T_c6ff1_level0_col10" class="col_heading level0 col10" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6ff1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6ff1_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c6ff1_row0_col1" class="data row0 col1" >512</td>
#       <td id="T_c6ff1_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_c6ff1_row0_col3" class="data row0 col3" >1266427680</td>
#       <td id="T_c6ff1_row0_col4" class="data row0 col4" >275297453</td>
#       <td id="T_c6ff1_row0_col5" class="data row0 col5" >0.217381</td>
#       <td id="T_c6ff1_row0_col6" class="data row0 col6" >0.239359</td>
#       <td id="T_c6ff1_row0_col7" class="data row0 col7" >0.065895</td>
#       <td id="T_c6ff1_row0_col8" class="data row0 col8" >0.009266</td>
#       <td id="T_c6ff1_row0_col9" class="data row0 col9" >5524063</td>
#       <td id="T_c6ff1_row0_col10" class="data row0 col10" >596155020</td>
#     </tr>
#     <tr>
#       <th id="T_c6ff1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6ff1_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_c6ff1_row1_col1" class="data row1 col1" >1024</td>
#       <td id="T_c6ff1_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_c6ff1_row1_col3" class="data row1 col3" >10110546358</td>
#       <td id="T_c6ff1_row1_col4" class="data row1 col4" >2167746299</td>
#       <td id="T_c6ff1_row1_col5" class="data row1 col5" >0.214404</td>
#       <td id="T_c6ff1_row1_col6" class="data row1 col6" >0.193990</td>
#       <td id="T_c6ff1_row1_col7" class="data row1 col7" >0.420521</td>
#       <td id="T_c6ff1_row1_col8" class="data row1 col8" >0.010271</td>
#       <td id="T_c6ff1_row1_col9" class="data row1 col9" >48883460</td>
#       <td id="T_c6ff1_row1_col10" class="data row1 col10" >4759532739</td>
#     </tr>
#     <tr>
#       <th id="T_c6ff1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c6ff1_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_c6ff1_row2_col1" class="data row2 col1" >2048</td>
#       <td id="T_c6ff1_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_c6ff1_row2_col3" class="data row2 col3" >81046235957</td>
#       <td id="T_c6ff1_row2_col4" class="data row2 col4" >20743036584</td>
#       <td id="T_c6ff1_row2_col5" class="data row2 col5" >0.255941</td>
#       <td id="T_c6ff1_row2_col6" class="data row2 col6" >0.193622</td>
#       <td id="T_c6ff1_row2_col7" class="data row2 col7" >4.016311</td>
#       <td id="T_c6ff1_row2_col8" class="data row2 col8" >0.010452</td>
#       <td id="T_c6ff1_row2_col9" class="data row2 col9" >398769644</td>
#       <td id="T_c6ff1_row2_col10" class="data row2 col10" >38151767767</td>
#     </tr>
#     <tr>
#       <th id="T_c6ff1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c6ff1_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_c6ff1_row3_col1" class="data row3 col1" >4096</td>
#       <td id="T_c6ff1_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_c6ff1_row3_col3" class="data row3 col3" >648460832126</td>
#       <td id="T_c6ff1_row3_col4" class="data row3 col4" >213888968362</td>
#       <td id="T_c6ff1_row3_col5" class="data row3 col5" >0.329841</td>
#       <td id="T_c6ff1_row3_col6" class="data row3 col6" >0.193504</td>
#       <td id="T_c6ff1_row3_col7" class="data row3 col7" >41.388287</td>
#       <td id="T_c6ff1_row3_col8" class="data row3 col8" >0.012343</td>
#       <td id="T_c6ff1_row3_col9" class="data row3 col9" >3767687760</td>
#       <td id="T_c6ff1_row3_col10" class="data row3 col10" >305247199626</td>
#     </tr>
#   </tbody>
# </table>

# %%
! ./matrix_mul/blockmm 2048 4 >> ./matrix_mul/blockmm.csv
! ./matrix_mul/blockmm 2048 16 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 32 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 64 >> ./matrix_mul/blockmm.csv
! ./matrix_mul/blockmm 2048 128 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 256 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 512 >> ./matrix_mul/blockmm.csv 
display_df_mono(render_csv("matrix_mul/blockmm.csv"))
# Out:
# <style type="text/css">
# #T_42d0e_row0_col0, #T_42d0e_row0_col1, #T_42d0e_row0_col2, #T_42d0e_row0_col3, #T_42d0e_row0_col4, #T_42d0e_row0_col5, #T_42d0e_row0_col6, #T_42d0e_row0_col7, #T_42d0e_row0_col8, #T_42d0e_row0_col9, #T_42d0e_row0_col10, #T_42d0e_row1_col0, #T_42d0e_row1_col1, #T_42d0e_row1_col2, #T_42d0e_row1_col3, #T_42d0e_row1_col4, #T_42d0e_row1_col5, #T_42d0e_row1_col6, #T_42d0e_row1_col7, #T_42d0e_row1_col8, #T_42d0e_row1_col9, #T_42d0e_row1_col10, #T_42d0e_row2_col0, #T_42d0e_row2_col1, #T_42d0e_row2_col2, #T_42d0e_row2_col3, #T_42d0e_row2_col4, #T_42d0e_row2_col5, #T_42d0e_row2_col6, #T_42d0e_row2_col7, #T_42d0e_row2_col8, #T_42d0e_row2_col9, #T_42d0e_row2_col10, #T_42d0e_row3_col0, #T_42d0e_row3_col1, #T_42d0e_row3_col2, #T_42d0e_row3_col3, #T_42d0e_row3_col4, #T_42d0e_row3_col5, #T_42d0e_row3_col6, #T_42d0e_row3_col7, #T_42d0e_row3_col8, #T_42d0e_row3_col9, #T_42d0e_row3_col10, #T_42d0e_row4_col0, #T_42d0e_row4_col1, #T_42d0e_row4_col2, #T_42d0e_row4_col3, #T_42d0e_row4_col4, #T_42d0e_row4_col5, #T_42d0e_row4_col6, #T_42d0e_row4_col7, #T_42d0e_row4_col8, #T_42d0e_row4_col9, #T_42d0e_row4_col10, #T_42d0e_row5_col0, #T_42d0e_row5_col1, #T_42d0e_row5_col2, #T_42d0e_row5_col3, #T_42d0e_row5_col4, #T_42d0e_row5_col5, #T_42d0e_row5_col6, #T_42d0e_row5_col7, #T_42d0e_row5_col8, #T_42d0e_row5_col9, #T_42d0e_row5_col10, #T_42d0e_row6_col0, #T_42d0e_row6_col1, #T_42d0e_row6_col2, #T_42d0e_row6_col3, #T_42d0e_row6_col4, #T_42d0e_row6_col5, #T_42d0e_row6_col6, #T_42d0e_row6_col7, #T_42d0e_row6_col8, #T_42d0e_row6_col9, #T_42d0e_row6_col10, #T_42d0e_row7_col0, #T_42d0e_row7_col1, #T_42d0e_row7_col2, #T_42d0e_row7_col3, #T_42d0e_row7_col4, #T_42d0e_row7_col5, #T_42d0e_row7_col6, #T_42d0e_row7_col7, #T_42d0e_row7_col8, #T_42d0e_row7_col9, #T_42d0e_row7_col10, #T_42d0e_row8_col0, #T_42d0e_row8_col1, #T_42d0e_row8_col2, #T_42d0e_row8_col3, #T_42d0e_row8_col4, #T_42d0e_row8_col5, #T_42d0e_row8_col6, #T_42d0e_row8_col7, #T_42d0e_row8_col8, #T_42d0e_row8_col9, #T_42d0e_row8_col10, #T_42d0e_row9_col0, #T_42d0e_row9_col1, #T_42d0e_row9_col2, #T_42d0e_row9_col3, #T_42d0e_row9_col4, #T_42d0e_row9_col5, #T_42d0e_row9_col6, #T_42d0e_row9_col7, #T_42d0e_row9_col8, #T_42d0e_row9_col9, #T_42d0e_row9_col10, #T_42d0e_row10_col0, #T_42d0e_row10_col1, #T_42d0e_row10_col2, #T_42d0e_row10_col3, #T_42d0e_row10_col4, #T_42d0e_row10_col5, #T_42d0e_row10_col6, #T_42d0e_row10_col7, #T_42d0e_row10_col8, #T_42d0e_row10_col9, #T_42d0e_row10_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_42d0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42d0e_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_42d0e_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_42d0e_level0_col2" class="col_heading level0 col2" >tile_size</th>
#       <th id="T_42d0e_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_42d0e_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_42d0e_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_42d0e_level0_col6" class="col_heading level0 col6" >CT_ns</th>
#       <th id="T_42d0e_level0_col7" class="col_heading level0 col7" >ET_s</th>
#       <th id="T_42d0e_level0_col8" class="col_heading level0 col8" >DL1_miss_rate</th>
#       <th id="T_42d0e_level0_col9" class="col_heading level0 col9" >DL1_misses</th>
#       <th id="T_42d0e_level0_col10" class="col_heading level0 col10" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42d0e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42d0e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_42d0e_row0_col1" class="data row0 col1" >512</td>
#       <td id="T_42d0e_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_42d0e_row0_col3" class="data row0 col3" >1266427680</td>
#       <td id="T_42d0e_row0_col4" class="data row0 col4" >275297453</td>
#       <td id="T_42d0e_row0_col5" class="data row0 col5" >0.217381</td>
#       <td id="T_42d0e_row0_col6" class="data row0 col6" >0.239359</td>
#       <td id="T_42d0e_row0_col7" class="data row0 col7" >0.065895</td>
#       <td id="T_42d0e_row0_col8" class="data row0 col8" >0.009266</td>
#       <td id="T_42d0e_row0_col9" class="data row0 col9" >5524063</td>
#       <td id="T_42d0e_row0_col10" class="data row0 col10" >596155020</td>
#     </tr>
#     <tr>
#       <th id="T_
level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c947_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_7c947_row5_col1" class="data row5 col1" >2048</td>
#       <td id="T_7c947_row5_col2" class="data row5 col2" >128</td>
#       <td id="T_7c947_row5_col3" class="data row5 col3" >69446081686</td>
#       <td id="T_7c947_row5_col4" class="data row5 col4" >34562306757</td>
#       <td id="T_7c947_row5_col5" class="data row5 col5" >0.497685</td>
#       <td id="T_7c947_row5_col6" class="data row5 col6" >0.193374</td>
#       <td id="T_7c947_row5_col7" class="data row5 col7" >6.683450</td>
#       <td id="T_7c947_row5_col8" class="data row5 col8" >0.245759</td>
#       <td id="T_7c947_row5_col9" class="data row5 col9" >8498030900</td>
#       <td i

# %%
render_code("matrix_mul/blockmm_transpose.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm_transpose.c:62-80 (19 lines)
# //START
# void blockmm_transpose(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   int i,j,k, ii, jj, kk;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(ii = i; ii < i+tile_size; ii++)
#             for(jj = j; jj < j+tile_size; jj++)
#               for(kk = k; kk < k+tile_size; kk++)
#                 c[ii][jj] += a[ii][kk]*b[jj][kk];
#       }
#     }
#   }
# }
# //END

# %% [markdown]
# ### Matrix transpose

# %%
! cd matrix_mul; rm blockmm_transpose; make blockmm_transpose; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm_transpose.csv
! ./matrix_mul/blockmm_transpose 512 8 >> ./matrix_mul/blockmm_transpose.csv ;./matrix_mul/blockmm_transpose 1024 8 >> ./matrix_mul/blockmm_transpose.csv ; ./matrix_mul/blockmm_transpose 2048 8 >> ./matrix_mul/blockmm_transpose.csv; ./matrix_mul/blockmm_transpose 4096 8 >> ./matrix_mul/blockmm_transpose.csv
# Out:
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H blockmm_transpose.c perfstats.c -o blockmm_transpose
# 234410496.000000,1406510080.000000,10521102336.000000,48070299648.000000,

# %%
! ./matrix_mul/blockmm_transpose 2048 8 >> ./matrix_mul/blockmm_transpose.csv 
! ./matrix_mul/blockmm_transpose 2048 16 >> ./matrix_mul/blockmm_transpose.csv 
! ./matrix_mul/blockmm_transpose 2048 32 >> ./matrix_mul/blockmm_transpose.csv 
! ./matrix_mul/blockmm_transpose 2048 64 >> ./matrix_mul/blockmm_transpose.csv
! ./matrix_mul/blockmm_transpose 2048 128 >> ./matrix_mul/blockmm_transpose.csv
! ./matrix_mul/blockmm_transpose 2048 256 >> ./matrix_mul/blockmm_transpose.csv
# Out:
# 10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,

# %%
display_df_mono(render_csv("matrix_mul/blockmm_transpose.csv"))
# Out:
# <style type="text/css">
# #T_285b0_row0_col0, #T_285b0_row0_col1, #T_285b0_row0_col2, #T_285b0_row0_col3, #T_285b0_row0_col4, #T_285b0_row0_col5, #T_285b0_row0_col6, #T_285b0_row0_col7, #T_285b0_row0_col8, #T_285b0_row0_col9, #T_285b0_row0_col10, #T_285b0_row1_col0, #T_285b0_row1_col1, #T_285b0_row1_col2, #T_285b0_row1_col3, #T_285b0_row1_col4, #T_285b0_row1_col5, #T_285b0_row1_col6, #T_285b0_row1_col7, #T_285b0_row1_col8, #T_285b0_row1_col9, #T_285b0_row1_col10, #T_285b0_row2_col0, #T_285b0_row2_col1, #T_285b0_row2_col2, #T_285b0_row2_col3, #T_285b0_row2_col4, #T_285b0_row2_col5, #T_285b0_row2_col6, #T_285b0_row2_col7, #T_285b0_row2_col8, #T_285b0_row2_col9, #T_285b0_row2_col10, #T_285b0_row3_col0, #T_285b0_row3_col1, #T_285b0_row3_col2, #T_285b0_row3_col3, #T_285b0_row3_col4, #T_285b0_row3_col5, #T_285b0_row3_col6, #T_285b0_row3_col7, #T_285b0_row3_col8, #T_285b0_row3_col9, #T_285b0_row3_col10, #T_285b0_row4_col0, #T_285b0_row4_col1, #T_285b0_row4_col2, #T_285b0_row4_col3, #T_285b0_row4_col4, #T_285b0_row4_col5, #T_285b0_row4_col6, #T_285b0_row4_col7, #T_285b0_row4_col8, #T_285b0_row4_col9, #T_285b0_row4_col10, #T_285b0_row5_col0, #T_285b0_row5_col1, #T_285b0_row5_col2, #T_285b0_row5_col3, #T_285b0_row5_col4, #T_285b0_row5_col5, #T_285b0_row5_col6, #T_285b0_row5_col7, #T_285b0_row5_col8, #T_285b0_row5_col9, #T_285b0_row5_col10, #T_285b0_row6_col0, #T_285b0_row6_col1, #T_285b0_row6_col2, #T_285b0_row6_col3, #T_285b0_row6_col4, #T_285b0_row6_col5, #T_285b0_row6_col6, #T_285b0_row6_col7, #T_285b0_row6_col8, #T_285b0_row6_col9, #T_285b0_row6_col10, #T_285b0_row7_col0, #T_285b0_row7_col1, #T_285b0_row7_col2, #T_285b0_row7_col3, #T_285b0_row7_col4, #T_285b0_row7_col5, #T_285b0_row7_col6, #T_285b0_row7_col7, #T_285b0_row7_col8, #T_285b0_row7_col9, #T_285b0_row7_col10, #T_285b0_row8_col0, #T_285b0_row8_col1, #T_285b0_row8_col2, #T_285b0_row8_col3, #T_285b0_row8_col4, #T_285b0_row8_col5, #T_285b0_row8_col6, #T_285b0_row8_col7, #T_285b0_row8_col8, #T_285b0_row8_col9, #T_285b0_row8_col10, #T_285b0_row9_col0, #T_285b0_row9_col1, #T_285b0_row9_col2, #T_285b0_row9_col3, #T_285b0_row9_col4, #T_285b0_row9_col5, #T_285b0_row9_col6, #T_285b0_row9_col7, #T_285b0_row9_col8, #T_285b0_row9_col9, #T_285b0_row9_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_285b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_285b0_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_285b0_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_285b0_level0_col2" class="col_heading level0 col2" >tile_size</th>
#       <th id="T_285b0_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_285b0_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_285b0_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_285b0_level0_col6" class="col_heading level0 col6" >CT_ns</th>
#       <th id="T_285b0_level0_col7" class="col_heading level0 col7" >ET_s</th>
#       <th id="T_285b0_level0_col8" class="col_heading level0 col8" >DL1_miss_rate</th>
#       <th id="T_285b0_level0_col9" class="col_heading level0 col9" >DL1_misses</th>
#       <th id="T_285b0_level0_col10" class="col_heading level0 col10" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_285b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_285b0_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_285b0_row0_col1" class="data row0 col1" >512</td>
#       <td id="T_285b0_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_285b0_row0_col3" class="data row0 col3" >1070281542</td>
#       <td id="T_285b0_row0_col4" class="data row0 col4" >242439252</td>
#       <td id="T_285b0_row0_col5" class="data row0 col5" >0.226519</td>
#       <td id="T_285b0_row0_col6" class="data row0 col6" >0.245084</td>
#       <td id="T_285b0_row0_col7" class="data row0 col7" >0.059418</td>
#       <td id="T_285b0_row0_col8" class="data row0 col8" >0.005558</td>
#       <td id="T_285b0_row0_col9" class="data row0 col9" >2432375</td>
#       <td id="T_285b0_row0_col10" class="data row0 col10" >437667454</td>
#     </tr>
#     <tr>
#       <th id="T_285b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_285b0_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_285b0_row1_col1" class="data row1 col1" >1024</td>
#       <td id="T_285b0_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_285b0_row1_col3" class="data row1 col3" >8793396438</td>
#       <td id="T_285b0_row1_col4" class="data row1 col4" >1993091552</td>
#       <td id="T_285b0_row1_col5" class="data row1 col5" >0.226658</td>
#       <td id="T_285b0_row1_col6" class="data row1 col6" >0.194256</td>
#       <td id="T_285b0_row1_col7" class="data row1 col7" >0.387170</td>
#       <td id="T_285b0_row1_col8" class="data row1 col8" >0.005302</td>
#       <td id="T_285b0_row1_col9" class="data row1 col9" >19065101</td>
#       <td id="T_285b0_row1_col10" class="data row1 col10" >3596013701</td>
#     </tr>
#     <tr>
#       <th id="T_285b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_285b0_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_285b0_row2_col1" class="data row2 col1" >2048</td>
#       <td id="T_285b0_row2_col2" class="data row2 col2" >8</td>
#       <td id="T
lines)
# //START
# void blockmm_transpose(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   int i,j,k, ii, jj, kk;
#   double result = 0;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(ii = i; ii < i+tile_size; ii++)
#             for(jj = j; jj < j+tile_size; jj++)
#             {
#               result = 0;
#               for(kk = k; kk < k+tile_size; kk++)
#                 result += a[ii][kk]*b[jj][kk];
#               c[ii][jj] += result;
#             }
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul; rm blockmm_transpose_reg; make blockmm_transpose_reg; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm_transpose_reg.csv 
! ./matrix_mul/blockmm_transpose_reg 2048 8 >> ./matrix_mul/blockmm_transpose_reg.csv 
! ./matrix_mul/blockmm_transpose_reg 2048 16 >> ./matrix_mul/blockmm_transpose_reg.csv 
! ./matrix_mul/blockmm_transpose_reg 2048 32 >> ./matrix_mul/blockmm_transpose_reg.csv 
! ./matrix_mul/blockmm_transpose_reg 2048 64 >> ./matrix_mul/blockmm_transpose_reg.csv
! ./matrix_mul/blockmm_transpose_reg 2048 128 >> ./matrix_mul/blockmm_transpose_reg.csv
! ./matrix_mul/blockmm_transpose_reg 2048 256 >> ./matrix_mul/blockmm_transpose_reg.csv
# Out:
# rm: cannot remove 'blockmm_transpose_reg': No such file or directory
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H blockmm_transpose_reg.c perfstats.c -o blockmm_transpose_reg
# 10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,

# %%
display_df_mono(render_csv("matrix_mul/blockmm_transpose_reg.csv"))
# Out:
# <style type="text/css">
# #T_10f71_row0_col0, #T_10f71_row0_col1, #T_10f71_row0_col2, #T_10f71_row0_col3, #T_10f71_row0_col4, #T_10f71_row0_col5, #T_10f71_row0_col6, #T_10f71_row0_col7, #T_10f71_row0_col8, #T_10f71_row0_col9, #T_10f71_row0_col10, #T_10f71_row1_col0, #T_10f71_row1_col1, #T_10f71_row1_col2, #T_10f71_row1_col3, #T_10f71_row1_col4, #T_10f71_row1_col5, #T_10f71_row1_col6, #T_10f71_row1_col7, #T_10f71_row1_col8, #T_10f71_row1_col9, #T_10f71_row1_col10, #T_10f71_row2_col0, #T_10f71_row2_col1, #T_10f71_row2_col2, #T_10f71_row2_col3, #T_10f71_row2_col4, #T_10f71_row2_col5, #T_10f71_row2_col6, #T_10f71_row2_col7, #T_10f71_row2_col8, #T_10f71_row2_col9, #T_10f71_row2_col10, #T_10f71_row3_col0, #T_10f71_row3_col1, #T_10f71_row3_col2, #T_10f71_row3_col3, #T_10f71_row3_col4, #T_10f71_row3_col5, #T_10f71_row3_col6, #T_10f71_row3_col7, #T_10f71_row3_col8, #T_10f71_row3_col9, #T_10f71_row3_col10, #T_10f71_row4_col0, #T_10f71_row4_col1, #T_10f71_row4_col2, #T_10f71_row4_col3, #T_10f71_row4_col4, #T_10f71_row4_col5, #T_10f71_row4_col6, #T_10f71_row4_col7, #T_10f71_row4_col8, #T_10f71_row4_col9, #T_10f71_row4_col10, #T_10f71_row5_col0, #T_10f71_row5_col1, #T_10f71_row5_col2, #T_10f71_row5_col3, #T_10f71_row5_col4, #T_10f71_row5_col5, #T_10f71_row5_col6, #T_10f71_row5_col7, #T_10f71_row5_col8, #T_10f71_row5_col9, #T_10f71_row5_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_10f71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10f71_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_10f71_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_10f71_level0_col2" class="col_heading level0 col2" >tile_size</th>
#       <th id="T_10f71_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_10f71_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_10f71_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_10f71_level0_col6" class="col_heading level0 col6" >CT_ns</th>
#       <th id="T_10f71_level0_col7" class="col_heading level0 col7" >ET_s</th>
#       <th id="T_10f71_level0_col8" class="col_heading level0 col8" >DL1_miss_rate</th>
#       <th id="T_10f71_level0_col9" class="col_heading level0 col9" >DL1_misses</th>
#       <th id="T_10f71_level0_col10" class="col_heading level0 col10" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10f71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10f71_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_10f71_row0_col1" class="data row0 col1" >2048</td>
#       <td id="T_10f71_row0_col2" class="data row0 col2" >8</td>
#       <td id="T
row5_col1" class="data row5 col1" >2048</td>
#       <td id="T_10f71_row5_col2" class="data row5 col2" >256</td>
#       <td id="T_10f71_row5_col3" class="data row5 col3" >39326412762</td>
#       <td id="T_10f71_row5_col4" class="data row5 col4" >14051616706</td>
#       <td id="T_10f71_row5_col5" class="data row5 col5" >0.357307</td>
#       <td id="T_10f71_row5_col6" class="data row5 col6" >0.193021</td>
#       <td id="T_10f71_row5_col7" class="data row5 col7" >2.712263</td>
#       <td id="T_10f71_row5_col8" class="data row5 col8" >0.032001</td>
#       <td id="T_10f71_row5_col9" class="data row5 col9" >281741221</td>
#       <td id="T_10f71_row5_col10" class="data row5 col10" >8804127506</td>
#     </tr>
#   </tbody>
# </table>

# %%
render_code("matrix_mul/rect_blockmm_trans.c", show=["//START","//END"])
# Out:
# // matrix_mul/rect_blockmm_trans.c:73-96 (24 lines)
# //START
# void blockmm_transpose(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   int i,j,k, ii, jj, kk;
#   double result=0;
#   for(i = 0; i < M; i+=tile_size_y)
#   {
#     for(j = 0; j < K; j+=tile_size_y)
#     {
#       for(k = 0; k < N; k+=tile_size_x)
#       {
#           for(ii = i; ii < i+tile_size_y; ii++)
#               for(jj = j; jj < j+tile_size_y; jj++)
#               {
#                       result = 0;
#                       for(kk = k; kk < k+tile_size_x ; kk++)
#                           result += a[ii][kk]*b[jj][kk];
#                       c[ii][jj] += result;
#               }
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul; make rect_blockmm_trans; echo "size,tile_size_x,tile_size_y,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 8 8 >> ./matrix_mul/rect_blockmm_trans.csv 
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 8 16 >> ./matrix_mul/rect_blockmm_trans.csv 
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 16 8 >> ./matrix_mul/rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 16 16 >> ./matrix_mul/rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 32 8 >> ./matrix_mul/rect_blockmm_trans.csv 
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 32 16 >> ./matrix_mul/rect_blockmm_trans.csv 
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 64 8 >> ./matrix_mul/rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 128 8 >> ./matrix_mul/rect_blockmm_trans.csv
! taskset -c 8 ./matrix_mul/rect_blockmm_trans 2048 256 8 >> ./matrix_mul/rect_blockmm_trans.csv
display_df_mono(render_csv("matrix_mul/rect_blockmm_trans.csv"))
# Out:
# gcc -O4 -DHAVE_LINUX_PERF_EVENT_H rect_blockmm_trans.c perfstats.c -o rect_blockmm_trans
# 10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,
# <style type="text/css">
# #T_7ef7f_row0_col0, #T_7ef7f_row0_col1, #T_7ef7f_row0_col2, #T_7ef7f_row0_col3, #T_7ef7f_row0_col4, #T_7ef7f_row0_col5, #T_7ef7f_row0_col6, #T_7ef7f_row0_col7, #T_7ef7f_row0_col8, #T_7ef7f_row0_col9, #T_7ef7f_row0_col10, #T_7ef7f_row0_col11, #T_7ef7f_row1_col0, #T_7ef7f_row1_col1, #T_7ef7f_row1_col2, #T_7ef7f_row1_col3, #T_7ef7f_row1_col4, #T_7ef7f_row1_col5, #T_7ef7f_row1_col6, #T_7ef7f_row1_col7, #T_7ef7f_row1_col8, #T_7ef7f_row1_col9, #T_7ef7f_row1_col10, #T_7ef7f_row1_col11, #T_7ef7f_row2_col0, #T_7ef7f_row2_col1, #T_7ef7f_row2_col2, #T_7ef7f_row2_col3, #T_7ef7f_row2_col4, #T_7ef7f_row2_col5, #T_7ef7f_row2_col6, #T_7ef7f_row2_col7, #T_7ef7f_row2_col8, #T_7ef7f_row2_col9, #T_7ef7f_row2_col10, #T_7ef7f_row2_col11, #T_7ef7f_row3_col0, #T_7ef7f_row3_col1, #T_7ef7f_row3_col2, #T_7ef7f_row3_col3, #T_7ef7f_row3_col4, #T_7ef7f_row3_col5, #T_7ef7f_row3_col6, #T_7ef7f_row3_col7, #T_7ef7f_row3_col8, #T_7ef7f_row3_col9, #T_7ef7f_row3_col10, #T_7ef7f_row3_col11, #T_7ef7f_row4_col0, #T_7ef7f_row4_col1, #T_7ef7f_row4_col2, #T_7ef7f_row4_col3, #T_7ef7f_row4_col4, #T_7ef7f_row4_col5, #T_7ef7f_row4_col6, #T_7ef7f_row4_col7, #T_7ef7f_row4_col8, #T_7ef7f_row4_col9, #T_7ef7f_row4_col10, #T_7ef7f_row4_col11, #T_7ef7f_row5_col0, #T_7ef7f_row5_col1, #T_7ef7f_row5_col2, #T_7ef7f_row5_col3, #T_7ef7f_row5_col4, #T_7ef7f_row5_col5, #T_7ef7f_row5_col6, #T_7ef7f_row5_col7, #T_7ef7f_row5_col8, #T_7ef7f_row5_col9, #T_7ef7f_row5_col10, #T_7ef7f_row5_col11, #T_7ef7f_row6_col0, #T_7ef7f_row6_col1, #T_7ef7f_row6_col2, #T_7ef7f_row6_col3, #T_7ef7f_row6_col4, #T_7ef7f_row6_col5, #T_7ef7f_row6_col6, #T_7ef7f_row6_col7, #T_7ef7f_row6_col8, #T_7ef7f_row6_col9, #T_7ef7f_row6_col10, #T_7ef7f_row6_col11, #T_7ef7f_row7_col0, #T_7ef7f_row7_col1, #T_7ef7f_row7_col2, #T_7ef7f_row7_col3, #T_7ef7f_row7_col4, #T_7ef7f_row7_col5, #T_7ef7f_row7_col6, #T_7ef7f_row7_col7, #T_7ef7f_row7_col8, #T_7ef7f_row7_col9, #T_7ef7f_row7_col10, #T_7ef7f_row7_col11, #T_7ef7f_row8_col0, #T_7ef7f_row8_col1, #T_7ef7f_row8_col2, #T_7ef7f_row8_col3, #T_7ef7f_row8_col4, #T_7ef7f_row8_col5, #T_7ef7f_row8_col6, #T_7ef7f_row8_col7, #T_7ef7f_row8_col8, #T_7ef7f_row8_col9, #T_7ef7f_row8_col10, #T_7ef7f_row8_col11 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_7ef7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ef7f_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_7ef7f_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_7ef7f_level0_col2" class="col_heading level0 col2" >tile_size_x</th>
#       <th id="T_7ef7f_level0_col3" class="col_heading level0 col3" >tile_size_y</th>
#       <th id="T_7ef7f_level0_col4" class="col_heading level0 col4" >IC</th>
#       <th id="T_7ef7f_level0_col5" class="col_heading level0 col5" >Cycles</th>
#       <th id="T_7ef7f_level0_col6" class="col_heading level0 col6" >CPI</th>
#       <th id="T_7ef7f_level0_col7" class="col_heading level0 col7" >CT_ns</th>
#       <th id="T_7ef7f_level0_col8" class="col_heading level0 col8" >ET_s</th>
#       <th id="T_7ef7f_level0_col9" class="col_heading level0 col9" >DL1_miss_rate</th>
#       <th id="T_7ef7f_level0_col10" class="col_heading level0 col10" >DL1_misses</th>
#       <th id="T_7ef7f_level0_col11" class="col_heading level0 col11" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ef7f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ef7f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7ef7f_row0_col1" class="data row0 col1" >2048</td>
#       <td id="T_7ef7f_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_7ef7f_row0_col3" class="data row0 col3" >8</td>
#       <td id="T
row4_col3" class="data row4 col3" >8</td>
#       <td id="T_7ef7f_row4_col4" class="data row4 col4" >44182439997</td>
#       <td id="T_7ef7f_row4_col5" class="data row4 col5" >9418862226</td>
#       <td id="T_7ef7f_row4_col6" class="data row4 col6" >0.213181</td>
#       <td id="T_7ef7f_row4_col7" class="data row4 col7" >0.193463</td>
#       <td id="T_7ef7f_row4_col8" class="data row4 col8" >1.822202</td>
#       <td id="T_7ef7f_row4_col9" class="data row4 col9" >0.005665</td>
#       <td id="T_7ef7f_row4_col10" class="data row4 col10" >58957446</td>
#       <td id="T_7ef7f_row4_col11" class="data row4 col11" >

# %% [markdown]
# ## Prefetch
#
# x86 provide prefetch instructions. As a programmer, you may insert ```_mm_prefetch``` in x86 programs to perform software prefetch for your code. The gcc compiler also has a flag ```-fprefetch-loop-arrays``` to automatically insert software prefetch instructions.
#
# ### Using prefetch in matrix transpose code
#
# The following example is a highly optimized matrix transpose code. In the example, we try to prefetch the next row.

# %%
render_code("./prefetch/transpose.cpp", lang="c++", show=["//START", "//END"])
# Out:
# // ./prefetch/transpose.cpp:42-63 (22 lines)
#     //START
#     //  Iterate each row.
#     f_vector *y_iter = T;
#     do{
#         //  Iterate each column.
#         f_vector *ptr_x = y_iter + block;
#         f_vector *ptr_y = y_iter + row_size;
#
#         do{
#
# #ifdef ENABLE_PREFETCH
#             _mm_prefetch((char*)(ptr_y + row_size),_MM_HINT_T0);
# #endif
#             swap_block(ptr_x,ptr_y,block);
#
#             ptr_x += block;
#             ptr_y += row_size;
#         }while (ptr_y < stop_T);
#
#         y_iter += iter_size;
#     }while (y_iter < end);
#     //END

# %% [markdown]
# Now, let's take a look of what's happening!

# %%
! cd prefetch; make clean; make
# ! echo "Without prefetch -- the baseline"; ssh htseng@celebi "lscpu | grep Model; cd courses/CS203/demo/memory/prefetch/; ./transpose"
! echo "Without prefetch -- the baseline"
! lscpu | grep Model
! ./prefetch/transpose
! echo "With prefetch"
! ./prefetch/transpose_prefetch
# Out:
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# Without prefetch -- the baseline
# Model name:                           13th Gen Intel(R) Core(TM) i7-13700
# Model:                                183
# bytes = 4294967296
# Starting Data Transpose...   Done
# Time: 0.510648 seconds
# With prefetch
# bytes = 4294967296
# Starting Data Transpose...   Done
# Time: 0.430467 seconds

# %% [markdown]
# Let's try a different machine now.

# %%
! ssh htseng@xerneas "cd /nfshome/htseng/courses/CSE142/demo/memory/; make -C ./prefetch clean; make -C ./prefetch ; lscpu | grep Model"
! echo "Without prefetch -- the baseline"; ssh htseng@xerneas  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose"
! echo "With prefetch";  ssh htseng@xerneas  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch"
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# Model name:                           AMD Ryzen 9 5950X 16-Core Processor
# Model:                                33
# Without prefetch -- the baseline
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.115764 seconds
# With prefetch
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.108927 seconds

# %%
! ssh htseng@blissey "cd /nfshome/htseng/courses/CSE142/demo/memory/; make -C ./prefetch clean; make -C ./prefetch ; lscpu | grep Model"
! echo "Without prefetch -- the baseline"; ssh htseng@blissey  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose"
! echo "With prefetch";  ssh htseng@blissey  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch"
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# Model name:                           AMD Ryzen 7 5700X 8-Core Processor
# Model:                                33
# Without prefetch -- the baseline
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.103637 seconds
# With prefetch
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.096679 seconds

# %%
! ssh htseng@eevee "cd /nfshome/htseng/courses/CSE142/demo/memory/; make -C ./prefetch clean; make -C ./prefetch ; lscpu | grep Model"
! echo "Without prefetch -- the baseline"; ssh htseng@eevee  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose"
! echo "With prefetch";  ssh htseng@eevee  "/nfshome/htseng/courses/CSE142/demo/memory/prefetch/transpose_prefetch"
# Out:
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# rm -f blockmm_sse blockmm blockmm_sse_prefetch transpose transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# make: Entering directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# g++ -msse4.1 -mavx -O3 transpose.cpp -o transpose
# g++ -msse4.1 -mavx -O3 -DENABLE_PREFETCH transpose.cpp -o transpose_prefetch
# make: Leaving directory '/nfshome/htseng/courses/CSE142/demo/memory/prefetch'
# Model:                              85
# Model name:                         Intel(R) Xeon(R) Silver 4108 CPU @ 1.80GHz
# Without prefetch -- the baseline
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.270896 seconds
# With prefetch
# bytes = 1073741824
# Starting Data Transpose...   Done
# Time: 0.238537 seconds

# %% [markdown]
# -- It doesn't work always!

# %%
render_code("matrix_mul/blockmm_interchange.c", show=["//START","//END"])
# Out:
# // matrix_mul/blockmm_interchange.c:59-77 (19 lines)
# //START
# void blockmm(double **a, double **b, double **c, uint64_t M, uint64_t N, uint64_t K)
# {
#   uint64_t i,j,k, ii, jj, kk;
#   for(i = 0; i < M; i+=tile_size)
#   {
#     for(j = 0; j < K; j+=tile_size)
#     {
#       for(k = 0; k < N; k+=tile_size)
#       {
#           for(kk = k; kk < k+tile_size; kk++)
#               for(ii = i; ii < i+tile_size; ii++)
#                 for(jj = j; jj < j+tile_size; jj++)
#                 c[ii][jj] += a[ii][kk]*b[kk][jj];
#       }
#     }
#   }
# }
# //END

# %%
! cd matrix_mul; rm -f blockmm_interchange; make blockmm_interchange; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm_interchange.csv
! ./matrix_mul/blockmm_interchange 2048 8 >> ./matrix_mul/blockmm_interchange.csv 
! ./matrix_mul/blockmm_interchange 2048 16 >> ./matrix_mul/blockmm_interchange.csv 
! ./matrix_mul/blockmm_interchange 2048 32 >> ./matrix_mul/blockmm_interchange.csv 
! ./matrix_mul/blockmm_interchange 2048 64 >> ./matrix_mul/blockmm_interchange.csv
! ./matrix_mul/blockmm_interchange 2048 128 >> ./matrix_mul/blockmm_interchange.csv
! ./matrix_mul/blockmm_interchange 2048 256 >> ./matrix_mul/blockmm_interchange.csv
! cd matrix_mul; echo "size,tile_size,IC,Cycles,CPI,CT_ns,ET_s,DL1_miss_rate,DL1_misses,DL1_accesses" > blockmm.csv
! ./matrix_mul/blockmm 2048 16 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 32 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 64 >> ./matrix_mul/blockmm.csv
! ./matrix_mul/blockmm 2048 128 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 256 >> ./matrix_mul/blockmm.csv 
! ./matrix_mul/blockmm 2048 512 >> ./matrix_mul/blockmm.csv 
display_df_mono(render_csv("matrix_mul/blockmm.csv"))
display_df_mono(render_csv("matrix_mul/blockmm_interchange.csv"))
# Out:
# gcc -O3 -DHAVE_LINUX_PERF_EVENT_H blockmm_interchange.c perfstats.c -o blockmm_interchange
# blockmm_interchange.c: In function ‘main’:
# blockmm_interchange.c:48:16: warning: format ‘%lu’ expects argument of type ‘long unsigned int’, but argument 3 has type ‘int’ [-Wformat=]
#    48 |   printf("%d,%lu,",ARRAY_SIZE,tile_size);
#       |              ~~^              ~~~~~~~~~
#       |                |              |
#       |                |              int
#       |                long unsigned int
#       |              %u
# 10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,10521102336.000000,
# <style type="text/css">
# #T_0e500_row0_col0, #T_0e500_row0_col1, #T_0e500_row0_col2, #T_0e500_row0_col3, #T_0e500_row0_col4, #T_0e500_row0_col5, #T_0e500_row0_col6, #T_0e500_row0_col7, #T_0e500_row0_col8, #T_0e500_row0_col9, #T_0e500_row0_col10, #T_0e500_row1_col0, #T_0e500_row1_col1, #T_0e500_row1_col2, #T_0e500_row1_col3, #T_0e500_row1_col4, #T_0e500_row1_col5, #T_0e500_row1_col6, #T_0e500_row1_col7, #T_0e500_row1_col8, #T_0e500_row1_col9, #T_0e500_row1_col10, #T_0e500_row2_col0, #T_0e500_row2_col1, #T_0e500_row2_col2, #T_0e500_row2_col3, #T_0e500_row2_col4, #T_0e500_row2_col5, #T_0e500_row2_col6, #T_0e500_row2_col7, #T_0e500_row2_col8, #T_0e500_row2_col9, #T_0e500_row2_col10, #T_0e500_row3_col0, #T_0e500_row3_col1, #T_0e500_row3_col2, #T_0e500_row3_col3, #T_0e500_row3_col4, #T_0e500_row3_col5, #T_0e500_row3_col6, #T_0e500_row3_col7, #T_0e500_row3_col8, #T_0e500_row3_col9, #T_0e500_row3_col10, #T_0e500_row4_col0, #T_0e500_row4_col1, #T_0e500_row4_col2, #T_0e500_row4_col3, #T_0e500_row4_col4, #T_0e500_row4_col5, #T_0e500_row4_col6, #T_0e500_row4_col7, #T_0e500_row4_col8, #T_0e500_row4_col9, #T_0e500_row4_col10, #T_0e500_row5_col0, #T_0e500_row5_col1, #T_0e500_row5_col2, #T_0e500_row5_col3, #T_0e500_row5_col4, #T_0e500_row5_col5, #T_0e500_row5_col6, #T_0e500_row5_col7, #T_0e500_row5_col8, #T_0e500_row5_col9, #T_0e500_row5_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_0e500">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e500_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_0e500_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_0e500_level0_col2" class="col_heading level0 col2" >tile_size</th>
#       <th id="T_0e500_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_0e500_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_0e500_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_0e500_level0_col6" class="col_heading level0 col6" >CT_ns</th>
#       <th id="T_0e500_level0_col7" class="col_heading level0 col7" >ET_s</th>
#       <th id="T_0e500_level0_col8" class="col_heading level0 col8" >DL1_miss_rate</th>
#       <th id="T_0e500_level0_col9" class="col_heading level0 col9" >DL1_misses</th>
#       <th id="T_0e500_level0_col10" class="col_heading level0 col10" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e500_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e500_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0e500_row0_col1" class="data row0 col1" >2048</td>
#       <td id="T_0e500_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_0e500_row0_col3" class="data row0 col3" >74473386911</td>
#       <td id="T_0e500_row0_col4" class="data row0 col4" >19237819138</td>
#       <td id="T_0e500_row0_col5" class="data row0 col5" >0.258318</td>
#       <td id="T_0e500_row0_col6" class="data row0 col6" >0.193622</td>
#       <td id="T_0e500_row0_col7" class="data row0 col7" >3.724860</td>
#       <td id="T_0e500_row0_col8" class="data row0 col8" >0.071290</td>
#       <td id="T_0e500_row0_col9" class="data row0 col9" >2573932385</td>
#       <td id="T_0e500_row0_col10" class="data row0 col10" >36105251964</td>
#     </tr>
#     <tr>
#       <th id="T_0e500_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0e500_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_0e500_row1_col1" class="data row1 col1" >2048</td>
#       <td id="T_0e500_row1_col2" class="data row1 col2" >32</td>
#       <td id="T_0e500_row1_col3" class="data row1 col3" >71544344489</td>
#       <td id="T_0e500_row1_col4" class="data row1 col4" >28028089435</td>
#       <td id="T_0e500_row1_col5" class="data row1 col5" >0.391758</td>
#       <td id="T_0e500_row1_col6" class="data row1 col6" >0.193641</td>
#       <td id="T_0e500_row1_col7" class="data row1 col7" >5.427381</td>
#       <td id="T_0e500_row1_col8" class="data row1 col8" >0.217403</td>
#       <td id="T_0e500_row1_col9" class="data row1 col9" >7655790077</td>
#       <td id="T_0e500_row1_col10" class="data row1 col10" >35214730065</td>
#     </tr>
#     <tr>
#       <th id="T_0e500_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0e500_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_0e500_row2_col1" class="data row2 col1" >2048</td>
#       <td id="T_0e500_row2_col2" class="data row2 col2" >64</td>
#       <td id="T_0e500_row2_col3" class="data row2 col3" >70028007243</td>
#       <td id="T_0e500_row2_col4" class="data row2 col4" >32675835340</td>
#       <td id="T_0e500_row2_col5" class="data row2 col5" >0.466611</td>
#       <td id="T_0e500_row2_col6" class="data row2 col6" >0.194037</td>
#       <td id="T_0e500_row2_col7" class="data row2 col7" >6.340316</td>
#       <td id="T_0e500_row2_col8" class="data row2 col8" >0.242686</td>
#       <td id="T_0e500_row2_col9" class="data row2 col9" >8429345312</td>
#       <td id="T_0e500_row2_col10" class="data row2 col10" >34733602612</td>
#     </tr>
#     <tr>
#       <th id="T_0e500_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0e500_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_0e500_row3_col1" class="data row3 col1" >2048</td>
#       <td id="T_0e500_row3_col2" class="data row3 col2" >128</td>
#       <td id="T_0e500_row3_col3" class="data row3 col3" >69474313293</td>
#       <td id="T_0e500_row3_col4" class="data row3 col4" >37149820875</td>
#       <td id="T_0e500_row3_col5" class="data row3 col5" >0.534727</td>
#       <td id="T_0e500_row3_col6" class="data row3 col6" >0.193606</td>
#       <td id="T_0e500_row3_col7" class="data row3 col7" >7.192432</td>
#       <td id="T_0e500_row3_col8" class="data row3 col8" >0.244877</td>
#       <td id="T_0e500_row3_col9" class="data row3 col9" >8470773775</td>
#       <td id="T_0e500_row3_col10" class="data row3 col10" >34591994955</td>
#     </tr>
#     <tr>
#       <th id="T_0e500_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0e500_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_0e500_row4_col1" class="data row4 col1" >2048</td>
#       <td id="T_0e500_row4_col2" class="data row4 col2" >256</td>
#       <td id="T_0e500_row4_col3" class="data row4 col3" >69120040189</td>
#       <td id="T_0e500_row4_col4" class="data row4 col4" >53298747450</td>
#       <td id="T_0e500_row4_col5" class="data row4 col5" >0.771104</td>
#       <td id="T_0e500_row4_col6" class="data row4 col6" >0.193899</td>
#       <td id="T_0e500_row4_col7" class="data row4 col7" >10.334574</td>
#       <td id="T_0e500_row4_col8" class="data row4 col8" >0.241203</td>
#       <td id="T_0e500_row4_col9" class="data row4 col9" >8316237916</td>
#       <td id="T_0e500_row4_col10" class="data row4 col10" >34478129179</td>
#     </tr>
#     <tr>
#       <th id="T_0e500_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0e500_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_0e500_row5_col1" class="data row5 col1" >2048</td>
#       <td id="T_0e500_row5_col2" class="data row5 col2" >512</td>
#       <td id="T_0e500_row5_col3" class="data row5 col3" >69044315168</td>
#       <td id="T_0e500_row5_col4" class="data row5 col4" >72573739373</td>
#       <td id="T_0e500_row5_col5" class="data row5 col5" >1.051118</td>
#       <td id="T_0e500_row5_col6" class="data row5 col6" >0.193706</td>
#       <td id="T_0e500_row5_col7" class="data row5 col7" >14.057958</td>
#       <td id="T_0e500_row5_col8" class="data row5 col8" >0.235176</td>
#       <td id="T_0e500_row5_col9" class="data row5 col9" >8106169032</td>
#       <td id="T_0e500_row5_col10" class="data row5 col10" >34468477710</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_835b7_row0_col0, #T_835b7_row0_col1, #T_835b7_row0_col2, #T_835b7_row0_col3, #T_835b7_row0_col4, #T_835b7_row0_col5, #T_835b7_row0_col6, #T_835b7_row0_col7, #T_835b7_row0_col8, #T_835b7_row0_col9, #T_835b7_row0_col10, #T_835b7_row1_col0, #T_835b7_row1_col1, #T_835b7_row1_col2, #T_835b7_row1_col3, #T_835b7_row1_col4, #T_835b7_row1_col5, #T_835b7_row1_col6, #T_835b7_row1_col7, #T_835b7_row1_col8, #T_835b7_row1_col9, #T_835b7_row1_col10, #T_835b7_row2_col0, #T_835b7_row2_col1, #T_835b7_row2_col2, #T_835b7_row2_col3, #T_835b7_row2_col4, #T_835b7_row2_col5, #T_835b7_row2_col6, #T_835b7_row2_col7, #T_835b7_row2_col8, #T_835b7_row2_col9, #T_835b7_row2_col10, #T_835b7_row3_col0, #T_835b7_row3_col1, #T_835b7_row3_col2, #T_835b7_row3_col3, #T_835b7_row3_col4, #T_835b7_row3_col5, #T_835b7_row3_col6, #T_835b7_row3_col7, #T_835b7_row3_col8, #T_835b7_row3_col9, #T_835b7_row3_col10, #T_835b7_row4_col0, #T_835b7_row4_col1, #T_835b7_row4_col2, #T_835b7_row4_col3, #T_835b7_row4_col4, #T_835b7_row4_col5, #T_835b7_row4_col6, #T_835b7_row4_col7, #T_835b7_row4_col8, #T_835b7_row4_col9, #T_835b7_row4_col10, #T_835b7_row5_col0, #T_835b7_row5_col1, #T_835b7_row5_col2, #T_835b7_row5_col3, #T_835b7_row5_col4, #T_835b7_row5_col5, #T_835b7_row5_col6, #T_835b7_row5_col7, #T_835b7_row5_col8, #T_835b7_row5_col9, #T_835b7_row5_col10 {
#   font-family: SF Mono;
#   font-size: 1.4vw;
# }
# </style>
# <table id="T_835b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_835b7_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_835b7_level0_col1" class="col_heading level0 col1" >size</th>
#       <th id="T_835b7_level0_col2" class="col_heading level0 col2" >tile_size</th>
#       <th id="T_835b7_level0_col3" class="col_heading level0 col3" >IC</th>
#       <th id="T_835b7_level0_col4" class="col_heading level0 col4" >Cycles</th>
#       <th id="T_835b7_level0_col5" class="col_heading level0 col5" >CPI</th>
#       <th id="T_835b7_level0_col6" class="col_heading level0 col6" >CT_ns</th>
#       <th id="T_835b7_level0_col7" class="col_heading level0 col7" >ET_s</th>
#       <th id="T_835b7_level0_col8" class="col_heading level0 col8" >DL1_miss_rate</th>
#       <th id="T_835b7_level0_col9" class="col_heading level0 col9" >DL1_misses</th>
#       <th id="T_835b7_level0_col10" class="col_heading level0 col10" >DL1_accesses</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_835b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_835b7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_835b7_row0_col1" class="data row0 col1" >2048</td>
#       <td id="T_835b7_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_835b7_row0_col3" class="data row0 col3" >68604448245</td>
#       <td id="T_835b7_row0_col4" class="data row0 col4" >15718358160</td>
#       <td id="T_835b7_row0_col5" class="data row0 col5" >0.229116</td>
#       <td id="T_835b7_row0_col6" class="data row0 col6" >0.193676</td>
#       <td id="T_835b7_row0_col7" class="data row0 col7" >3.044266</td>
#       <td id="T_835b7_row0_col8" class="data row0 col8" >0.013131</td>
#       <td id="T_835b7_row0_col9" class="data row0 col9" >316092777</td>
#       <td id="T_835b7_row0_col10" class="data row0 col10" >24071954131</td>
#     </tr>
#     <tr>
#       <th id="T_835b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_835b7_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_835b7_row1_col1" class="data row1 col1" >2048</td>
#       <td id="T_835b7_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_835b7_row1_col3" class="data row1 col3" >50678840944</td>
#       <td id="T_835b7_row1_col4" class="data row1 col4" >13624971615</td>
#       <td id="T_835b7_row1_col5" class="data row1 col5" >0.268849</td>
#       <td id="T_835b7_row1_col6" class="data row1 col6" >0.193750</td>
#       <td id="T_835b7_row1_col7" class="data row1 col7" >2.639845</td>
#       <td id="T_835b7_row1_col8" class="data row1 col8" >0.072926</td>
#       <td id="T_835b7_row1_col9" class="data row1 col9" >1318845843</td>
#       <td id="T_835b7_row1_col10" class="data row1 col10" >18084631718</td>
#     </tr>
#     <tr>
#       <th id="T_835b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T